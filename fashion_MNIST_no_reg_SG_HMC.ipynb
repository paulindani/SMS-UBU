# %%
#@title Import Dependencies

import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import itertools
import pickle
import numpy as np
from numpy import random
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from tqdm import tqdm
from PIL import Image
from matplotlib import pyplot as plt
import matplotlib
from typing import TypeVar, Dict

import torch
import torch.nn as nn
from torch.optim.optimizer import Optimizer

Tensor = TypeVar('torch.tensor')

#matplotlib.use('Agg')

import click
from argparse import Namespace
import ast
import os

import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F
from typing import TypeVar, Tuple
import gdown
import copy
# Out:
# no display found. Using non-interactive Agg backend

# %%
#@title Define Hyperparameters

# class_names = ["5_o_Clock_Shadow", "Arched_Eyebrows", "Attractive", "Bags_Under_Eyes", "Bald", "Bangs",
#                 "Big_Lips", "Big_Nose", "Black_Hair", "Blond_Hair", "Blurry", "Brown_Hair", "Bushy_Eyebrows",
#                 "Chubby", "Double_Chin", "Eyeglasses", "Goatee", "Gray_Hair", "Heavy_Makeup", "High_Cheekbones",
#                 "Male", "Mouth_Slightly_Open", "Mustache", "Narrow_Eyes", "No_Beard", "Oval_Face", "Pale_Skin",
#                 "Pointy_Nose", "Receding_Hairline", "Rosy_Cheeks", "Sideburns", "Smiling", "Straight_Hair",
#                 "Wavy_Hair", "Wearing_Earrings", "Wearing_Hat", "Wearing_Lipstick", "Wearing_Necklace",
#                 "Wearing_Necktie", "Young"]
# num_classes = 40
# data_shape = [3, 64, 64]
# n_bits = 5
# temp = 0.7
# data_mean = [0.485, 0.456, 0.406]
# data_std = [0.229, 0.224, 0.225]

input_size = 28*28*1 # img_size = (28,28) ---> 28*28=784 in total
batch_size = 200 # the size of input data took for one iteration

# %%
# from torchvision.transforms import v2
# transform_RandomErasing=transforms.Compose([v2.RandomErasing(),
#                               transforms.ToTensor()])

transform=transforms.Compose([transforms.ToTensor()])

train_data = dsets.FashionMNIST(root = './data', train=True, transform = transform, download = True)
test_data = dsets.FashionMNIST(root = './data', train=False, transform = transform, download = True)

# %%
#@title Loading the data

train_gen = torch.utils.data.DataLoader(dataset = train_data,
                                             batch_size = batch_size,
                                             shuffle = True)

test_gen = torch.utils.data.DataLoader(dataset = test_data,
                                      batch_size = batch_size,
                                      shuffle = False)

# %%
#cvmx=torch.zeros([3*64*64,3*64*64],device=device)
images_list=[]
labels_list=[]
no_batches=len(train_gen)
#images_mean=torch.zeros(3,64,64,device=device)
for i ,(images,labels) in enumerate(train_gen):
    images = Variable(images).cuda().detach()
    labels=Variable(labels).cuda().detach()
    # images_mean=images_mean+images.mean(0)
    # im=torch.reshape(images,[images.shape[0],3*64*64])
    # cvmx+=torch.matmul(torch.transpose(im,0,1),im)
    if(i<(len(train_gen))):
        images_list.append(images)
        labels_list.append(labels)



test_images_list=[]
test_labels_list=[]
test_no_batches=len(test_gen)
for i ,(images,labels) in enumerate(test_gen):
    images = Variable(images).cuda().detach()
    labels=Variable(labels).cuda().detach()
    if(i<(len(test_gen))):
        test_images_list.append(images)
        test_labels_list.append(labels)

train_data_len=len(train_data)
test_data_len=len(test_data)

# %%
#@title Define model class
import torch.nn as nn
import torch
import torch.nn.functional as F

from typing import TypeVar, Tuple

Tensor = TypeVar('torch.tensor')


class CNN(NeuralNet):
    """
    CNN for (binary) classification for CelebA, CheXpert
    """

    def __init__(self,
                 in_channels: int = 3,
                 num_classes: int = 2,
                 flattened_size: int = 16384,
                 low_rank: int = 32,
                 batch_norm_mom: float = 1.0):
        """CNN Builder."""
        super(CNN, self).__init__()

        self.conv_layer = nn.Sequential(

            # Conv Layer block 1
            nn.Conv2d(in_channels=in_channels, out_channels=32, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(32,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.BatchNorm2d(64,momentum=batch_norm_mom),

            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(64,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(128,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.MaxPool2d(kernel_size=2, stride=2),
            #nn.BatchNorm2d(128),

            # nn.BatchNorm2d(128),
            # nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            # nn.Softplus(beta=1.0),
            # nn.MaxPool2d(kernel_size=2, stride=2),
            # nn.BatchNorm2d(128),

            # # Conv Layer block 2
            # nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            # nn.BatchNorm2d(128),
            # nn.Softplus(beta=1.0),
            # nn.BatchNorm2d(128),
            # nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            # nn.Softplus(beta=1.0),
            # nn.MaxPool2d(kernel_size=2, stride=2),
            # nn.BatchNorm2d(128),

            # Conv Layer block 3
            nn.BatchNorm2d(128,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(256,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.fc_layer = nn.Sequential(
            #nn.Dropout(p=0.1),
            nn.BatchNorm1d(flattened_size,momentum=batch_norm_mom),
#            nn.Linear(flattened_size, 512),
            nn.Linear(flattened_size, low_rank),
            nn.BatchNorm1d(low_rank,momentum=batch_norm_mom),
            nn.Linear(low_rank,512),            
            nn.Softplus(beta=1.0),
            nn.BatchNorm1d(512,momentum=batch_norm_mom),
            # nn.Linear(2048, 512),
            # nn.Softplus(beta=1.0),
            # nn.BatchNorm1d(512),
            # nn.Linear(1024, 512),
            # nn.Softplus(beta=1.0), 
            # nn.BatchNorm1d(512),
            #nn.Dropout(p=0.1),
        )

        self.last_layer=nn.Sequential(
            nn.Linear(512, num_classes)
        )

    def forward(self, x: Tensor) -> Tensor:
        """Perform forward."""

        # conv layers
        x = self.conv_layer(x)

        # flatten
        x = x.view(x.size(0), -1)

        # # # fc layer
        x = self.fc_layer(x)

        x=self.last_layer(x)

        return x

    def classify(self, x: Tensor) -> Tuple[Tensor, Tensor, Tensor]:
        net_out = self.forward(x)
        acc = F.softmax(net_out, dim=1)
        class_idx = torch.max(net_out, 1)[1]

        return acc, acc[0, class_idx], class_idx
    




class CelebA_CNN(CNN):
    """CNN."""

    def __init__(self,
                 in_channels: int = 3,
                 num_classes: int = 2,
                 #num_classes: int = 1,
                 flattened_size: int = 16384):
        """CNN Builder."""
        super(CelebA_CNN, self).__init__(in_channels=in_channels, num_classes=num_classes,
                                         flattened_size=flattened_size)

class Fashion_MNIST_CNN(CNN):
    """CNN."""

    def __init__(self,
                 in_channels: int = 1,
                 num_classes: int = 10,
                 #flattened_size: int = 6272,
                 flattened_size: int = 2304,
                 low_rank: int = 64,
                 batch_norm_mom: float = 1.0):
        """CNN Builder."""
        super(Fashion_MNIST_CNN, self).__init__(in_channels=in_channels, num_classes=num_classes,
                                         flattened_size=flattened_size)




class CheXpert_CNN(CNN):
    def __init__(self,
                 in_channels: int = 1,
                 num_classes: int = 2,
                 flattened_size: int = 65536):
        """CNN Builder."""
        super(CheXpert_CNN, self).__init__(in_channels=in_channels, num_classes=num_classes,
                                           flattened_size=flattened_size)


class Net(nn.Module):
  def __init__(self, input_size, hidden_size, num_classes):
    super(Net,self).__init__()
    self.fc1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(hidden_size, num_classes)

  def forward(self,x):
    out = self.fc1(x)
    out = self.relu(out)
    out = self.fc2(out)
    return out

# %%
# net=Fashion_MNIST_CNN()
# n=0
# for par in net.parameters():
#     n+=par.numel()

# n

# %%
#@title Define loss-function & optimizer
loss_function = nn.CrossEntropyLoss()


def images_regulariser(): 
    li_reg_loss = 0
    penalized     = [p for name,p in net.named_parameters() if 'bias' not in name]
    not_penalized = [p for name,p in net.named_parameters() if 'bias' in name]
    for p in penalized:
        li_reg_loss += (p**2).sum()*0.5
    #for p in net.parameters():
#        li_reg_loss += (p**2).sum()*0.5
    reg=li_reg_loss/(train_data_len)*l2regconst
    return(reg)

# %%
def addnet(net,net2):
    for param1, param2 in zip(net.parameters(), net2.parameters()):
     param1.data += param2.data

def multiplynet(net,a):
   for param1 in net.parameters():
     param1.data *=a

# %%
from dataclasses import dataclass
@dataclass
class hclass:
    h: Tensor
    eta: Tensor
    etam1g: Tensor
    c11: Tensor
    c21: Tensor
    c22: Tensor

def hper2const(h,gam):
    gh=gam.double()*h.double()
    s=torch.sqrt(4*torch.expm1(-gh/2)-torch.expm1(-gh)+gh)
    eta=(torch.exp(-gh/2)).float()
    etam1g=((-torch.expm1(-gh/2))/gam.double()).float()
    c11=(s/gam).float()
    c21=(torch.exp(-gh)*(torch.expm1(gh/2.0))**2/s).float()
    c22=(torch.sqrt(8*torch.expm1(-gh/2)-4*torch.expm1(-gh)-gh*torch.expm1(-gh))/s).float()
    hc=hclass(h=h,eta=eta,etam1g=etam1g,c11=c11,c21=c21,c22=c22)
    return(hc)

def U(x,v,hc):
    xi1=torch.randn(x.size(),device=device)
    xi2=torch.randn(x.size(),device=device)

    xn=x+hc.etam1g*v+hc.c11*xi1
    vn=v*hc.eta+hc.c21*xi1+hc.c22*xi2
    return([xn, vn])

def bounce(x,v,xstar,width):
    vsign=(((x-xstar+width)/(2*width)).floor()% 2)*(-2)+1
    vn=v*vsign
    xn=((x-xstar-width)% (4*width)-2*width).abs()-width+xstar
    # num_outside=((xn-xstar)>width).sum()+((xstar-xn)>width).sum()
    # if(num_outside>0):
    #     print(num_outside)    
    return([xn, vn])

def bouncenet():
    for p,p_star in zip(net.parameters(),net_star.parameters()):
        [p.data, p.v]=bounce(p.data, p.v, p_star.data, 6/torch.sqrt(l2regconst_extra))

def svrg_grad(net, batch_it):
    outputsU = net(images_list[batch_it])
    loss_likelihood = loss_function(outputsU, labels_list[batch_it])  


    grads_reg=[torch.zeros_like(par) for par in net.parameters()]
    net_pars=list(net.parameters())
    with torch.no_grad():
        for it in range(len_params):
            if(list_no_bias[it]):
                grads_reg[it]=net_pars[it].data*l2regconst

    net.zero_grad()
    loss_likelihood.backward()
    with torch.no_grad():
        grads_likelihood=[par.grad*batch_size for par in net.parameters()]

        svrg_grads=[]
        for p,grad,grad_reg,p_star,grad_star,star_sum_grad in zip(list(net.parameters()),grads_likelihood,grads_reg,list(net_star.parameters()),net_star_grad_list[batch_it],net_star_full_grad):              
            svrg_grads.append(grad_reg+star_sum_grad+(grad-grad_star)*no_batches+l2regconst_extra*(p.data-p_star.data))
    return svrg_grads,loss_likelihood.data

def EM_step(net, h, gam,batch_it):   
    svrg_grads,loss_likelihood_data=svrg_grad(net, batch_it)   

    with torch.no_grad():
        for p,gradp in zip(net.parameters(), svrg_grads):              
            p.xi=torch.randn_like(p.data,device=device)
            p.data+=p.v*h
            p.v-=(h)*gradp+gam*(h)*p.v-torch.sqrt(2*gam*h)*p.xi

    return(loss_likelihood_data)

def UBU_step(hper2c,images,labels,batch_it):   
    with torch.no_grad():
        for p in list(net.parameters()):
            # maxlen=20*torch.sqrt((torch.tensor(torch.numel(p.v))).float())
            # if(torch.norm(p.v)>maxlen):
            #    print("big trouble!!!!")    
            [p.data,p.v]=U(p.data,p.v,hper2c)

        #bouncenet()
    #print("outputsU",len(outputsU))
    #print("labelsU",len(labels))
    #print("imagesU",len(images))
    outputsU = net(images)
    loss_likelihood = loss_function(outputsU, labels)  


    grads_reg=[torch.zeros_like(par) for par in net.parameters()]
    net_pars=list(net.parameters())
    with torch.no_grad():
        for it in range(len_params):
            if(list_no_bias[it]):
                grads_reg[it]=net_pars[it].data*l2regconst

    net.zero_grad()
    #loss.backward()
    loss_likelihood.backward()
    with torch.no_grad():
        grads_likelihood=[par.grad*batch_size for par in net.parameters()]
    
        #Normal, no variance reduction
        # for p,p_star in zip(net.parameters(),net_star.parameters()):      
        #     p.v-=hper2c.h*(p.grad*train_data_len+l2regconst_extra*(p.data-p_star.data))

        for p,grad,grad_reg,p_star,grad_star,star_sum_grad in zip(list(net.parameters()),grads_likelihood,grads_reg,list(net_star.parameters()),net_star_grad_list[batch_it],net_star_full_grad):              
            #Using variance reduction
            p.v-=hper2c.h*(grad_reg+star_sum_grad+(grad-grad_star)*no_batches+l2regconst_extra*(p.data-p_star.data))

            # maxlen=20*torch.sqrt((torch.tensor(torch.numel(p.v))).float())
            # if(torch.norm(p.v)>maxlen):
            #     print("trouble")
                #p.v=(p.v/torch.norm(p.v))*maxlen
        # for it in range(len_params):
        #     [list(net.parameters())[it].data,list(net.parameters())[it].v]=U(list(net.parameters())[it].data,list(net.parameters())[it].v,hper2c)        
        for p in list(net.parameters()):
            [p.data,p.v]=U(p.data,p.v,hper2c)

    #bouncenet()
    return(loss_likelihood.data)

def ind_create(batch_it):
    modit=batch_it %(2*no_batches)
    ind=(modit<=(no_batches-1))*modit+(modit>=no_batches)*(2*no_batches-modit-1)
    return ind

# %%
#net = Fashion_MNIST_CNN().cuda()
#net2=copy.deepcopy(net)
#addnet(net2,net)
#multiplynet(net2,1/10)

# %%
# filepath="output_fashion_low_rank_9n.pickle"
# #filepath="output_fashion_low_rank_long.pickle"
# with open(filepath,"rb") as file:
#    [labels_arr,test_labels_arr,test_prob_arr]=pickle.load(file)
# labels_arr=torch.tensor(labels_arr).detach()
# test_labels_arr=torch.tensor(test_labels_arr).detach()
# test_prob_arr=torch.tensor(test_prob_arr).detach()

# %%
#@title Output arrays
par_runs=64
num_classes=10
num_epochs=60
switch_to_sampling_epoch=20
switch_to_swag_epoch=15

num_swag_epochs=switch_to_sampling_epoch-switch_to_swag_epoch

training_size=no_batches*batch_size
test_size=test_data_len
labels_arr=torch.zeros(training_size)
test_labels_arr=torch.zeros(test_size)
test_prob_arr=torch.zeros([test_size,num_classes,num_epochs,par_runs])

lr = 1e-2
lr_swag=1e-3
h=2.5e-4
l2regconst=torch.tensor(1).detach()
l2regconst_extra=torch.tensor(0).detach()
gam=torch.sqrt(torch.tensor(50)).detach()
hper2c=hper2const(torch.tensor(h/2),gam)

for par_it in range(par_runs):
  print("par_it:",par_it,"\n")
  #@title Build the model
  net = Fashion_MNIST_CNN().cuda()
  net.train()
  optimizer = torch.optim.Adam( net.parameters(), lr=lr)
  
  lr_scheduler = torch.optim.lr_scheduler.PolynomialLR(optimizer=optimizer, total_iters=switch_to_swag_epoch,power=1)


  #@title Training the model

  for epoch in range(num_epochs):
    sum_loss=0
    #l2regconst=torch.min(torch.tensor(1+epoch),torch.tensor(switch_to_swag_epoch)).detach()
    net.train()
    if(epoch==(switch_to_swag_epoch-1)):
      net_star2=copy.deepcopy(net)
      net2=copy.deepcopy(net)
      multiplynet(net2,0)
      optimizer=torch.optim.Adam(net.parameters(),lr=lr_swag)

    if(epoch>=switch_to_sampling_epoch and (epoch-switch_to_sampling_epoch)%2==0):
        rperm=random.permutation(list(range(no_batches)))
    
    for i in range(no_batches): 
      b=torch.randint(high=no_batches,size=(1,1))
      images=images_list[b]
      labels=labels_list[b]
      
      # outputs = net(images)    
      # loss = loss_function(outputs, labels)
      # sum_loss=sum_loss+loss    
      # reg=images_regulariser()
      # loss=loss+reg
      # optimizer.zero_grad()
      # loss.backward()
      # optimizer.step()
      # sum_loss_tot=sum_loss_tot+loss


      if(epoch<switch_to_sampling_epoch):
        outputs = net(images)    
        loss_likelihood = loss_function(outputs, labels)
        sum_loss=sum_loss+loss_likelihood    
        reg=images_regulariser()
        loss=loss_likelihood+reg
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if(epoch>=(switch_to_swag_epoch)):
          addnet(net2,net)
      else:
        loss_likelihood=EM_step(net, h, gam,b)
        #UBU_step(hper2c,images,labels,b)
        sum_loss=sum_loss+loss_likelihood




    #if (i+1) % (no_batches) == 0:
    #print("Reg:",reg)
    print('Epoch [%d/%d], Step [%d/%d]' %(epoch+1, num_epochs, i+1, no_batches))
    correct = 0
    total = 0
    





    #for imagest,labelst in eval_gen:
    if epoch==(switch_to_sampling_epoch-1):
      multiplynet(net2,1/(num_swag_epochs*no_batches))
      multiplynet(net,0)
      addnet(net,net2)
      del net2

      net_star=copy.deepcopy(net)
      len_params=len(list(net_star.parameters()))

      #Variance reduction - saving gradients at each batch at x_star
      net_star_grad_list=[]
      net_star_full_grad=[torch.zeros_like(par, device=device) for par in list(net_star.parameters())]
      for i in range(no_batches):
          images=images_list[i]
          labels=labels_list[i]
          outputs=net_star(images)
          loss_likelihood = loss_function(outputs, labels)
          reg=images_regulariser()
          net_star.zero_grad()
          loss_likelihood.backward()
          grads=[par.grad*batch_size for par in list(net_star.parameters())]
          net_star_grad_list.append(grads)
          for g, gi in zip(net_star_full_grad,grads):
            g+=gi          

      len_params=len(list(net_star.parameters()))
      list_no_bias=torch.zeros(len_params)
      pit=0
      for name, p in net_star.named_parameters():
          if 'bias' not in name:
              list_no_bias[pit]=1.0
          pit+=1

      #Initialise velocities
      for par in list(net.parameters()):
        par.v = torch.randn_like(par,device=device)      


    with torch.no_grad():
      net(torch.cat(images_list[0:20],dim=0).detach())        
      net.eval()

      # for mod in list(net.named_modules()):
      #   if(hasattr(mod[1],"momentum")):
      #     mod[1].momentum=None
      # for i in range(no_batches):
      #   net(images_list[i].detach())
      # net.eval()

      for testit in range(test_no_batches):
        imagest=test_images_list[testit]
        labelst=test_labels_list[testit]
        actual_batch_size=len(imagest)
        test_labels_arr[(testit*batch_size):(testit*batch_size+actual_batch_size)]=labelst.detach().cpu()
        outputt = net(imagest).detach()#.reshape(actual_batch_size).detach()
        _, predictedt = torch.max(outputt,1)

        correct += (predictedt == labelst).sum()
        total += labelst.size(0)

        test_prob_arr[(testit*batch_size):(testit*batch_size+actual_batch_size),:,epoch,par_it]=torch.softmax(outputt,dim=1)
    


    

    #net.train()       
    print('Test accuracy of the model: %.3f %%' %((100*correct)/(total+1)))

    if(epoch<=switch_to_swag_epoch):
      lr_scheduler.step()
    print('Epoch [%d], Average Loss: %0.4f' %(epoch+1, sum_loss/no_batches))
    
    # for mod in list(net.named_modules()):
    #   if(hasattr(mod[1],"momentum")):
    #     mod[1].momentum=1.0
  
  filepath="output_fashion_SG_HMC.pickle"
  with open(filepath,"wb") as file:
    pickle.dump([labels_arr.numpy(),test_labels_arr.numpy(),test_prob_arr.numpy()],file)
# Out:
# par_it: 0
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 86.661 %
# Epoch [1], Average Loss: 0.5508
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 90.321 %
# Epoch [2], Average Loss: 0.2899
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.481 %
# Epoch [3], Average Loss: 0.2468
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 91.311 %
# Epoch [4], Average Loss: 0.2185
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.821 %
# Epoch [5], Average Loss: 0.1872
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 92.121 %
# Epoch [6], Average Loss: 0.1742
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.921 %
# Epoch [7], Average Loss: 0.1494
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 92.161 %
# Epoch [8], Average Loss: 0.1381
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.401 %
# Epoch [9], Average Loss: 0.1299
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.041 %
# Epoch [10], Average Loss: 0.1067
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.871 %
# Epoch [11], Average Loss: 0.0934
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.621 %
# Epoch [12], Average Loss: 0.0736
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.981 %
# Epoch [13], Average Loss: 0.0503
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.271 %
# Epoch [14], Average Loss: 0.0301
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 92.991 %
# Epoch [15], Average Loss: 0.0204
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 93.151 %
# Epoch [16], Average Loss: 0.0130
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.851 %
# Epoch [17], Average Loss: 0.0145
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 93.111 %
# Epoch [18], Average Loss: 0.0152
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 92.971 %
# Epoch [19], Average Loss: 0.0122
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.651 %
# Epoch [20], Average Loss: 0.0112
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.681 %
# Epoch [21], Average Loss: 0.0044
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.681 %
# Epoch [22], Average Loss: 0.0511
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 90.761 %
# Epoch [23], Average Loss: 0.1405
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.701 %
# Epoch [24], Average Loss: 0.2045
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 89.581 %
# Epoch [25], Average Loss: 0.2145
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 89.251 %
# Epoch [26], Average Loss: 0.2237
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 90.361 %
# Epoch [27], Average Loss: 0.2269
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 89.521 %
# Epoch [28], Average Loss: 0.2403
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 90.581 %
# Epoch [29], Average Loss: 0.2457
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.371 %
# Epoch [30], Average Loss: 0.2343
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 90.451 %
# Epoch [31], Average Loss: 0.2282
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 89.901 %
# Epoch [32], Average Loss: 0.2435
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 89.531 %
# Epoch [33], Average Loss: 0.2371
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 89.511 %
# Epoch [34], Average Loss: 0.2486
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.141 %
# Epoch [35], Average Loss: 0.2512
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 89.681 %
# Epoch [36], Average Loss: 0.2394
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 91.041 %
# Epoch [37], Average Loss: 0.2245
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 91.021 %
# Epoch [38], Average Loss: 0.2207
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 90.111 %
# Epoch [39], Average Loss: 0.2148
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.241 %
# Epoch [40], Average Loss: 0.2266
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 89.621 %
# Epoch [41], Average Loss: 0.2321
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 89.851 %
# Epoch [42], Average Loss: 0.2392
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 90.451 %
# Epoch [43], Average Loss: 0.2444
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 90.751 %
# Epoch [44], Average Loss: 0.2111
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.861 %
# Epoch [45], Average Loss: 0.2129
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 90.991 %
# Epoch [46], Average Loss: 0.2128
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 90.121 %
# Epoch [47], Average Loss: 0.2397
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 91.001 %
# Epoch [48], Average Loss: 0.2418
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 90.191 %
# Epoch [49], Average Loss: 0.2220
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.291 %
# Epoch [50], Average Loss: 0.2279
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 90.681 %
# Epoch [51], Average Loss: 0.2192
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.501 %
# Epoch [52], Average Loss: 0.2187
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.781 %
# Epoch [53], Average Loss: 0.2413
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 90.831 %
# Epoch [54], Average Loss: 0.2441
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.091 %
# Epoch [55], Average Loss: 0.2372
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 89.661 %
# Epoch [56], Average Loss: 0.2364
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.511 %
# Epoch [57], Average Loss: 0.2555
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 90.761 %
# Epoch [58], Average Loss: 0.2605
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.781 %
# Epoch [59], Average Loss: 0.2307
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.591 %
# Epoch [60], Average Loss: 0.2189
# par_it: 1
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 87.091 %
# Epoch [1], Average Loss: 0.5491
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.311 %
# Epoch [2], Average Loss: 0.2973
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 91.291 %
# Epoch [3], Average Loss: 0.2350
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 90.421 %
# Epoch [4], Average Loss: 0.2122
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.221 %
# Epoch [5], Average Loss: 0.1923
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 92.051 %
# Epoch [6], Average Loss: 0.1769
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.801 %
# Epoch [7], Average Loss: 0.1625
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 91.891 %
# Epoch [8], Average Loss: 0.1426
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 91.921 %
# Epoch [9], Average Loss: 0.1291
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.881 %
# Epoch [10], Average Loss: 0.1145
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.851 %
# Epoch [11], Average Loss: 0.0952
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.481 %
# Epoch [12], Average Loss: 0.0740
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.921 %
# Epoch [13], Average Loss: 0.0516
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.301 %
# Epoch [14], Average Loss: 0.0307
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.401 %
# Epoch [15], Average Loss: 0.0194
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 93.001 %
# Epoch [16], Average Loss: 0.0150
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 93.031 %
# Epoch [17], Average Loss: 0.0112
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 93.071 %
# Epoch [18], Average Loss: 0.0146
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 93.241 %
# Epoch [19], Average Loss: 0.0109
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.721 %
# Epoch [20], Average Loss: 0.0119
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 93.061 %
# Epoch [21], Average Loss: 0.0048
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 92.051 %
# Epoch [22], Average Loss: 0.0472
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 91.041 %
# Epoch [23], Average Loss: 0.1288
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.061 %
# Epoch [24], Average Loss: 0.2077
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 89.851 %
# Epoch [25], Average Loss: 0.2388
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 88.571 %
# Epoch [26], Average Loss: 0.2706
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 89.271 %
# Epoch [27], Average Loss: 0.2605
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 90.351 %
# Epoch [28], Average Loss: 0.2447
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 89.451 %
# Epoch [29], Average Loss: 0.2805
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 90.141 %
# Epoch [30], Average Loss: 0.2709
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 89.101 %
# Epoch [31], Average Loss: 0.2321
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 90.841 %
# Epoch [32], Average Loss: 0.2430
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 90.321 %
# Epoch [33], Average Loss: 0.2407
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 88.881 %
# Epoch [34], Average Loss: 0.2575
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.821 %
# Epoch [35], Average Loss: 0.2321
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 90.021 %
# Epoch [36], Average Loss: 0.2093
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 90.361 %
# Epoch [37], Average Loss: 0.2091
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 90.051 %
# Epoch [38], Average Loss: 0.2259
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 90.961 %
# Epoch [39], Average Loss: 0.2342
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.321 %
# Epoch [40], Average Loss: 0.2447
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.171 %
# Epoch [41], Average Loss: 0.2415
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.151 %
# Epoch [42], Average Loss: 0.2513
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 90.381 %
# Epoch [43], Average Loss: 0.2479
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 90.471 %
# Epoch [44], Average Loss: 0.2270
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 90.751 %
# Epoch [45], Average Loss: 0.2234
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 89.711 %
# Epoch [46], Average Loss: 0.2363
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 90.131 %
# Epoch [47], Average Loss: 0.2530
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 90.161 %
# Epoch [48], Average Loss: 0.2408
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 89.881 %
# Epoch [49], Average Loss: 0.2250
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.321 %
# Epoch [50], Average Loss: 0.2497
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 91.331 %
# Epoch [51], Average Loss: 0.2457
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.731 %
# Epoch [52], Average Loss: 0.2244
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.761 %
# Epoch [53], Average Loss: 0.2131
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 91.991 %
# Epoch [54], Average Loss: 0.2073
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 89.451 %
# Epoch [55], Average Loss: 0.2223
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 90.881 %
# Epoch [56], Average Loss: 0.2368
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.391 %
# Epoch [57], Average Loss: 0.2268
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 90.001 %
# Epoch [58], Average Loss: 0.2314
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.051 %
# Epoch [59], Average Loss: 0.2482
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 91.131 %
# Epoch [60], Average Loss: 0.2313
# par_it: 2
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 86.211 %
# Epoch [1], Average Loss: 0.5645
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.651 %
# Epoch [2], Average Loss: 0.3073
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.721 %
# Epoch [3], Average Loss: 0.2475
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 92.011 %
# Epoch [4], Average Loss: 0.2115
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.921 %
# Epoch [5], Average Loss: 0.2016
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 90.981 %
# Epoch [6], Average Loss: 0.1735
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 92.011 %
# Epoch [7], Average Loss: 0.1551
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 91.701 %
# Epoch [8], Average Loss: 0.1475
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.701 %
# Epoch [9], Average Loss: 0.1288
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 91.701 %
# Epoch [10], Average Loss: 0.1131
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.311 %
# Epoch [11], Average Loss: 0.0937
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.861 %
# Epoch [12], Average Loss: 0.0744
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.931 %
# Epoch [13], Average Loss: 0.0532
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.041 %
# Epoch [14], Average Loss: 0.0338
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.131 %
# Epoch [15], Average Loss: 0.0217
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 93.341 %
# Epoch [16], Average Loss: 0.0158
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.761 %
# Epoch [17], Average Loss: 0.0161
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 92.721 %
# Epoch [18], Average Loss: 0.0091
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 93.021 %
# Epoch [19], Average Loss: 0.0172
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.471 %
# Epoch [20], Average Loss: 0.0106
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.671 %
# Epoch [21], Average Loss: 0.0049
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.911 %
# Epoch [22], Average Loss: 0.0447
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 90.641 %
# Epoch [23], Average Loss: 0.1304
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.471 %
# Epoch [24], Average Loss: 0.2021
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 90.821 %
# Epoch [25], Average Loss: 0.2199
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 90.271 %
# Epoch [26], Average Loss: 0.2207
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 89.051 %
# Epoch [27], Average Loss: 0.2351
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 89.531 %
# Epoch [28], Average Loss: 0.2433
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 89.741 %
# Epoch [29], Average Loss: 0.2420
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.521 %
# Epoch [30], Average Loss: 0.2372
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 90.071 %
# Epoch [31], Average Loss: 0.2164
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 90.601 %
# Epoch [32], Average Loss: 0.2238
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 89.201 %
# Epoch [33], Average Loss: 0.2442
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 88.561 %
# Epoch [34], Average Loss: 0.2650
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.261 %
# Epoch [35], Average Loss: 0.2526
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 89.661 %
# Epoch [36], Average Loss: 0.2451
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 89.441 %
# Epoch [37], Average Loss: 0.2322
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 91.251 %
# Epoch [38], Average Loss: 0.2350
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 90.321 %
# Epoch [39], Average Loss: 0.2338
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.811 %
# Epoch [40], Average Loss: 0.2242
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 89.411 %
# Epoch [41], Average Loss: 0.2249
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.641 %
# Epoch [42], Average Loss: 0.2531
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 89.401 %
# Epoch [43], Average Loss: 0.2564
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 89.321 %
# Epoch [44], Average Loss: 0.2316
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.761 %
# Epoch [45], Average Loss: 0.2579
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 89.401 %
# Epoch [46], Average Loss: 0.2518
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.361 %
# Epoch [47], Average Loss: 0.2554
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 89.741 %
# Epoch [48], Average Loss: 0.2418
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 89.761 %
# Epoch [49], Average Loss: 0.2296
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.061 %
# Epoch [50], Average Loss: 0.2434
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 89.501 %
# Epoch [51], Average Loss: 0.2855
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.631 %
# Epoch [52], Average Loss: 0.2665
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 91.551 %
# Epoch [53], Average Loss: 0.2458
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 90.961 %
# Epoch [54], Average Loss: 0.2223
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.431 %
# Epoch [55], Average Loss: 0.2190
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 90.201 %
# Epoch [56], Average Loss: 0.2290
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.411 %
# Epoch [57], Average Loss: 0.2219
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 91.311 %
# Epoch [58], Average Loss: 0.2287
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.181 %
# Epoch [59], Average Loss: 0.2326
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 91.101 %
# Epoch [60], Average Loss: 0.2128
# par_it: 3
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 85.841 %
# Epoch [1], Average Loss: 0.5453
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 88.801 %
# Epoch [2], Average Loss: 0.3029
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.541 %
# Epoch [3], Average Loss: 0.2484
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 90.951 %
# Epoch [4], Average Loss: 0.2198
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.621 %
# Epoch [5], Average Loss: 0.1977
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 91.801 %
# Epoch [6], Average Loss: 0.1751
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.651 %
# Epoch [7], Average Loss: 0.1557
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 92.911 %
# Epoch [8], Average Loss: 0.1422
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.541 %
# Epoch [9], Average Loss: 0.1264
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.461 %
# Epoch [10], Average Loss: 0.1138
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.451 %
# Epoch [11], Average Loss: 0.0948
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.771 %
# Epoch [12], Average Loss: 0.0726
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.971 %
# Epoch [13], Average Loss: 0.0560
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.301 %
# Epoch [14], Average Loss: 0.0286
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.051 %
# Epoch [15], Average Loss: 0.0206
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 93.081 %
# Epoch [16], Average Loss: 0.0125
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.791 %
# Epoch [17], Average Loss: 0.0166
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 92.931 %
# Epoch [18], Average Loss: 0.0144
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 92.831 %
# Epoch [19], Average Loss: 0.0135
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.531 %
# Epoch [20], Average Loss: 0.0105
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.631 %
# Epoch [21], Average Loss: 0.0058
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 92.101 %
# Epoch [22], Average Loss: 0.0509
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 91.211 %
# Epoch [23], Average Loss: 0.1192
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.121 %
# Epoch [24], Average Loss: 0.1806
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 89.921 %
# Epoch [25], Average Loss: 0.2281
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 89.091 %
# Epoch [26], Average Loss: 0.2781
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 89.201 %
# Epoch [27], Average Loss: 0.2658
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 90.791 %
# Epoch [28], Average Loss: 0.2525
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 89.831 %
# Epoch [29], Average Loss: 0.2331
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.541 %
# Epoch [30], Average Loss: 0.2655
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 89.831 %
# Epoch [31], Average Loss: 0.2668
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 89.771 %
# Epoch [32], Average Loss: 0.2556
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 90.211 %
# Epoch [33], Average Loss: 0.2508
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 90.221 %
# Epoch [34], Average Loss: 0.2250
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 89.551 %
# Epoch [35], Average Loss: 0.2229
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 88.601 %
# Epoch [36], Average Loss: 0.2576
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 89.761 %
# Epoch [37], Average Loss: 0.2523
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 90.951 %
# Epoch [38], Average Loss: 0.2181
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 91.101 %
# Epoch [39], Average Loss: 0.2162
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 89.601 %
# Epoch [40], Average Loss: 0.2454
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.811 %
# Epoch [41], Average Loss: 0.2214
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.461 %
# Epoch [42], Average Loss: 0.2195
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 91.041 %
# Epoch [43], Average Loss: 0.2158
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 88.601 %
# Epoch [44], Average Loss: 0.2408
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.211 %
# Epoch [45], Average Loss: 0.2995
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 89.411 %
# Epoch [46], Average Loss: 0.2825
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.561 %
# Epoch [47], Average Loss: 0.2559
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 89.851 %
# Epoch [48], Average Loss: 0.2583
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 89.541 %
# Epoch [49], Average Loss: 0.2444
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.101 %
# Epoch [50], Average Loss: 0.2461
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 90.041 %
# Epoch [51], Average Loss: 0.2519
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 89.931 %
# Epoch [52], Average Loss: 0.2738
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.421 %
# Epoch [53], Average Loss: 0.2577
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 89.531 %
# Epoch [54], Average Loss: 0.2354
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.141 %
# Epoch [55], Average Loss: 0.2211
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 90.741 %
# Epoch [56], Average Loss: 0.2170
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.431 %
# Epoch [57], Average Loss: 0.2095
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 90.681 %
# Epoch [58], Average Loss: 0.2163
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.891 %
# Epoch [59], Average Loss: 0.2121
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.181 %
# Epoch [60], Average Loss: 0.2056
# par_it: 4
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 87.021 %
# Epoch [1], Average Loss: 0.5405
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.781 %
# Epoch [2], Average Loss: 0.3032
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 89.921 %
# Epoch [3], Average Loss: 0.2497
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 90.831 %
# Epoch [4], Average Loss: 0.2139
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.421 %
# Epoch [5], Average Loss: 0.1967
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 92.291 %
# Epoch [6], Average Loss: 0.1757
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.341 %
# Epoch [7], Average Loss: 0.1606
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 91.681 %
# Epoch [8], Average Loss: 0.1423
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.401 %
# Epoch [9], Average Loss: 0.1319
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.541 %
# Epoch [10], Average Loss: 0.1162
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 91.901 %
# Epoch [11], Average Loss: 0.0919
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.771 %
# Epoch [12], Average Loss: 0.0786
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.621 %
# Epoch [13], Average Loss: 0.0597
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 92.841 %
# Epoch [14], Average Loss: 0.0313
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.161 %
# Epoch [15], Average Loss: 0.0224
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 92.981 %
# Epoch [16], Average Loss: 0.0168
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.751 %
# Epoch [17], Average Loss: 0.0170
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 92.631 %
# Epoch [18], Average Loss: 0.0115
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 93.121 %
# Epoch [19], Average Loss: 0.0171
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.441 %
# Epoch [20], Average Loss: 0.0108
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.851 %
# Epoch [21], Average Loss: 0.0049
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.731 %
# Epoch [22], Average Loss: 0.0554
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 90.461 %
# Epoch [23], Average Loss: 0.1408
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.811 %
# Epoch [24], Average Loss: 0.2093
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 88.511 %
# Epoch [25], Average Loss: 0.2432
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 89.431 %
# Epoch [26], Average Loss: 0.2583
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 90.251 %
# Epoch [27], Average Loss: 0.2433
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 89.891 %
# Epoch [28], Average Loss: 0.2275
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 90.011 %
# Epoch [29], Average Loss: 0.2509
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.301 %
# Epoch [30], Average Loss: 0.2500
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 89.871 %
# Epoch [31], Average Loss: 0.2243
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 90.341 %
# Epoch [32], Average Loss: 0.2294
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 88.711 %
# Epoch [33], Average Loss: 0.2513
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 88.921 %
# Epoch [34], Average Loss: 0.2518
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 89.891 %
# Epoch [35], Average Loss: 0.2634
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 89.641 %
# Epoch [36], Average Loss: 0.2281
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 90.861 %
# Epoch [37], Average Loss: 0.2431
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 89.551 %
# Epoch [38], Average Loss: 0.2691
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 89.251 %
# Epoch [39], Average Loss: 0.2733
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.461 %
# Epoch [40], Average Loss: 0.2246
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.931 %
# Epoch [41], Average Loss: 0.2106
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.481 %
# Epoch [42], Average Loss: 0.1997
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 88.961 %
# Epoch [43], Average Loss: 0.2130
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 90.751 %
# Epoch [44], Average Loss: 0.2221
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 90.251 %
# Epoch [45], Average Loss: 0.2287
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 90.891 %
# Epoch [46], Average Loss: 0.2465
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.731 %
# Epoch [47], Average Loss: 0.2176
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 90.391 %
# Epoch [48], Average Loss: 0.2310
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 90.381 %
# Epoch [49], Average Loss: 0.2287
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 89.961 %
# Epoch [50], Average Loss: 0.2400
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 88.981 %
# Epoch [51], Average Loss: 0.2402
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.191 %
# Epoch [52], Average Loss: 0.2481
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.451 %
# Epoch [53], Average Loss: 0.2314
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 89.651 %
# Epoch [54], Average Loss: 0.2333
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.841 %
# Epoch [55], Average Loss: 0.2376
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 89.481 %
# Epoch [56], Average Loss: 0.2267
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.291 %
# Epoch [57], Average Loss: 0.2366
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 89.871 %
# Epoch [58], Average Loss: 0.2205
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 91.231 %
# Epoch [59], Average Loss: 0.2198
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.291 %
# Epoch [60], Average Loss: 0.2046
# par_it: 5
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 87.191 %
# Epoch [1], Average Loss: 0.5434
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.451 %
# Epoch [2], Average Loss: 0.3075
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.601 %
# Epoch [3], Average Loss: 0.2478
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 90.451 %
# Epoch [4], Average Loss: 0.2110
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.511 %
# Epoch [5], Average Loss: 0.1973
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 91.481 %
# Epoch [6], Average Loss: 0.1758
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.471 %
# Epoch [7], Average Loss: 0.1631
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 91.931 %
# Epoch [8], Average Loss: 0.1409
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 91.921 %
# Epoch [9], Average Loss: 0.1333
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.691 %
# Epoch [10], Average Loss: 0.1156
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.251 %
# Epoch [11], Average Loss: 0.0975
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.581 %
# Epoch [12], Average Loss: 0.0759
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.821 %
# Epoch [13], Average Loss: 0.0543
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.011 %
# Epoch [14], Average Loss: 0.0285
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 92.791 %
# Epoch [15], Average Loss: 0.0231
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 92.921 %
# Epoch [16], Average Loss: 0.0163
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.621 %
# Epoch [17], Average Loss: 0.0133
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 92.921 %
# Epoch [18], Average Loss: 0.0117
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 92.961 %
# Epoch [19], Average Loss: 0.0137
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.671 %
# Epoch [20], Average Loss: 0.0124
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.351 %
# Epoch [21], Average Loss: 0.0043
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.721 %
# Epoch [22], Average Loss: 0.0504
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 91.591 %
# Epoch [23], Average Loss: 0.1283
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 91.171 %
# Epoch [24], Average Loss: 0.2060
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 89.161 %
# Epoch [25], Average Loss: 0.2691
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 89.981 %
# Epoch [26], Average Loss: 0.2845
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 90.441 %
# Epoch [27], Average Loss: 0.2595
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 90.211 %
# Epoch [28], Average Loss: 0.2246
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 90.771 %
# Epoch [29], Average Loss: 0.2082
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.881 %
# Epoch [30], Average Loss: 0.2221
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 90.191 %
# Epoch [31], Average Loss: 0.2353
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 90.841 %
# Epoch [32], Average Loss: 0.2154
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 89.691 %
# Epoch [33], Average Loss: 0.2103
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 90.251 %
# Epoch [34], Average Loss: 0.2172
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 89.021 %
# Epoch [35], Average Loss: 0.2705
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 89.951 %
# Epoch [36], Average Loss: 0.2697
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 90.361 %
# Epoch [37], Average Loss: 0.2550
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 89.981 %
# Epoch [38], Average Loss: 0.2587
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 89.831 %
# Epoch [39], Average Loss: 0.2392
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 89.861 %
# Epoch [40], Average Loss: 0.2242
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.191 %
# Epoch [41], Average Loss: 0.2250
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.801 %
# Epoch [42], Average Loss: 0.2268
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 90.821 %
# Epoch [43], Average Loss: 0.2171
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 91.081 %
# Epoch [44], Average Loss: 0.2116
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.811 %
# Epoch [45], Average Loss: 0.2247
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 89.491 %
# Epoch [46], Average Loss: 0.2356
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.111 %
# Epoch [47], Average Loss: 0.2555
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 90.311 %
# Epoch [48], Average Loss: 0.2526
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 90.301 %
# Epoch [49], Average Loss: 0.2307
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 91.071 %
# Epoch [50], Average Loss: 0.2214
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 90.451 %
# Epoch [51], Average Loss: 0.2219
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 88.941 %
# Epoch [52], Average Loss: 0.2207
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.551 %
# Epoch [53], Average Loss: 0.2186
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 88.661 %
# Epoch [54], Average Loss: 0.2322
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.681 %
# Epoch [55], Average Loss: 0.2498
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 90.711 %
# Epoch [56], Average Loss: 0.2612
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.611 %
# Epoch [57], Average Loss: 0.2507
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 89.371 %
# Epoch [58], Average Loss: 0.2324
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.661 %
# Epoch [59], Average Loss: 0.2204
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 91.361 %
# Epoch [60], Average Loss: 0.2139
# par_it: 6
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 87.691 %
# Epoch [1], Average Loss: 0.4970
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.491 %
# Epoch [2], Average Loss: 0.2808
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.361 %
# Epoch [3], Average Loss: 0.2369
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 90.881 %
# Epoch [4], Average Loss: 0.2102
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.211 %
# Epoch [5], Average Loss: 0.1860
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 92.171 %
# Epoch [6], Average Loss: 0.1717
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.321 %
# Epoch [7], Average Loss: 0.1525
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 92.201 %
# Epoch [8], Average Loss: 0.1452
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.151 %
# Epoch [9], Average Loss: 0.1247
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.611 %
# Epoch [10], Average Loss: 0.1045
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.751 %
# Epoch [11], Average Loss: 0.0940
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.861 %
# Epoch [12], Average Loss: 0.0690
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 93.261 %
# Epoch [13], Average Loss: 0.0442
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.531 %
# Epoch [14], Average Loss: 0.0261
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.251 %
# Epoch [15], Average Loss: 0.0174
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 93.071 %
# Epoch [16], Average Loss: 0.0152
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.661 %
# Epoch [17], Average Loss: 0.0159
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 93.551 %
# Epoch [18], Average Loss: 0.0131
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 93.001 %
# Epoch [19], Average Loss: 0.0091
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.801 %
# Epoch [20], Average Loss: 0.0131
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 93.261 %
# Epoch [21], Average Loss: 0.0042
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 92.171 %
# Epoch [22], Average Loss: 0.0471
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 91.221 %
# Epoch [23], Average Loss: 0.1264
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.171 %
# Epoch [24], Average Loss: 0.2068
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 90.191 %
# Epoch [25], Average Loss: 0.2606
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 89.821 %
# Epoch [26], Average Loss: 0.2536
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 90.261 %
# Epoch [27], Average Loss: 0.2337
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 87.941 %
# Epoch [28], Average Loss: 0.2523
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 89.161 %
# Epoch [29], Average Loss: 0.2669
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 88.181 %
# Epoch [30], Average Loss: 0.2589
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 90.131 %
# Epoch [31], Average Loss: 0.2584
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 90.651 %
# Epoch [32], Average Loss: 0.2338
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 89.561 %
# Epoch [33], Average Loss: 0.2267
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 90.131 %
# Epoch [34], Average Loss: 0.2241
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.371 %
# Epoch [35], Average Loss: 0.2297
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 90.031 %
# Epoch [36], Average Loss: 0.2195
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 91.191 %
# Epoch [37], Average Loss: 0.2319
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 90.231 %
# Epoch [38], Average Loss: 0.2183
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 91.031 %
# Epoch [39], Average Loss: 0.2121
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.631 %
# Epoch [40], Average Loss: 0.2127
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.651 %
# Epoch [41], Average Loss: 0.2211
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 89.441 %
# Epoch [42], Average Loss: 0.2263
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 90.801 %
# Epoch [43], Average Loss: 0.2347
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 90.521 %
# Epoch [44], Average Loss: 0.2150
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 90.341 %
# Epoch [45], Average Loss: 0.2241
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 90.131 %
# Epoch [46], Average Loss: 0.2441
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.721 %
# Epoch [47], Average Loss: 0.2343
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 89.751 %
# Epoch [48], Average Loss: 0.2375
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 91.341 %
# Epoch [49], Average Loss: 0.2239
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.231 %
# Epoch [50], Average Loss: 0.2410
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 90.851 %
# Epoch [51], Average Loss: 0.2534
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.591 %
# Epoch [52], Average Loss: 0.2298
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 91.191 %
# Epoch [53], Average Loss: 0.2274
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 91.141 %
# Epoch [54], Average Loss: 0.2385
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.011 %
# Epoch [55], Average Loss: 0.2562
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 89.011 %
# Epoch [56], Average Loss: 0.2616
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.001 %
# Epoch [57], Average Loss: 0.2491
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 90.741 %
# Epoch [58], Average Loss: 0.2286
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 89.081 %
# Epoch [59], Average Loss: 0.2238
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 89.991 %
# Epoch [60], Average Loss: 0.2219
# par_it: 7
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 86.651 %
# Epoch [1], Average Loss: 0.5347
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.881 %
# Epoch [2], Average Loss: 0.3027
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.531 %
# Epoch [3], Average Loss: 0.2385
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 91.221 %
# Epoch [4], Average Loss: 0.2120
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.161 %
# Epoch [5], Average Loss: 0.1916
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 92.031 %
# Epoch [6], Average Loss: 0.1741
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 92.391 %
# Epoch [7], Average Loss: 0.1545
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 92.001 %
# Epoch [8], Average Loss: 0.1420
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.011 %
# Epoch [9], Average Loss: 0.1260
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.571 %
# Epoch [10], Average Loss: 0.1004
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 93.101 %
# Epoch [11], Average Loss: 0.0902
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.541 %
# Epoch [12], Average Loss: 0.0690
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.541 %
# Epoch [13], Average Loss: 0.0507
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.031 %
# Epoch [14], Average Loss: 0.0261
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.041 %
# Epoch [15], Average Loss: 0.0193
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 92.741 %
# Epoch [16], Average Loss: 0.0158
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 93.011 %
# Epoch [17], Average Loss: 0.0137
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 93.171 %
# Epoch [18], Average Loss: 0.0105
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 93.111 %
# Epoch [19], Average Loss: 0.0126
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.701 %
# Epoch [20], Average Loss: 0.0139
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.811 %
# Epoch [21], Average Loss: 0.0047
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.321 %
# Epoch [22], Average Loss: 0.0512
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 91.961 %
# Epoch [23], Average Loss: 0.1260
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 91.261 %
# Epoch [24], Average Loss: 0.1611
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 89.291 %
# Epoch [25], Average Loss: 0.2168
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 90.391 %
# Epoch [26], Average Loss: 0.2609
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 89.621 %
# Epoch [27], Average Loss: 0.2630
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 90.311 %
# Epoch [28], Average Loss: 0.2428
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 89.491 %
# Epoch [29], Average Loss: 0.2450
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 90.071 %
# Epoch [30], Average Loss: 0.2277
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 90.361 %
# Epoch [31], Average Loss: 0.2269
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 91.261 %
# Epoch [32], Average Loss: 0.2241
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 89.501 %
# Epoch [33], Average Loss: 0.2537
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 88.851 %
# Epoch [34], Average Loss: 0.2807
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.331 %
# Epoch [35], Average Loss: 0.2774
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 89.851 %
# Epoch [36], Average Loss: 0.2481
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 90.131 %
# Epoch [37], Average Loss: 0.2390
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 89.461 %
# Epoch [38], Average Loss: 0.2360
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 90.281 %
# Epoch [39], Average Loss: 0.2207
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.731 %
# Epoch [40], Average Loss: 0.2088
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.391 %
# Epoch [41], Average Loss: 0.2156
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 89.661 %
# Epoch [42], Average Loss: 0.2176
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 90.291 %
# Epoch [43], Average Loss: 0.2309
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 89.911 %
# Epoch [44], Average Loss: 0.2196
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.921 %
# Epoch [45], Average Loss: 0.2217
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 89.421 %
# Epoch [46], Average Loss: 0.2484
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 90.761 %
# Epoch [47], Average Loss: 0.2593
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 90.381 %
# Epoch [48], Average Loss: 0.2587
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 91.121 %
# Epoch [49], Average Loss: 0.2647
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.671 %
# Epoch [50], Average Loss: 0.2374
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 89.931 %
# Epoch [51], Average Loss: 0.2342
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.201 %
# Epoch [52], Average Loss: 0.2467
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.221 %
# Epoch [53], Average Loss: 0.2492
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 90.701 %
# Epoch [54], Average Loss: 0.2376
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 89.151 %
# Epoch [55], Average Loss: 0.2623
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 89.861 %
# Epoch [56], Average Loss: 0.2498
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.561 %
# Epoch [57], Average Loss: 0.2514
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 89.861 %
# Epoch [58], Average Loss: 0.2349
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.821 %
# Epoch [59], Average Loss: 0.2262
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.681 %
# Epoch [60], Average Loss: 0.2010
# par_it: 8
#
# Epoch [1/60], Step [300/300]
# ...
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.781 %
# Epoch [21], Average Loss: 0.0037
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.921 %
# Epoch [22], Average Loss: 0.0439
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 90.931 %
# Epoch [23], Average Loss: 0.1244
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.551 %
# Epoch [24], Average Loss: 0.1695
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 88.021 %
# Epoch [25], Average Loss: 0.2253
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 88.681 %
# Epoch [26], Average Loss: 0.2505
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 89.841 %
# Epoch [27], Average Loss: 0.2486
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 90.221 %
# Epoch [28], Average Loss: 0.2492
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 90.321 %
# Epoch [29], Average Loss: 0.2729
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.781 %
# Epoch [30], Average Loss: 0.2511
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 89.971 %
# Epoch [31], Average Loss: 0.2336
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 90.161 %
# Epoch [32], Average Loss: 0.2162
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 90.501 %
# Epoch [33], Average Loss: 0.2294
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 90.461 %
# Epoch [34], Average Loss: 0.2370
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.401 %
# Epoch [35], Average Loss: 0.2308
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 90.791 %
# Epoch [36], Average Loss: 0.2153
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 90.451 %
# Epoch [37], Average Loss: 0.2157
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 90.201 %
# Epoch [38], Average Loss: 0.2315
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 89.421 %
# Epoch [39], Average Loss: 0.2415
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.781 %
# Epoch [40], Average Loss: 0.2419
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.081 %
# Epoch [41], Average Loss: 0.2543
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.291 %
# Epoch [42], Average Loss: 0.2520
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 90.041 %
# Epoch [43], Average Loss: 0.2581
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 90.351 %
# Epoch [44], Average Loss: 0.2501
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.571 %
# Epoch [45], Average Loss: 0.2318
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 90.421 %
# Epoch [46], Average Loss: 0.2286
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.681 %
# Epoch [47], Average Loss: 0.2479
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 90.591 %
# Epoch [48], Average Loss: 0.2317
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 90.661 %
# Epoch [49], Average Loss: 0.2137
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 90.901 %
# Epoch [50], Average Loss: 0.2026
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 89.821 %
# Epoch [51], Average Loss: 0.2089
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 89.951 %
# Epoch [52], Average Loss: 0.2375
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 89.981 %
# Epoch [53], Average Loss: 0.2483
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 90.691 %
# Epoch [54], Average Loss: 0.2434
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 91.161 %
# Epoch [55], Average Loss: 0.2457
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 89.941 %
# Epoch [56], Average Loss: 0.2463
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 89.571 %
# Epoch [57], Average Loss: 0.2505
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 89.011 %
# Epoch [58], Average Loss: 0.2375
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.311 %
# Epoch [59], Average Loss: 0.2439
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.401 %
# Epoch [60], Average Loss: 0.2237
# par_it: 62
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 86.211 %
# Epoch [1], Average Loss: 0.5450
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 88.591 %
# Epoch [2], Average Loss: 0.3070
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 90.701 %
# Epoch [3], Average Loss: 0.2500
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 91.211 %
# Epoch [4], Average Loss: 0.2235
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 91.481 %
# Epoch [5], Average Loss: 0.1934
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 91.171 %
# Epoch [6], Average Loss: 0.1781
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.771 %
# Epoch [7], Average Loss: 0.1689
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 91.791 %
# Epoch [8], Average Loss: 0.1515
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.281 %
# Epoch [9], Average Loss: 0.1319
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 92.601 %
# Epoch [10], Average Loss: 0.1126
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.281 %
# Epoch [11], Average Loss: 0.1024
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 92.631 %
# Epoch [12], Average Loss: 0.0800
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.841 %
# Epoch [13], Average Loss: 0.0597
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.121 %
# Epoch [14], Average Loss: 0.0335
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.131 %
# Epoch [15], Average Loss: 0.0217
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 92.641 %
# Epoch [16], Average Loss: 0.0188
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.861 %
# Epoch [17], Average Loss: 0.0159
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 92.801 %
# Epoch [18], Average Loss: 0.0122
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 92.711 %
# Epoch [19], Average Loss: 0.0128
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.381 %
# Epoch [20], Average Loss: 0.0124
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.771 %
# Epoch [21], Average Loss: 0.0055
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.891 %
# Epoch [22], Average Loss: 0.0504
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 90.661 %
# Epoch [23], Average Loss: 0.1310
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.331 %
# Epoch [24], Average Loss: 0.1659
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 90.491 %
# Epoch [25], Average Loss: 0.2109
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 90.131 %
# Epoch [26], Average Loss: 0.2135
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 88.021 %
# Epoch [27], Average Loss: 0.2802
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 89.201 %
# Epoch [28], Average Loss: 0.2899
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 90.631 %
# Epoch [29], Average Loss: 0.2774
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 90.601 %
# Epoch [30], Average Loss: 0.2580
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 89.641 %
# Epoch [31], Average Loss: 0.2612
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 89.861 %
# Epoch [32], Average Loss: 0.2588
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 91.221 %
# Epoch [33], Average Loss: 0.2383
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 91.151 %
# Epoch [34], Average Loss: 0.2265
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 90.001 %
# Epoch [35], Average Loss: 0.2452
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 89.431 %
# Epoch [36], Average Loss: 0.2462
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 88.131 %
# Epoch [37], Average Loss: 0.2515
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 89.701 %
# Epoch [38], Average Loss: 0.2303
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 90.501 %
# Epoch [39], Average Loss: 0.2323
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.701 %
# Epoch [40], Average Loss: 0.2409
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 89.821 %
# Epoch [41], Average Loss: 0.2297
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 91.081 %
# Epoch [42], Average Loss: 0.2072
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 91.231 %
# Epoch [43], Average Loss: 0.1906
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 90.051 %
# Epoch [44], Average Loss: 0.1855
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 90.981 %
# Epoch [45], Average Loss: 0.2111
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 90.261 %
# Epoch [46], Average Loss: 0.2024
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 89.571 %
# Epoch [47], Average Loss: 0.2090
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 89.281 %
# Epoch [48], Average Loss: 0.2494
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 88.701 %
# Epoch [49], Average Loss: 0.2756
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 89.171 %
# Epoch [50], Average Loss: 0.2664
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 91.041 %
# Epoch [51], Average Loss: 0.2270
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 90.271 %
# Epoch [52], Average Loss: 0.2233
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 91.001 %
# Epoch [53], Average Loss: 0.2142
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 90.771 %
# Epoch [54], Average Loss: 0.2040
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.661 %
# Epoch [55], Average Loss: 0.2052
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 90.301 %
# Epoch [56], Average Loss: 0.2099
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 91.351 %
# Epoch [57], Average Loss: 0.2417
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 88.921 %
# Epoch [58], Average Loss: 0.2450
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 90.161 %
# Epoch [59], Average Loss: 0.2217
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.991 %
# Epoch [60], Average Loss: 0.2107
# par_it: 63
#
# Epoch [1/60], Step [300/300]
# Test accuracy of the model: 85.211 %
# Epoch [1], Average Loss: 0.5362
# Epoch [2/60], Step [300/300]
# Test accuracy of the model: 89.181 %
# Epoch [2], Average Loss: 0.3045
# Epoch [3/60], Step [300/300]
# Test accuracy of the model: 89.351 %
# Epoch [3], Average Loss: 0.2491
# Epoch [4/60], Step [300/300]
# Test accuracy of the model: 91.631 %
# Epoch [4], Average Loss: 0.2181
# Epoch [5/60], Step [300/300]
# Test accuracy of the model: 90.911 %
# Epoch [5], Average Loss: 0.1994
# Epoch [6/60], Step [300/300]
# Test accuracy of the model: 91.251 %
# Epoch [6], Average Loss: 0.1777
# Epoch [7/60], Step [300/300]
# Test accuracy of the model: 91.951 %
# Epoch [7], Average Loss: 0.1601
# Epoch [8/60], Step [300/300]
# Test accuracy of the model: 92.521 %
# Epoch [8], Average Loss: 0.1478
# Epoch [9/60], Step [300/300]
# Test accuracy of the model: 92.521 %
# Epoch [9], Average Loss: 0.1339
# Epoch [10/60], Step [300/300]
# Test accuracy of the model: 91.641 %
# Epoch [10], Average Loss: 0.1179
# Epoch [11/60], Step [300/300]
# Test accuracy of the model: 92.191 %
# Epoch [11], Average Loss: 0.0975
# Epoch [12/60], Step [300/300]
# Test accuracy of the model: 93.091 %
# Epoch [12], Average Loss: 0.0776
# Epoch [13/60], Step [300/300]
# Test accuracy of the model: 92.881 %
# Epoch [13], Average Loss: 0.0564
# Epoch [14/60], Step [300/300]
# Test accuracy of the model: 93.201 %
# Epoch [14], Average Loss: 0.0321
# Epoch [15/60], Step [300/300]
# Test accuracy of the model: 93.031 %
# Epoch [15], Average Loss: 0.0250
# Epoch [16/60], Step [300/300]
# Test accuracy of the model: 92.791 %
# Epoch [16], Average Loss: 0.0174
# Epoch [17/60], Step [300/300]
# Test accuracy of the model: 92.921 %
# Epoch [17], Average Loss: 0.0167
# Epoch [18/60], Step [300/300]
# Test accuracy of the model: 93.381 %
# Epoch [18], Average Loss: 0.0126
# Epoch [19/60], Step [300/300]
# Test accuracy of the model: 93.221 %
# Epoch [19], Average Loss: 0.0125
# Epoch [20/60], Step [300/300]
# Test accuracy of the model: 93.621 %
# Epoch [20], Average Loss: 0.0140
# Epoch [21/60], Step [300/300]
# Test accuracy of the model: 92.761 %
# Epoch [21], Average Loss: 0.0055
# Epoch [22/60], Step [300/300]
# Test accuracy of the model: 91.851 %
# Epoch [22], Average Loss: 0.0521
# Epoch [23/60], Step [300/300]
# Test accuracy of the model: 91.221 %
# Epoch [23], Average Loss: 0.1325
# Epoch [24/60], Step [300/300]
# Test accuracy of the model: 90.021 %
# Epoch [24], Average Loss: 0.2014
# Epoch [25/60], Step [300/300]
# Test accuracy of the model: 88.621 %
# Epoch [25], Average Loss: 0.2768
# Epoch [26/60], Step [300/300]
# Test accuracy of the model: 88.741 %
# Epoch [26], Average Loss: 0.2628
# Epoch [27/60], Step [300/300]
# Test accuracy of the model: 89.381 %
# Epoch [27], Average Loss: 0.2694
# Epoch [28/60], Step [300/300]
# Test accuracy of the model: 90.151 %
# Epoch [28], Average Loss: 0.2630
# Epoch [29/60], Step [300/300]
# Test accuracy of the model: 90.291 %
# Epoch [29], Average Loss: 0.2228
# Epoch [30/60], Step [300/300]
# Test accuracy of the model: 89.511 %
# Epoch [30], Average Loss: 0.2299
# Epoch [31/60], Step [300/300]
# Test accuracy of the model: 89.961 %
# Epoch [31], Average Loss: 0.2378
# Epoch [32/60], Step [300/300]
# Test accuracy of the model: 91.151 %
# Epoch [32], Average Loss: 0.2256
# Epoch [33/60], Step [300/300]
# Test accuracy of the model: 89.451 %
# Epoch [33], Average Loss: 0.2261
# Epoch [34/60], Step [300/300]
# Test accuracy of the model: 89.391 %
# Epoch [34], Average Loss: 0.2500
# Epoch [35/60], Step [300/300]
# Test accuracy of the model: 89.311 %
# Epoch [35], Average Loss: 0.2357
# Epoch [36/60], Step [300/300]
# Test accuracy of the model: 90.191 %
# Epoch [36], Average Loss: 0.2354
# Epoch [37/60], Step [300/300]
# Test accuracy of the model: 89.951 %
# Epoch [37], Average Loss: 0.2297
# Epoch [38/60], Step [300/300]
# Test accuracy of the model: 89.881 %
# Epoch [38], Average Loss: 0.2346
# Epoch [39/60], Step [300/300]
# Test accuracy of the model: 90.731 %
# Epoch [39], Average Loss: 0.2213
# Epoch [40/60], Step [300/300]
# Test accuracy of the model: 90.541 %
# Epoch [40], Average Loss: 0.2041
# Epoch [41/60], Step [300/300]
# Test accuracy of the model: 90.991 %
# Epoch [41], Average Loss: 0.1970
# Epoch [42/60], Step [300/300]
# Test accuracy of the model: 90.501 %
# Epoch [42], Average Loss: 0.2051
# Epoch [43/60], Step [300/300]
# Test accuracy of the model: 89.891 %
# Epoch [43], Average Loss: 0.2162
# Epoch [44/60], Step [300/300]
# Test accuracy of the model: 89.861 %
# Epoch [44], Average Loss: 0.2586
# Epoch [45/60], Step [300/300]
# Test accuracy of the model: 89.431 %
# Epoch [45], Average Loss: 0.2250
# Epoch [46/60], Step [300/300]
# Test accuracy of the model: 90.461 %
# Epoch [46], Average Loss: 0.2263
# Epoch [47/60], Step [300/300]
# Test accuracy of the model: 90.001 %
# Epoch [47], Average Loss: 0.2242
# Epoch [48/60], Step [300/300]
# Test accuracy of the model: 89.821 %
# Epoch [48], Average Loss: 0.2496
# Epoch [49/60], Step [300/300]
# Test accuracy of the model: 90.601 %
# Epoch [49], Average Loss: 0.2454
# Epoch [50/60], Step [300/300]
# Test accuracy of the model: 89.711 %
# Epoch [50], Average Loss: 0.2392
# Epoch [51/60], Step [300/300]
# Test accuracy of the model: 90.601 %
# Epoch [51], Average Loss: 0.2226
# Epoch [52/60], Step [300/300]
# Test accuracy of the model: 88.421 %
# Epoch [52], Average Loss: 0.2360
# Epoch [53/60], Step [300/300]
# Test accuracy of the model: 90.001 %
# Epoch [53], Average Loss: 0.2467
# Epoch [54/60], Step [300/300]
# Test accuracy of the model: 90.181 %
# Epoch [54], Average Loss: 0.2432
# Epoch [55/60], Step [300/300]
# Test accuracy of the model: 90.921 %
# Epoch [55], Average Loss: 0.2168
# Epoch [56/60], Step [300/300]
# Test accuracy of the model: 91.111 %
# Epoch [56], Average Loss: 0.2304
# Epoch [57/60], Step [300/300]
# Test accuracy of the model: 90.601 %
# Epoch [57], Average Loss: 0.2369
# Epoch [58/60], Step [300/300]
# Test accuracy of the model: 91.471 %
# Epoch [58], Average Loss: 0.2328
# Epoch [59/60], Step [300/300]
# Test accuracy of the model: 89.541 %
# Epoch [59], Average Loss: 0.2293
# Epoch [60/60], Step [300/300]
# Test accuracy of the model: 90.201 %
# Epoch [60], Average Loss: 0.2291

# %%
n=0
for par in net.parameters():
    n+=par.numel()
n
# Out:
# 1265258

# %%
net_star_backup=copy.deepcopy(net_star)

# %%
# #net_star=Fashion_MNIST_CNN().cuda()
# #net_star=net
# net_star=copy.deepcopy(net_star_backup)
# net_star.train()
# with torch.no_grad():
#     for par in net_star.parameters():
#         par+=(torch.rand_like(par)*2-1)*6/torch.sqrt(l2regconst_extra)

# len_params=len(list(net_star.parameters()))
# list_no_bias=torch.zeros(len_params)
# it=0
# for name, p in net_star.named_parameters():
#     if 'bias' not in name:
#         list_no_bias[it]=1.0
#     it+=1

# # def grad_vec(vec):   
# #     net_star_copy=copy.deepcopy(net_star)
# #     for it in range(len_params):
# #         list(net_star_copy.parameters())[it]=vec[it]
# #         list(net_star_copy.parameters())[it].requires_grad=True
# #     out=net_star_copy(images)
# #     loss=loss_function(out,labels)*train_data_len    
# #     net_star_copy.zero_grad()
# #     loss.backward()
# #     grad=[p.grad for p in net_star_copy.parameters()]
# #     # pars = list(net_star_copy.parameters())
# #     # out=net_star_copy(images)
# #     # loss=loss_function(out,labels)*train_data_len    
# #     # net_star_copy.zero_grad()
# #     # grad=list(torch.autograd.grad(loss,pars,create_graph=False))
# #     # with torch.no_grad():
# #     #     for it in range(len_params):
# #     #         if(list_no_bias[it]):
# #     #             grad[it]+=vec[it]*l2regconst
# #     return(grad)

# # def grad_vec_full(vec):
# #     gradfull=copy.deepcopy(list(vec))
# #     for p in gradfull:
# #         p.requires_grad=False
# #         p*=0
# #     len_pars=len(list(vec))
# #     for it in range(no_batches):
# #         images=images_list[it]
# #         labels=labels_list[it]
# #         grad=grad_vec(vec)
# #         for pit in range(len_pars):
# #             gradfull[pit]+=grad[pit]
# #     return(gradfull)

# def hess_vec(vec,images,labels):   
#     out=net_star(images)
#     loss=loss_function(out,labels)*batch_size
#     net_star.zero_grad()
#     grad=list(torch.autograd.grad(loss,list(net_star.parameters()),create_graph=True))
#     res=torch.zeros(1).cuda()
#     for it in range(len_params):
#         res+=(grad[it]*vec[it]).sum()
#     net_star.zero_grad()
#     hvp=list(torch.autograd.grad(res,list(net_star.parameters()),create_graph=False))

#     return(hvp)
    
#     # hvp_with_prior=copy.deepcopy(hvp)
#     # l2regnewconst=torch.tensor(1e3)
#     # for p,v in zip(hvp_with_prior,vec):
#     #     p+=l2regnewconst*v
#     # return(hvp_with_prior)
# def hess_vec_full(vec):
#     hvfull=copy.deepcopy(list(vec))
#     for p in hvfull:
#         p.requires_grad=False
#         p*=0
#     len_pars=len(hvfull)
#     for it in range(no_batches):
#         images=images_list[it]
#         labels=labels_list[it]
#         hv=hess_vec(vec,images,labels)
#         for pit in range(len_pars):
#             hvfull[pit]+=hv[pit]
#     for pit in range(len_pars):
#         hvfull[pit]+=list(vec)[pit]*l2regconst_extra
#         if(list_no_bias[pit]):
#             hvfull[pit]+=list(vec)[pit]*l2regconst
#     return(hvfull)

# def norm_par(vec):
#     n=torch.zeros(1).detach().cuda()
#     for p in vec:
#         n+=p.pow(2).sum()
#     return n.sqrt()

# def multiply_par(vec,c):
#     res_vec=copy.deepcopy(vec)
#     for it in range(len_params):
#         res_vec[it].requires_grad=False
#         res_vec[it]=res_vec[it]*c
#     return res_vec

# def scalar_prod_par(vec1,vec2):
#     res=torch.zeros(1).cuda()
#     for it in range(len_params):
#         res+=(vec1[it]*vec2[it]).sum()
#     return res

# def add_par(vec1,vec2):
#     res_vec=copy.deepcopy(vec1)
#     for it in range(len_params):
#         res_vec[it].requires_grad=False
#         res_vec[it]=vec1[it]+vec2[it]
#     return res_vec

# # print(norm_par(list(net_star.parameters())))
# # print(norm_par(multiply_par(list(net_star.parameters()),0.1)))

# vec=copy.deepcopy(list(net_star.parameters()))
# for p in vec:
#     p.requires_grad=False
# norm_iter=norm_par(vec)
# vec=multiply_par(vec,torch.Tensor(1/norm_iter))
# for iter in range(10):
#     vec=hess_vec_full(vec)
#     norm_iter=norm_par(vec)
#     vec=multiply_par(vec,1/norm_iter)    
#     print(norm_iter)

# max_eigen_vec=copy.deepcopy(vec)
# max_eigen=norm_iter

# vec=copy.deepcopy(list(net_star.parameters()))
# for p in vec:
#     p.requires_grad=False
# vec=add_par(vec,multiply_par(max_eigen_vec,-scalar_prod_par(vec,max_eigen_vec)))
# norm_iter=norm_par(vec)
# vec=multiply_par(vec,torch.Tensor(1/norm_iter))

# for iter in range(10):
#     vec=hess_vec_full(vec)
#     vec=add_par(vec,multiply_par(max_eigen_vec,-scalar_prod_par(vec,max_eigen_vec)))
#     norm_iter=norm_par(vec)
#     vec=multiply_par(vec,1/norm_iter)    
#     print(norm_iter)

# %%
#filepath="output_fashion.pickle"
#with open(filepath,"rb") as file:
#    [labels_arr,test_labels_arr,test_prob_arr,_,_]=pickle.load(file)
#labels_arr=torch.tensor(labels_arr).detach()
#test_labels_arr=torch.tensor(test_labels_arr).detach()
#test_prob_arr=torch.tensor(test_prob_arr).detach()

# %%
# Outcome should be a binary list of the ordinal outcome. [0, 1, 0] for exmaple.
# Probs should be a list of probabilities. [0.79, 0.09, 0.12] for example.
# Outcome and Probs must be provided with the same order as probabilities.

def rps_single(probs, true_label):
    outcome=torch.zeros(num_classes)
    outcome[true_label.int()]=1.0
    cum_probs = torch.cumsum(probs,0)
    cum_outcomes = torch.cumsum(outcome,0)
    
    #print(cum_outcomes)
    #print(cum_probs)
    sum_rps = 0
    for i in range(len(outcome)):         
        sum_rps+= (cum_probs[i] - cum_outcomes[i])**2
    
    return sum_rps/(num_classes-1)

def rps_calc(test_probs, true_labels):
    rps_vec=torch.zeros(test_data_len)
    for it in range(test_data_len):
        rps_vec[it]=rps_single(test_probs[it,:].reshape(num_classes),true_labels[it])
    return rps_vec

def nll_calc(test_probs, true_labels):
    res=0
    for it in range(test_data_len):
        res-=torch.max(torch.tensor([torch.log(test_probs[it,true_labels[it].int()]),-100]))
    return res/test_data_len

def adaptive_calibration_error(test_probs,true_labels, num_bins=20):
    max_probs, predicted_labels = torch.max(test_probs,1)
    ind=torch.argsort(max_probs,stable=True)
    sorted_max_probs=max_probs[ind]
    sorted_predicted_labels=predicted_labels[ind]
    sorted_true_labels=true_labels[ind]

    correct = (sorted_predicted_labels == sorted_true_labels).clone().detach().float()
    bins=(torch.tensor(range(test_data_len))/torch.tensor(test_data_len/num_bins)).floor()

    o=torch.tensor(0.0)
    for b in range(num_bins):
        mask = (bins == b)
        if torch.any(mask):
            #print(b, sorted_max_probs[mask].mean(), (correct[mask] - sorted_max_probs[mask]).mean())
            o += (correct[mask] - sorted_max_probs[mask]).mean().abs()

    return o / num_bins

# %%
def GRdiagnostics(res):
  J=res.shape[0] #Number of chains
  L=res.shape[1] #Number of samples after burnin
  res_means=res.mean(dim=1)
  res_mean=res_means.mean()
  B=(res_means-res_mean).pow(2).sum()*L/(J-1)
  W=(res_means.reshape([J,1])@torch.ones([1,L])-res).pow(2).sum()/(J*(L-1))
  R=(W*(L-1)/L+B/L)/W
  return R


par_chains=4
no_GR_epochs=40
test_prob_GR_arr=torch.zeros([test_size,num_classes])
nll_GR_arr=torch.zeros([par_chains,no_GR_epochs])
for chain in range(par_chains):
    net=copy.deepcopy(net_star)
    with torch.no_grad():
      for par in net.parameters():
        par+=(torch.randn_like(par))/torch.sqrt(torch.tensor(4))
        par.v = torch.randn_like(par,device=device)
    for par in list(net.parameters()):
      par.v = torch.randn_like(par,device=device)          
    for epoch in range(no_GR_epochs):
      print("chain: ",chain, "/epoch:",epoch)
      # if(epoch % 2 == 1):
      #   irange=range(no_batches-1,-1,-1)
      # else:
      #   irange=range(no_batches)
      # for b in irange:
      #   images=images_list[b]
      #   labels=labels_list[b]
      for it in range(batch_size):
        b=torch.randint(high=no_batches,size=(1,1))        
        EM_step(net, h, gam,b)

      for testit in range(test_no_batches):
        imagest=test_images_list[testit]
        labelst=test_labels_list[testit]
        actual_batch_size=len(imagest)
        outputt = net(imagest).detach()
        test_prob_GR_arr[(testit*batch_size):(testit*batch_size+actual_batch_size),:]=torch.softmax(outputt,dim=1)
      
      nll_GR_arr[chain,epoch]=nll_calc(test_prob_GR_arr,test_labels_arr)
      print("NLL:", nll_GR_arr[chain,epoch])

print(GRdiagnostics(nll_GR_arr))
# Out:
# chain:  0 /epoch: 0
# NLL: tensor(2.2595)
# chain:  0 /epoch: 1
# NLL: tensor(3.2714)
# chain:  0 /epoch: 2
# NLL: tensor(3.9557)
# chain:  0 /epoch: 3
# NLL: tensor(4.4849)
# chain:  0 /epoch: 4
# NLL: tensor(4.3363)
# chain:  0 /epoch: 5
# NLL: tensor(3.9835)
# chain:  0 /epoch: 6
# NLL: tensor(5.3242)
# chain:  0 /epoch: 7
# NLL: tensor(3.3267)
# chain:  0 /epoch: 8
# NLL: tensor(3.2231)
# chain:  0 /epoch: 9
# NLL: tensor(3.9681)
# chain:  0 /epoch: 10
# NLL: tensor(4.1702)
# chain:  0 /epoch: 11
# NLL: tensor(3.9891)
# chain:  0 /epoch: 12
# NLL: tensor(3.8212)
# chain:  0 /epoch: 13
# NLL: tensor(3.0601)
# chain:  0 /epoch: 14
# NLL: tensor(3.1426)
# chain:  0 /epoch: 15
# NLL: tensor(3.3896)
# chain:  0 /epoch: 16
# NLL: tensor(2.3290)
# chain:  0 /epoch: 17
# NLL: tensor(2.2624)
# chain:  0 /epoch: 18
# NLL: tensor(2.2708)
# chain:  0 /epoch: 19
# NLL: tensor(2.3081)
# chain:  0 /epoch: 20
# NLL: tensor(2.4802)
# chain:  0 /epoch: 21
# NLL: tensor(2.0481)
# chain:  0 /epoch: 22
# NLL: tensor(2.8352)
# chain:  0 /epoch: 23
# NLL: tensor(1.2631)
# chain:  0 /epoch: 24
# NLL: tensor(1.7498)
# chain:  0 /epoch: 25
# NLL: tensor(1.8773)
# chain:  0 /epoch: 26
# NLL: tensor(2.0787)
# chain:  0 /epoch: 27
# NLL: tensor(1.3866)
# chain:  0 /epoch: 28
# NLL: tensor(1.7951)
# chain:  0 /epoch: 29
# NLL: tensor(1.9715)
# chain:  0 /epoch: 30
# NLL: tensor(1.4960)
# chain:  0 /epoch: 31
# NLL: tensor(1.4432)
# chain:  0 /epoch: 32
# NLL: tensor(1.3559)
# chain:  0 /epoch: 33
# NLL: tensor(1.0706)
# chain:  0 /epoch: 34
# NLL: tensor(1.2767)
# chain:  0 /epoch: 35
# NLL: tensor(0.9627)
# chain:  0 /epoch: 36
# NLL: tensor(0.8846)
# chain:  0 /epoch: 37
# NLL: tensor(0.7295)
# chain:  0 /epoch: 38
# NLL: tensor(0.9705)
# chain:  0 /epoch: 39
# NLL: tensor(0.8341)
# chain:  1 /epoch: 0
# NLL: tensor(3.0244)
# chain:  1 /epoch: 1
# NLL: tensor(2.6602)
# chain:  1 /epoch: 2
# NLL: tensor(2.5847)
# chain:  1 /epoch: 3
# NLL: tensor(4.3128)
# chain:  1 /epoch: 4
# NLL: tensor(2.5851)
# chain:  1 /epoch: 5
# NLL: tensor(3.4841)
# chain:  1 /epoch: 6
# NLL: tensor(3.8051)
# chain:  1 /epoch: 7
# NLL: tensor(2.5049)
# chain:  1 /epoch: 8
# NLL: tensor(3.5613)
# chain:  1 /epoch: 9
# NLL: tensor(2.1949)
# chain:  1 /epoch: 10
# NLL: tensor(3.3139)
# chain:  1 /epoch: 11
# NLL: tensor(2.5876)
# chain:  1 /epoch: 12
# NLL: tensor(3.2394)
# chain:  1 /epoch: 13
# NLL: tensor(4.5318)
# chain:  1 /epoch: 14
# NLL: tensor(3.5766)
# chain:  1 /epoch: 15
# NLL: tensor(3.1888)
# chain:  1 /epoch: 16
# NLL: tensor(4.3713)
# chain:  1 /epoch: 17
# NLL: tensor(2.8663)
# chain:  1 /epoch: 18
# NLL: tensor(2.2237)
# chain:  1 /epoch: 19
# NLL: tensor(2.5123)
# chain:  1 /epoch: 20
# NLL: tensor(3.8485)
# chain:  1 /epoch: 21
# NLL: tensor(2.2496)
# chain:  1 /epoch: 22
# NLL: tensor(2.7039)
# chain:  1 /epoch: 23
# NLL: tensor(2.3614)
# chain:  1 /epoch: 24
# NLL: tensor(2.4608)
# chain:  1 /epoch: 25
# NLL: tensor(2.2187)
# chain:  1 /epoch: 26
# NLL: tensor(3.0769)
# chain:  1 /epoch: 27
# NLL: tensor(2.3321)
# chain:  1 /epoch: 28
# NLL: tensor(1.4790)
# chain:  1 /epoch: 29
# NLL: tensor(1.6183)
# chain:  1 /epoch: 30
# NLL: tensor(1.3305)
# chain:  1 /epoch: 31
# NLL: tensor(1.5968)
# chain:  1 /epoch: 32
# NLL: tensor(1.6335)
# chain:  1 /epoch: 33
# NLL: tensor(1.4992)
# chain:  1 /epoch: 34
# NLL: tensor(1.1181)
# chain:  1 /epoch: 35
# NLL: tensor(1.3941)
# chain:  1 /epoch: 36
# NLL: tensor(1.2567)
# chain:  1 /epoch: 37
# NLL: tensor(0.9019)
# chain:  1 /epoch: 38
# NLL: tensor(1.2231)
# chain:  1 /epoch: 39
# NLL: tensor(1.1333)
# chain:  2 /epoch: 0
# NLL: tensor(3.7972)
# chain:  2 /epoch: 1
# NLL: tensor(3.1783)
# chain:  2 /epoch: 2
# NLL: tensor(2.5586)
# chain:  2 /epoch: 3
# NLL: tensor(3.0296)
# chain:  2 /epoch: 4
# NLL: tensor(3.9712)
# chain:  2 /epoch: 5
# NLL: tensor(4.6029)
# chain:  2 /epoch: 6
# NLL: tensor(3.8362)
# chain:  2 /epoch: 7
# NLL: tensor(3.1221)
# chain:  2 /epoch: 8
# NLL: tensor(2.8825)
# chain:  2 /epoch: 9
# NLL: tensor(2.1752)
# chain:  2 /epoch: 10
# NLL: tensor(2.6916)
# chain:  2 /epoch: 11
# NLL: tensor(3.1300)
# chain:  2 /epoch: 12
# NLL: tensor(3.4627)
# chain:  2 /epoch: 13
# NLL: tensor(3.1782)
# chain:  2 /epoch: 14
# NLL: tensor(2.7097)
# chain:  2 /epoch: 15
# NLL: tensor(3.1702)
# chain:  2 /epoch: 16
# NLL: tensor(3.2982)
# chain:  2 /epoch: 17
# NLL: tensor(2.3495)
# chain:  2 /epoch: 18
# NLL: tensor(2.5310)
# chain:  2 /epoch: 19
# NLL: tensor(1.6033)
# chain:  2 /epoch: 20
# NLL: tensor(1.5633)
# chain:  2 /epoch: 21
# NLL: tensor(2.0903)
# chain:  2 /epoch: 22
# NLL: tensor(1.3033)
# chain:  2 /epoch: 23
# NLL: tensor(1.7152)
# chain:  2 /epoch: 24
# NLL: tensor(1.8731)
# chain:  2 /epoch: 25
# NLL: tensor(1.5995)
# chain:  2 /epoch: 26
# NLL: tensor(0.9769)
# chain:  2 /epoch: 27
# NLL: tensor(1.1010)
# chain:  2 /epoch: 28
# NLL: tensor(0.9465)
# chain:  2 /epoch: 29
# NLL: tensor(1.2614)
# chain:  2 /epoch: 30
# NLL: tensor(1.2520)
# chain:  2 /epoch: 31
# NLL: tensor(0.9305)
# chain:  2 /epoch: 32
# NLL: tensor(1.0409)
# chain:  2 /epoch: 33
# NLL: tensor(1.0862)
# chain:  2 /epoch: 34
# NLL: tensor(0.8888)
# chain:  2 /epoch: 35
# NLL: tensor(1.3237)
# chain:  2 /epoch: 36
# NLL: tensor(1.2156)
# chain:  2 /epoch: 37
# NLL: tensor(0.7908)
# chain:  2 /epoch: 38
# NLL: tensor(0.9998)
# chain:  2 /epoch: 39
# NLL: tensor(1.0794)
# chain:  3 /epoch: 0
# NLL: tensor(2.7038)
# chain:  3 /epoch: 1
# NLL: tensor(3.3194)
# chain:  3 /epoch: 2
# NLL: tensor(4.7407)
# chain:  3 /epoch: 3
# NLL: tensor(2.6679)
# chain:  3 /epoch: 4
# NLL: tensor(3.4489)
# chain:  3 /epoch: 5
# NLL: tensor(2.9107)
# chain:  3 /epoch: 6
# NLL: tensor(4.9856)
# chain:  3 /epoch: 7
# NLL: tensor(5.8802)
# chain:  3 /epoch: 8
# NLL: tensor(4.0264)
# chain:  3 /epoch: 9
# NLL: tensor(6.0857)
# chain:  3 /epoch: 10
# NLL: tensor(6.4822)
# chain:  3 /epoch: 11
# NLL: tensor(5.3467)
# chain:  3 /epoch: 12
# NLL: tensor(5.8792)
# chain:  3 /epoch: 13
# NLL: tensor(5.2028)
# chain:  3 /epoch: 14
# NLL: tensor(4.1737)
# chain:  3 /epoch: 15
# NLL: tensor(5.3439)
# chain:  3 /epoch: 16
# NLL: tensor(6.6933)
# chain:  3 /epoch: 17
# NLL: tensor(4.3260)
# chain:  3 /epoch: 18
# NLL: tensor(4.1736)
# chain:  3 /epoch: 19
# NLL: tensor(3.7093)
# chain:  3 /epoch: 20
# NLL: tensor(4.6511)
# chain:  3 /epoch: 21
# NLL: tensor(2.4176)
# chain:  3 /epoch: 22
# NLL: tensor(3.2772)
# chain:  3 /epoch: 23
# NLL: tensor(3.1944)
# chain:  3 /epoch: 24
# NLL: tensor(7.4010)
# chain:  3 /epoch: 25
# NLL: tensor(5.0834)
# chain:  3 /epoch: 26
# NLL: tensor(4.3290)
# chain:  3 /epoch: 27
# NLL: tensor(3.6636)
# chain:  3 /epoch: 28
# NLL: tensor(2.5372)
# chain:  3 /epoch: 29
# NLL: tensor(4.4767)
# chain:  3 /epoch: 30
# NLL: tensor(5.3153)
# chain:  3 /epoch: 31
# NLL: tensor(5.4003)
# chain:  3 /epoch: 32
# NLL: tensor(6.3988)
# chain:  3 /epoch: 33
# NLL: tensor(4.2790)
# chain:  3 /epoch: 34
# NLL: tensor(3.3705)
# chain:  3 /epoch: 35
# NLL: tensor(3.6141)
# chain:  3 /epoch: 36
# NLL: tensor(2.6335)
# chain:  3 /epoch: 37
# NLL: tensor(2.3689)
# chain:  3 /epoch: 38
# NLL: tensor(3.0333)
# chain:  3 /epoch: 39
# NLL: tensor(1.9777)
# tensor(1.6629)

# %%
print(GRdiagnostics(nll_GR_arr[:,10:40]))
# Out:
# tensor(2.1597)

# %%
#test_prob=torch.Tensor(test_prob_arr[:,:,29,0]).reshape(test_size,num_classes)
#torch.cumsum(test_prob[1,:].reshape(num_classes),0)
#rps_single(test_prob[1,:].reshape(num_classes),test_labels_arr[1])

# %%
#no bayesian
par_runs=64
def compute_acc_ace_rps_no_bayes(es):
    copies=int(par_runs/es)
    ace_arr=torch.zeros(copies)
    rps_arr=torch.zeros(copies)
    nll_arr=torch.zeros(copies)
    accuracy_arr=torch.zeros(copies)

    for it in range(copies):
        test_prob=torch.Tensor(test_prob_arr[:,:,14,it*es:(it+1)*es]).mean(-1).reshape(test_size,num_classes)
        ace_arr[it]=adaptive_calibration_error(test_prob,test_labels_arr)
        rps_arr[it]=(rps_calc(test_prob, test_labels_arr)).mean()
        nll_arr[it]=nll_calc(test_prob, test_labels_arr)
        _, predictedt = torch.max(test_prob,1)
        accuracy_arr[it]= (predictedt==test_labels_arr.reshape(1,test_size)).sum()/test_size
    print("Non-Bayesian, ensemble size:", es)
    print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
    print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
    print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
    print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
    return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

acc=torch.zeros(5)
acc_std=torch.zeros(5)
ace=torch.zeros(5)
ace_std=torch.zeros(5)
rps=torch.zeros(5)
rps_std=torch.zeros(5)
nll=torch.zeros(5)
nll_std=torch.zeros(5)
[acc[0],acc_std[0],ace[0],ace_std[0],rps[0],rps_std[0],nll[0],nll_std[0]]=compute_acc_ace_rps_no_bayes(1)
[acc[1],acc_std[1],ace[1],ace_std[1],rps[1],rps_std[1],nll[1],nll_std[1]]=compute_acc_ace_rps_no_bayes(2)
[acc[2],acc_std[2],ace[2],ace_std[2],rps[2],rps_std[2],nll[2],nll_std[2]]=compute_acc_ace_rps_no_bayes(4)
[acc[3],acc_std[3],ace[3],ace_std[3],rps[3],rps_std[3],nll[3],nll_std[3]]=compute_acc_ace_rps_no_bayes(8)
[acc[4],acc_std[4],ace[4],ace_std[4],rps[4],rps_std[4],nll[4],nll_std[4]]=compute_acc_ace_rps_no_bayes(16)

from scipy.io import savemat
filepath="results_fashion_no_bayes_SG_HMC.mat"
mdic={"acc":acc.cpu().numpy(),"acc_std":acc_std.cpu().numpy(),"nll": nll.cpu().numpy(),"nll_std":nll_std.cpu().numpy(),\
      "ace": ace.cpu().numpy(),"ace_std":ace_std.cpu().numpy(), "rps":rps.cpu().numpy(),"rps_std":rps_std.cpu().numpy()}
savemat(filepath,mdic)
# Out:
# Non-Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9304) std: tensor(0.0022)
# mean ace: tensor(0.0468) std: tensor(0.0023)
# mean nll: tensor(0.3279) std: tensor(0.0180)
# mean rps: tensor(0.0217) std: tensor(0.0006)
# Non-Bayesian, ensemble size: 2
# mean accuracy: tensor(0.9392) std: tensor(0.0017)
# mean ace: tensor(0.0223) std: tensor(0.0023)
# mean nll: tensor(0.2338) std: tensor(0.0086)
# mean rps: tensor(0.0180) std: tensor(0.0004)
# Non-Bayesian, ensemble size: 4
# mean accuracy: tensor(0.9438) std: tensor(0.0014)
# mean ace: tensor(0.0125) std: tensor(0.0014)
# mean nll: tensor(0.1914) std: tensor(0.0061)
# mean rps: tensor(0.0162) std: tensor(0.0004)
# Non-Bayesian, ensemble size: 8
# mean accuracy: tensor(0.9462) std: tensor(0.0012)
# mean ace: tensor(0.0087) std: tensor(0.0006)
# mean nll: tensor(0.1706) std: tensor(0.0044)
# mean rps: tensor(0.0153) std: tensor(0.0003)
# Non-Bayesian, ensemble size: 16
# mean accuracy: tensor(0.9478) std: tensor(0.0007)
# mean ace: tensor(0.0063) std: tensor(0.0008)
# mean nll: tensor(0.1602) std: tensor(0.0028)
# mean rps: tensor(0.0148) std: tensor(0.0002)

# %% [markdown]
# Non-Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9296) std: tensor(0.0020)
# mean ace: tensor(0.0555) std: tensor(0.0018)
# mean nll: tensor(0.4709) std: tensor(0.0251)
# mean rps: tensor(0.0230) std: tensor(0.0008)
# Non-Bayesian, ensemble size: 2
# mean accuracy: tensor(0.9383) std: tensor(0.0015)
# mean ace: tensor(0.0294) std: tensor(0.0016)
# mean nll: tensor(0.3109) std: tensor(0.0127)
# mean rps: tensor(0.0188) std: tensor(0.0005)
# Non-Bayesian, ensemble size: 4
# mean accuracy: tensor(0.9422) std: tensor(0.0010)
# mean ace: tensor(0.0177) std: tensor(0.0011)
# mean nll: tensor(0.2385) std: tensor(0.0066)
# mean rps: tensor(0.0168) std: tensor(0.0003)
# Non-Bayesian, ensemble size: 8
# mean accuracy: tensor(0.9443) std: tensor(0.0006)
# mean ace: tensor(0.0126) std: tensor(0.0007)
# mean nll: tensor(0.2025) std: tensor(0.0042)
# mean rps: tensor(0.0157) std: tensor(0.0002)
# Non-Bayesian, ensemble size: 16
# mean accuracy: tensor(0.9459) std: tensor(0.0009)
# mean ace: tensor(0.0098) std: tensor(0.0007)
# mean nll: tensor(0.1832) std: tensor(0.0029)
# mean rps: tensor(0.0152) std: tensor(8.2395e-05)

# %%
#swa
def compute_acc_ace_rps_swa(es):
    copies=int(par_runs/es)
    ace_arr=torch.zeros(copies)
    rps_arr=torch.zeros(copies)
    nll_arr=torch.zeros(copies)
    accuracy_arr=torch.zeros(copies)

    for it in range(copies):
        test_prob=torch.Tensor(test_prob_arr[:,:,19,it*es:(it+1)*es]).mean(-1).reshape(test_size,num_classes)
        ace_arr[it]=adaptive_calibration_error(test_prob,test_labels_arr)
        rps_arr[it]=(rps_calc(test_prob, test_labels_arr)).mean()
        nll_arr[it]=nll_calc(test_prob, test_labels_arr)
        _, predictedt = torch.max(test_prob,1)
        accuracy_arr[it]= (predictedt==test_labels_arr.reshape(1,test_size)).sum()/test_size
    print("SWA, ensemble size:", es)
    print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
    print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
    print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
    print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
    return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

acc=torch.zeros(5)
acc_std=torch.zeros(5)
ace=torch.zeros(5)
ace_std=torch.zeros(5)
rps=torch.zeros(5)
rps_std=torch.zeros(5)
nll=torch.zeros(5)
nll_std=torch.zeros(5)
[acc[0],acc_std[0],ace[0],ace_std[0],rps[0],rps_std[0],nll[0],nll_std[0]]=compute_acc_ace_rps_swa(1)
[acc[1],acc_std[1],ace[1],ace_std[1],rps[1],rps_std[1],nll[1],nll_std[1]]=compute_acc_ace_rps_swa(2)
[acc[2],acc_std[2],ace[2],ace_std[2],rps[2],rps_std[2],nll[2],nll_std[2]]=compute_acc_ace_rps_swa(4)
[acc[3],acc_std[3],ace[3],ace_std[3],rps[3],rps_std[3],nll[3],nll_std[3]]=compute_acc_ace_rps_swa(8)
[acc[4],acc_std[4],ace[4],ace_std[4],rps[4],rps_std[4],nll[4],nll_std[4]]=compute_acc_ace_rps_swa(16)

from scipy.io import savemat
filepath="results_fashion_swa_SG_HMC.mat"
mdic={"acc":acc.cpu().numpy(),"acc_std":acc_std.cpu().numpy(),"nll": nll.cpu().numpy(),"nll_std":nll_std.cpu().numpy(),\
      "ace": ace.cpu().numpy(),"ace_std":ace_std.cpu().numpy(), "rps":rps.cpu().numpy(),"rps_std":rps_std.cpu().numpy()}
savemat(filepath,mdic)
# Out:
# SWA, ensemble size: 1
# mean accuracy: tensor(0.9356) std: tensor(0.0015)
# mean ace: tensor(0.0459) std: tensor(0.0016)
# mean nll: tensor(0.3383) std: tensor(0.0126)
# mean rps: tensor(0.0207) std: tensor(0.0005)
# SWA, ensemble size: 2
# mean accuracy: tensor(0.9420) std: tensor(0.0013)
# mean ace: tensor(0.0256) std: tensor(0.0013)
# mean nll: tensor(0.2467) std: tensor(0.0063)
# mean rps: tensor(0.0176) std: tensor(0.0003)
# SWA, ensemble size: 4
# mean accuracy: tensor(0.9453) std: tensor(0.0011)
# mean ace: tensor(0.0174) std: tensor(0.0010)
# mean nll: tensor(0.2038) std: tensor(0.0049)
# mean rps: tensor(0.0160) std: tensor(0.0002)
# SWA, ensemble size: 8
# mean accuracy: tensor(0.9474) std: tensor(0.0009)
# mean ace: tensor(0.0132) std: tensor(0.0008)
# mean nll: tensor(0.1816) std: tensor(0.0026)
# mean rps: tensor(0.0152) std: tensor(0.0001)
# SWA, ensemble size: 16
# mean accuracy: tensor(0.9489) std: tensor(0.0005)
# mean ace: tensor(0.0107) std: tensor(0.0004)
# mean nll: tensor(0.1700) std: tensor(0.0020)
# mean rps: tensor(0.0148) std: tensor(0.0001)

# %% [markdown]
# SWA, ensemble size: 1
# mean accuracy: tensor(0.9337) std: tensor(0.0016)
# mean ace: tensor(0.0537) std: tensor(0.0016)
# mean nll: tensor(0.4826) std: tensor(0.0191)
# mean rps: tensor(0.0220) std: tensor(0.0006)
# SWA, ensemble size: 2
# mean accuracy: tensor(0.9403) std: tensor(0.0012)
# mean ace: tensor(0.0309) std: tensor(0.0012)
# mean nll: tensor(0.3312) std: tensor(0.0111)
# mean rps: tensor(0.0184) std: tensor(0.0004)
# SWA, ensemble size: 4
# mean accuracy: tensor(0.9435) std: tensor(0.0011)
# mean ace: tensor(0.0223) std: tensor(0.0010)
# mean nll: tensor(0.2579) std: tensor(0.0078)
# mean rps: tensor(0.0166) std: tensor(0.0003)
# SWA, ensemble size: 8
# mean accuracy: tensor(0.9453) std: tensor(0.0008)
# mean ace: tensor(0.0180) std: tensor(0.0011)
# mean nll: tensor(0.2186) std: tensor(0.0036)
# mean rps: tensor(0.0157) std: tensor(0.0002)
# SWA, ensemble size: 16
# mean accuracy: tensor(0.9462) std: tensor(0.0008)
# mean ace: tensor(0.0158) std: tensor(0.0009)
# mean nll: tensor(0.1964) std: tensor(0.0034)
# mean rps: tensor(0.0153) std: tensor(5.5335e-05)

# %%
#Bayesian
def compute_acc_ace_rps_bayes(es):
    copies=int(par_runs/es)
    ace_arr=torch.zeros(copies)
    rps_arr=torch.zeros(copies)
    nll_arr=torch.zeros(copies)
    accuracy_arr=torch.zeros(copies)

    for it in range(copies):
        test_prob=torch.Tensor(test_prob_arr[:,:,30:60,it*es:(it+1)*es]).mean(-1).mean(-1).reshape(test_size,num_classes)
        ace_arr[it]=adaptive_calibration_error(test_prob,test_labels_arr)
        rps_arr[it]=(rps_calc(test_prob, test_labels_arr)).mean()
        nll_arr[it]=nll_calc(test_prob, test_labels_arr)
        _, predictedt = torch.max(test_prob,1)
        accuracy_arr[it]= (predictedt==test_labels_arr.reshape(1,test_size)).sum()/test_size
    print("Bayesian, ensemble size:", es)
    print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
    print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
    print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
    print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
    return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]



acc=torch.zeros(5)
acc_std=torch.zeros(5)
ace=torch.zeros(5)
ace_std=torch.zeros(5)
rps=torch.zeros(5)
rps_std=torch.zeros(5)
nll=torch.zeros(5)
nll_std=torch.zeros(5)
[acc[0],acc_std[0],ace[0],ace_std[0],rps[0],rps_std[0],nll[0],nll_std[0]]=compute_acc_ace_rps_bayes(1)
[acc[1],acc_std[1],ace[1],ace_std[1],rps[1],rps_std[1],nll[1],nll_std[1]]=compute_acc_ace_rps_bayes(2)
[acc[2],acc_std[2],ace[2],ace_std[2],rps[2],rps_std[2],nll[2],nll_std[2]]=compute_acc_ace_rps_bayes(4)
[acc[3],acc_std[3],ace[3],ace_std[3],rps[3],rps_std[3],nll[3],nll_std[3]]=compute_acc_ace_rps_bayes(8)
[acc[4],acc_std[4],ace[4],ace_std[4],rps[4],rps_std[4],nll[4],nll_std[4]]=compute_acc_ace_rps_bayes(16)

from scipy.io import savemat
filepath="results_fashion_bayes_SG_HMC.mat"
mdic={"acc":acc.cpu().numpy(),"acc_std":acc_std.cpu().numpy(),"nll": nll.cpu().numpy(),"nll_std":nll_std.cpu().numpy(),\
      "ace": ace.cpu().numpy(),"ace_std":ace_std.cpu().numpy(), "rps":rps.cpu().numpy(),"rps_std":rps_std.cpu().numpy()}
savemat(filepath,mdic)
# Out:
# Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9312) std: tensor(0.0015)
# mean ace: tensor(0.0166) std: tensor(0.0021)
# mean nll: tensor(0.1955) std: tensor(0.0025)
# mean rps: tensor(0.0189) std: tensor(0.0002)
# Bayesian, ensemble size: 2
# mean accuracy: tensor(0.9345) std: tensor(0.0010)
# mean ace: tensor(0.0217) std: tensor(0.0017)
# mean nll: tensor(0.1883) std: tensor(0.0014)
# mean rps: tensor(0.0183) std: tensor(0.0001)
# Bayesian, ensemble size: 4
# mean accuracy: tensor(0.9360) std: tensor(0.0008)
# mean ace: tensor(0.0242) std: tensor(0.0012)
# mean nll: tensor(0.1850) std: tensor(0.0009)
# mean rps: tensor(0.0180) std: tensor(9.6171e-05)
# Bayesian, ensemble size: 8
# mean accuracy: tensor(0.9365) std: tensor(0.0007)
# mean ace: tensor(0.0252) std: tensor(0.0009)
# mean nll: tensor(0.1833) std: tensor(0.0006)
# mean rps: tensor(0.0178) std: tensor(6.9177e-05)
# Bayesian, ensemble size: 16
# mean accuracy: tensor(0.9373) std: tensor(0.0010)
# mean ace: tensor(0.0262) std: tensor(0.0013)
# mean nll: tensor(0.1825) std: tensor(0.0005)
# mean rps: tensor(0.0177) std: tensor(6.2021e-05)

# %% [markdown]
# Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9358) std: tensor(nan)
# mean ace: tensor(0.0123) std: tensor(nan)
# mean nll: tensor(0.2039) std: tensor(nan)
# mean rps: tensor(0.0177) std: tensor(nan)
#
# Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9400) std: tensor(nan)
# mean ace: tensor(0.0072) std: tensor(nan)
# mean nll: tensor(0.1876) std: tensor(nan)
# mean rps: tensor(0.0169) std: tensor(nan)

# %%
# test_prob=torch.Tensor(test_prob_arr[:,7,0]).reshape(test_size,1)
# ace=adaptive_calibration_error(test_labels_arr.reshape(test_size,1).numpy(),test_prob.numpy(),20)
# ace

# %%
# test_prob=torch.Tensor(test_prob_arr[:,10:16,48:64]).mean(-1).mean(-1).reshape(test_size,1)
# ace=adaptive_calibration_error(test_labels_arr.reshape(test_size,1).numpy(),test_prob.numpy(),20)
# ace

# %%
import torchvision
from torchview import draw_graph
net2 = Fashion_MNIST_CNN()

#model_graph = draw_graph(net2, input_size=(1,3,64,64), expand_nested=True)
model_graph = draw_graph(net2, input_size=(1,1,28,28), expand_nested=True)
model_graph.visual_graph
# Out:
# Warning: Could not load "C:\Users\Daniel Paulin\.conda\envs\torchenv39\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: no hard-coded metrics for 'Linux libertine'.  Falling back to 'Times' metrics
