# %%
#@title Import Dependencies

import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import itertools
import pickle
import numpy as np
from numpy import random
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from tqdm import tqdm
from PIL import Image
from matplotlib import pyplot as plt
import matplotlib
from typing import TypeVar, Dict

import torch
import torch.nn as nn
from torch.optim.optimizer import Optimizer

Tensor = TypeVar('torch.tensor')

#matplotlib.use('Agg')

import click
from argparse import Namespace
import ast
import os

import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F
from typing import TypeVar, Tuple
import gdown
import copy
# Out:
# no display found. Using non-interactive Agg backend

# %%
#@title Define Hyperparameters

# class_names = ["5_o_Clock_Shadow", "Arched_Eyebrows", "Attractive", "Bags_Under_Eyes", "Bald", "Bangs",
#                 "Big_Lips", "Big_Nose", "Black_Hair", "Blond_Hair", "Blurry", "Brown_Hair", "Bushy_Eyebrows",
#                 "Chubby", "Double_Chin", "Eyeglasses", "Goatee", "Gray_Hair", "Heavy_Makeup", "High_Cheekbones",
#                 "Male", "Mouth_Slightly_Open", "Mustache", "Narrow_Eyes", "No_Beard", "Oval_Face", "Pale_Skin",
#                 "Pointy_Nose", "Receding_Hairline", "Rosy_Cheeks", "Sideburns", "Smiling", "Straight_Hair",
#                 "Wavy_Hair", "Wearing_Earrings", "Wearing_Hat", "Wearing_Lipstick", "Wearing_Necklace",
#                 "Wearing_Necktie", "Young"]
# num_classes = 40
# data_shape = [3, 64, 64]
# n_bits = 5
# temp = 0.7
# data_mean = [0.485, 0.456, 0.406]
# data_std = [0.229, 0.224, 0.225]

input_size = 28*28*1 # img_size = (28,28) ---> 28*28=784 in total
batch_size = 200 # the size of input data took for one iteration

# %%
# from torchvision.transforms import v2
# transform_RandomErasing=transforms.Compose([v2.RandomErasing(),
#                               transforms.ToTensor()])

transform=transforms.Compose([transforms.ToTensor()])

train_data = dsets.FashionMNIST(root = './data', train=True, transform = transform, download = True)
test_data = dsets.FashionMNIST(root = './data', train=False, transform = transform, download = True)

# %%
#@title Loading the data

train_gen = torch.utils.data.DataLoader(dataset = train_data,
                                             batch_size = batch_size,
                                             shuffle = True)

test_gen = torch.utils.data.DataLoader(dataset = test_data,
                                      batch_size = batch_size,
                                      shuffle = False)

# %%
#cvmx=torch.zeros([3*64*64,3*64*64],device=device)
images_list=[]
labels_list=[]
no_batches=len(train_gen)
#images_mean=torch.zeros(3,64,64,device=device)
for i ,(images,labels) in enumerate(train_gen):
    images = Variable(images).cuda().detach()
    labels=Variable(labels).cuda().detach()
    # images_mean=images_mean+images.mean(0)
    # im=torch.reshape(images,[images.shape[0],3*64*64])
    # cvmx+=torch.matmul(torch.transpose(im,0,1),im)
    if(i<(len(train_gen))):
        images_list.append(images)
        labels_list.append(labels)



test_images_list=[]
test_labels_list=[]
test_no_batches=len(test_gen)
for i ,(images,labels) in enumerate(test_gen):
    images = Variable(images).cuda().detach()
    labels=Variable(labels).cuda().detach()
    if(i<(len(test_gen))):
        test_images_list.append(images)
        test_labels_list.append(labels)

train_data_len=len(train_data)
test_data_len=len(test_data)

# %%
#@title Define model class
import torch.nn as nn
import torch
import torch.nn.functional as F

from typing import TypeVar, Tuple

Tensor = TypeVar('torch.tensor')



class NeuralNet(torch.nn.Module):
    """
    base class for all NN classifiers
    """
    def __init__(self):
        super().__init__()

    def initialize_weights(self):
        for m in self.modules():
            if isinstance(m, torch.nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    torch.nn.init.constant_(m.bias, 0)
            elif isinstance(m, torch.nn.BatchNorm2d):
                torch.nn.init.constant_(m.weight, 1)
                torch.nn.init.constant_(m.bias, 0)
            elif isinstance(m, torch.nn.Linear):
                torch.nn.init.normal_(m.weight, 0, 0.01)
                torch.nn.init.constant_(m.bias, 0)

class CNN(NeuralNet):
    """
    CNN for (binary) classification for CelebA, CheXpert
    """

    def __init__(self,
                 in_channels: int = 3,
                 num_classes: int = 2,
                 flattened_size: int = 16384,
                 low_rank: int = 32,
                 batch_norm_mom: float = 1.0):
        """CNN Builder."""
        super(CNN, self).__init__()

        self.conv_layer = nn.Sequential(

            # Conv Layer block 1
            nn.Conv2d(in_channels=in_channels, out_channels=32, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(32,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.BatchNorm2d(64,momentum=batch_norm_mom),

            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(64,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(128,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.MaxPool2d(kernel_size=2, stride=2),
            #nn.BatchNorm2d(128),

            # nn.BatchNorm2d(128),
            # nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            # nn.Softplus(beta=1.0),
            # nn.MaxPool2d(kernel_size=2, stride=2),
            # nn.BatchNorm2d(128),

            # # Conv Layer block 2
            # nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            # nn.BatchNorm2d(128),
            # nn.Softplus(beta=1.0),
            # nn.BatchNorm2d(128),
            # nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            # nn.Softplus(beta=1.0),
            # nn.MaxPool2d(kernel_size=2, stride=2),
            # nn.BatchNorm2d(128),

            # Conv Layer block 3
            nn.BatchNorm2d(128,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.BatchNorm2d(256,momentum=batch_norm_mom),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.Softplus(beta=1.0),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.fc_layer = nn.Sequential(
            #nn.Dropout(p=0.1),
            nn.BatchNorm1d(flattened_size,momentum=batch_norm_mom),
#            nn.Linear(flattened_size, 512),
            nn.Linear(flattened_size, low_rank),
            nn.BatchNorm1d(low_rank,momentum=batch_norm_mom),
            nn.Linear(low_rank,512),            
            nn.Softplus(beta=1.0),
            nn.BatchNorm1d(512,momentum=batch_norm_mom),
            # nn.Linear(2048, 512),
            # nn.Softplus(beta=1.0),
            # nn.BatchNorm1d(512),
            # nn.Linear(1024, 512),
            # nn.Softplus(beta=1.0), 
            # nn.BatchNorm1d(512),
            #nn.Dropout(p=0.1),
        )

        self.last_layer=nn.Sequential(
            nn.Linear(512, num_classes)
        )

    def forward(self, x: Tensor) -> Tensor:
        """Perform forward."""

        # conv layers
        x = self.conv_layer(x)

        # flatten
        x = x.view(x.size(0), -1)

        # # # fc layer
        x = self.fc_layer(x)

        x=self.last_layer(x)

        return x

    def classify(self, x: Tensor) -> Tuple[Tensor, Tensor, Tensor]:
        net_out = self.forward(x)
        acc = F.softmax(net_out, dim=1)
        class_idx = torch.max(net_out, 1)[1]

        return acc, acc[0, class_idx], class_idx
    




class CelebA_CNN(CNN):
    """CNN."""

    def __init__(self,
                 in_channels: int = 3,
                 num_classes: int = 2,
                 #num_classes: int = 1,
                 flattened_size: int = 16384):
        """CNN Builder."""
        super(CelebA_CNN, self).__init__(in_channels=in_channels, num_classes=num_classes,
                                         flattened_size=flattened_size)

class Fashion_MNIST_CNN(CNN):
    """CNN."""

    def __init__(self,
                 in_channels: int = 1,
                 num_classes: int = 10,
                 #flattened_size: int = 6272,
                 flattened_size: int = 2304,
                 low_rank: int = 64,
                 batch_norm_mom: float = 1.0):
        """CNN Builder."""
        super(Fashion_MNIST_CNN, self).__init__(in_channels=in_channels, num_classes=num_classes,
                                         flattened_size=flattened_size)




class CheXpert_CNN(CNN):
    def __init__(self,
                 in_channels: int = 1,
                 num_classes: int = 2,
                 flattened_size: int = 65536):
        """CNN Builder."""
        super(CheXpert_CNN, self).__init__(in_channels=in_channels, num_classes=num_classes,
                                           flattened_size=flattened_size)


class Net(nn.Module):
  def __init__(self, input_size, hidden_size, num_classes):
    super(Net,self).__init__()
    self.fc1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(hidden_size, num_classes)

  def forward(self,x):
    out = self.fc1(x)
    out = self.relu(out)
    out = self.fc2(out)
    return out

# %%
# net=Fashion_MNIST_CNN()
# n=0
# for par in net.parameters():
#     n+=par.numel()

# n

# %%
#@title Define loss-function & optimizer
loss_function = nn.CrossEntropyLoss()


def images_regulariser(): 
    li_reg_loss = 0
    penalized     = [p for name,p in net.named_parameters() if 'bias' not in name]
    not_penalized = [p for name,p in net.named_parameters() if 'bias' in name]
    for p in penalized:
        li_reg_loss += (p**2).sum()*0.5
    #for p in net.parameters():
#        li_reg_loss += (p**2).sum()*0.5
    reg=li_reg_loss/(train_data_len)*l2regconst
    return(reg)

# %%
def addnet(net,net2):
    for param1, param2 in zip(net.parameters(), net2.parameters()):
     param1.data += param2.data

def multiplynet(net,a):
   for param1 in net.parameters():
     param1.data *=a

# %%
from dataclasses import dataclass
@dataclass
class hclass:
    h: Tensor
    eta: Tensor
    etam1g: Tensor
    c11: Tensor
    c21: Tensor
    c22: Tensor

def hper2const(h,gam):
    gh=gam.double()*h.double()
    s=torch.sqrt(4*torch.expm1(-gh/2)-torch.expm1(-gh)+gh)
    eta=(torch.exp(-gh/2)).float()
    etam1g=((-torch.expm1(-gh/2))/gam.double()).float()
    c11=(s/gam).float()
    c21=(torch.exp(-gh)*(torch.expm1(gh/2.0))**2/s).float()
    c22=(torch.sqrt(8*torch.expm1(-gh/2)-4*torch.expm1(-gh)-gh*torch.expm1(-gh))/s).float()
    hc=hclass(h=h,eta=eta,etam1g=etam1g,c11=c11,c21=c21,c22=c22)
    return(hc)

def U(x,v,hc):
    xi1=torch.randn(x.size(),device=device)
    xi2=torch.randn(x.size(),device=device)

    xn=x+hc.etam1g*v+hc.c11*xi1
    vn=v*hc.eta+hc.c21*xi1+hc.c22*xi2
    return([xn, vn])

def bounce(x,v,xstar,width):
    vsign=(((x-xstar+width)/(2*width)).floor()% 2)*(-2)+1
    vn=v*vsign
    xn=((x-xstar-width)% (4*width)-2*width).abs()-width+xstar
    # num_outside=((xn-xstar)>width).sum()+((xstar-xn)>width).sum()
    # if(num_outside>0):
    #     print(num_outside)    
    return([xn, vn])

def bouncenet(net):
    for p,p_star in zip(net.parameters(),net_star.parameters()):
        [p.data, p.v]=bounce(p.data, p.v, p_star.data, 6/torch.sqrt(l2regconst_extra))

def UBU_step(net,hper2c,images,labels,batch_it):   
    with torch.no_grad():
        for p in list(net.parameters()):
            # maxlen=20*torch.sqrt((torch.tensor(torch.numel(p.v))).float())
            # if(torch.norm(p.v)>maxlen):
            #    print("big trouble!!!!")    
            [p.data,p.v]=U(p.data,p.v,hper2c)

        bouncenet(net)
    #print("outputsU",len(outputsU))
    #print("labelsU",len(labels))
    #print("imagesU",len(images))
    outputsU = net(images)
    loss_likelihood = loss_function(outputsU, labels)  


    grads_reg=[torch.zeros_like(par) for par in net.parameters()]
    net_pars=list(net.parameters())
    with torch.no_grad():
        for it in range(len_params):
            if(list_no_bias[it]):
                grads_reg[it]=net_pars[it].data*l2regconst

    net.zero_grad()
    #loss.backward()
    loss_likelihood.backward()
    with torch.no_grad():
        grads_likelihood=[par.grad*batch_size for par in net.parameters()]
    
        #Normal, no variance reduction
        # for p,p_star in zip(net.parameters(),net_star.parameters()):      
        #     p.v-=hper2c.h*(p.grad*train_data_len+l2regconst_extra*(p.data-p_star.data))

        for p,grad,grad_reg,p_star,grad_star,star_sum_grad in zip(list(net.parameters()),grads_likelihood,grads_reg,list(net_star.parameters()),net_star_grad_list[batch_it],net_star_full_grad):              
            #Using variance reduction
            p.v-=hper2c.h*(grad_reg+star_sum_grad+(grad-grad_star)*no_batches+l2regconst_extra*(p.data-p_star.data))

            # maxlen=20*torch.sqrt((torch.tensor(torch.numel(p.v))).float())
            # if(torch.norm(p.v)>maxlen):
            #     print("trouble")
                #p.v=(p.v/torch.norm(p.v))*maxlen
        # for it in range(len_params):
        #     [list(net.parameters())[it].data,list(net.parameters())[it].v]=U(list(net.parameters())[it].data,list(net.parameters())[it].v,hper2c)        
        for p in list(net.parameters()):
            [p.data,p.v]=U(p.data,p.v,hper2c)

    #bouncenet()
    return(loss_likelihood.data)

def ind_create(batch_it):
    modit=batch_it %(2*no_batches)
    ind=(modit<=(no_batches-1))*modit+(modit>=no_batches)*(2*no_batches-modit-1)
    return ind

# %%
#net = Fashion_MNIST_CNN().cuda()
#net2=copy.deepcopy(net)
#addnet(net2,net)
#multiplynet(net2,1/10)

# %%
# filepath="output_fashion_low_rank_9n.pickle"
# #filepath="output_fashion_low_rank_long.pickle"
# with open(filepath,"rb") as file:
#    [labels_arr,test_labels_arr,test_prob_arr]=pickle.load(file)
# labels_arr=torch.tensor(labels_arr).detach()
# test_labels_arr=torch.tensor(test_labels_arr).detach()
# test_prob_arr=torch.tensor(test_prob_arr).detach()

# %%
def GRdiagnostics(res):
  J=res.shape[0] #Number of chains
  L=res.shape[1] #Number of samples after burnin
  res_means=res.mean(dim=1)
  res_mean=res_means.mean()
  B=(res_means-res_mean).pow(2).sum()*L/(J-1)
  W=(res_means.reshape([J,1])@torch.ones([1,L])-res).pow(2).sum()/(J*(L-1))
  R=(W*(L-1)/L+B/L)/W
  return R

def GRtest(net_star,hper2c):
  par_chains=4
  num_epochs=40
  burnin_epochs=10
  loss_arr=torch.zeros([par_chains, num_epochs]).cuda()
  for chain in range(par_chains):
      net=copy.deepcopy(net_star)
      with torch.no_grad():
        for par in net.parameters():
          par+=(torch.randn_like(par))/torch.sqrt(l2regconst_extra)
          par.v = torch.randn_like(par,device=device)

      for epoch in range(num_epochs):
        print("chain: ",chain, "/epoch:",epoch)
        if(epoch % 2 == 0):
          rperm=random.permutation(list(range(no_batches)))
        for i in range(no_batches): 
          it=epoch*batch_size+i
          b=rperm[ind_create(it)]
          images=images_list[b]
          labels=labels_list[b]
          UBU_step(net,hper2c,images,labels,b)

        with torch.no_grad():
          for it in range(no_batches):
            images=images_list[it]
            labels=labels_list[it]
            actual_batch_size=len(images)
            output = net(images).detach()
            loss_arr[chain,epoch]+=loss_function(output,labels)*actual_batch_size
        print("Mean loss:", loss_arr[chain,epoch]/training_size)
  return(GRdiagnostics((loss_arr[:,range(burnin_epochs,num_epochs)]).cpu()), loss_arr.cpu())

# %%
#@title Output arrays
par_runs=16
num_classes=10
num_epochs=20
switch_to_swag_epoch=15
num_swag_epochs=num_epochs-switch_to_swag_epoch

training_size=no_batches*batch_size
test_size=test_data_len
labels_arr=torch.zeros(training_size)
test_labels_arr=torch.zeros(test_size)
test_prob_arr=torch.zeros([test_size,num_classes,num_epochs,par_runs])

lr = 1e-2
lr_swag=1e-3
h=2.5e-4
l2regconst=torch.tensor(1).detach()
l2regconst_extra=torch.tensor(50).detach()
gam=torch.sqrt(l2regconst_extra)
hper2c=hper2const(torch.tensor(h/2),gam)
GR_arr=torch.zeros(par_runs)
par_loss_arr=torch.zeros(par_runs,4,40)

for par_it in range(par_runs):
  print("par_it:",par_it,"\n")
  #@title Build the model
  net = Fashion_MNIST_CNN().cuda()
  net.train()
  optimizer = torch.optim.Adam( net.parameters(), lr=lr)
  
  lr_scheduler = torch.optim.lr_scheduler.PolynomialLR(optimizer=optimizer, total_iters=switch_to_swag_epoch,power=1)


  #@title Training the model

  for epoch in range(num_epochs):
    sum_loss=0
    #l2regconst=torch.min(torch.tensor(1+epoch),torch.tensor(switch_to_swag_epoch)).detach()
    net.train()
    if(epoch==(switch_to_swag_epoch-1)):
      net2=copy.deepcopy(net)
      multiplynet(net2,0)
      optimizer=torch.optim.Adam(net.parameters(),lr=lr_swag)

    for i in range(no_batches): 
      b=torch.randint(high=no_batches,size=(1,1))
      images=images_list[b]
      labels=labels_list[b]
      
      outputs = net(images)    
      loss_likelihood = loss_function(outputs, labels)
      sum_loss=sum_loss+loss_likelihood    
      reg=images_regulariser()
      loss=loss_likelihood+reg
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      if(epoch>=(switch_to_swag_epoch)):
        addnet(net2,net)

    print('Epoch [%d/%d], Step [%d/%d]' %(epoch+1, num_epochs, i+1, no_batches))
    correct = 0
    total = 0
    



    if epoch==(num_epochs-1):
      multiplynet(net2,1/(num_swag_epochs*no_batches))
      multiplynet(net,0)
      addnet(net,net2)
      del net2

      net_star=copy.deepcopy(net)
      len_params=len(list(net_star.parameters()))

      #Variance reduction - saving gradients at each batch at x_star
      net_star_grad_list=[]
      net_star_full_grad=[torch.zeros_like(par, device=device) for par in list(net_star.parameters())]
      for i in range(no_batches):
          images=images_list[i]
          labels=labels_list[i]
          outputs=net_star(images)
          loss_likelihood = loss_function(outputs, labels)
          reg=images_regulariser()
          net_star.zero_grad()
          loss_likelihood.backward()
          grads=[par.grad*batch_size for par in list(net_star.parameters())]
          net_star_grad_list.append(grads)
          for g, gi in zip(net_star_full_grad,grads):
            g+=gi

      len_params=len(list(net_star.parameters()))
      list_no_bias=torch.zeros(len_params)
      pit=0
      for name, p in net_star.named_parameters():
          if 'bias' not in name:
              list_no_bias[pit]=1.0
          pit+=1
      
      GR_arr[par_it],par_loss_arr[par_it,:,:]=GRtest(net_star,hper2c)

    with torch.no_grad():
      net(torch.cat(images_list[0:20],dim=0).detach())
      net.eval()
      for testit in range(test_no_batches):
        imagest=test_images_list[testit]
        labelst=test_labels_list[testit]
        actual_batch_size=len(imagest)
        test_labels_arr[(testit*batch_size):(testit*batch_size+actual_batch_size)]=labelst.detach().cpu()
        outputt = net(imagest).detach()#.reshape(actual_batch_size).detach()
        _, predictedt = torch.max(outputt,1)

        correct += (predictedt == labelst).sum()
        total += labelst.size(0)  
      net.train()


    #net.train()       
    print('Test accuracy of the model: %.3f %%' %((100*correct)/(total+1)))

    if(epoch<=switch_to_swag_epoch):
      lr_scheduler.step()
    print('Epoch [%d], Average Loss: %0.4f' %(epoch+1, sum_loss/no_batches))
  
  filepath="GR_fashion.pickle"
  with open(filepath,"wb") as file:
    pickle.dump([par_loss_arr.numpy(),GR_arr.numpy()],file)

  # filepath="output_fashionrand_test.pickle"
  # with open(filepath,"wb") as file:
  #   pickle.dump([labels_arr.numpy(),test_labels_arr.numpy(),test_prob_arr.numpy()],file)
# Out:
# par_it: 0
#
# Epoch [1/20], Step [300/300]
# Test accuracy of the model: 85.821 %
# Epoch [1], Average Loss: 0.5740
# Epoch [2/20], Step [300/300]
# Test accuracy of the model: 88.991 %
# Epoch [2], Average Loss: 0.3122
# Epoch [3/20], Step [300/300]
# Test accuracy of the model: 90.591 %
# Epoch [3], Average Loss: 0.2471
# Epoch [4/20], Step [300/300]
# Test accuracy of the model: 91.111 %
# Epoch [4], Average Loss: 0.2129
# Epoch [5/20], Step [300/300]
# Test accuracy of the model: 91.511 %
# Epoch [5], Average Loss: 0.1867
# Epoch [6/20], Step [300/300]
# Test accuracy of the model: 91.751 %
# Epoch [6], Average Loss: 0.1726
# Epoch [7/20], Step [300/300]
# Test accuracy of the model: 91.691 %
# Epoch [7], Average Loss: 0.1592
# Epoch [8/20], Step [300/300]
# Test accuracy of the model: 91.711 %
# Epoch [8], Average Loss: 0.1421
# Epoch [9/20], Step [300/300]
# Test accuracy of the model: 91.601 %
# Epoch [9], Average Loss: 0.1319
# Epoch [10/20], Step [300/300]
# Test accuracy of the model: 92.511 %
# Epoch [10], Average Loss: 0.1151
# Epoch [11/20], Step [300/300]
# Test accuracy of the model: 92.211 %
# Epoch [11], Average Loss: 0.0950
# Epoch [12/20], Step [300/300]
# Test accuracy of the model: 92.891 %
# Epoch [12], Average Loss: 0.0733
# Epoch [13/20], Step [300/300]
# Test accuracy of the model: 92.851 %
# Epoch [13], Average Loss: 0.0569
# Epoch [14/20], Step [300/300]
# Test accuracy of the model: 93.041 %
# Epoch [14], Average Loss: 0.0318
# Epoch [15/20], Step [300/300]
# Test accuracy of the model: 92.911 %
# Epoch [15], Average Loss: 0.0238
# Epoch [16/20], Step [300/300]
# Test accuracy of the model: 93.171 %
# Epoch [16], Average Loss: 0.0182
# Epoch [17/20], Step [300/300]
# Test accuracy of the model: 93.001 %
# Epoch [17], Average Loss: 0.0119
# Epoch [18/20], Step [300/300]
# Test accuracy of the model: 92.951 %
# Epoch [18], Average Loss: 0.0158
# Epoch [19/20], Step [300/300]
# Test accuracy of the model: 93.151 %
# Epoch [19], Average Loss: 0.0145
# Epoch [20/20], Step [300/300]
# chain:  0 /epoch: 0
# Mean loss: tensor(0.2481, device='cuda:0')
# chain:  0 /epoch: 1
# Mean loss: tensor(0.2226, device='cuda:0')
# chain:  0 /epoch: 2
# Mean loss: tensor(0.1938, device='cuda:0')
# chain:  0 /epoch: 3
# Mean loss: tensor(0.1708, device='cuda:0')
# chain:  0 /epoch: 4
# Mean loss: tensor(0.1504, device='cuda:0')
# chain:  0 /epoch: 5
# Mean loss: tensor(0.1278, device='cuda:0')
# chain:  0 /epoch: 6
# Mean loss: tensor(0.1109, device='cuda:0')
# chain:  0 /epoch: 7
# Mean loss: tensor(0.0961, device='cuda:0')
# chain:  0 /epoch: 8
# Mean loss: tensor(0.0854, device='cuda:0')
# chain:  0 /epoch: 9
# Mean loss: tensor(0.0702, device='cuda:0')
# chain:  0 /epoch: 10
# Mean loss: tensor(0.0666, device='cuda:0')
# chain:  0 /epoch: 11
# Mean loss: tensor(0.0600, device='cuda:0')
# chain:  0 /epoch: 12
# Mean loss: tensor(0.0589, device='cuda:0')
# chain:  0 /epoch: 13
# Mean loss: tensor(0.0607, device='cuda:0')
# chain:  0 /epoch: 14
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  0 /epoch: 15
# Mean loss: tensor(0.0524, device='cuda:0')
# chain:  0 /epoch: 16
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  0 /epoch: 17
# Mean loss: tensor(0.0502, device='cuda:0')
# chain:  0 /epoch: 18
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  0 /epoch: 19
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  0 /epoch: 20
# Mean loss: tensor(0.0528, device='cuda:0')
# chain:  0 /epoch: 21
# Mean loss: tensor(0.0501, device='cuda:0')
# chain:  0 /epoch: 22
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  0 /epoch: 23
# Mean loss: tensor(0.0489, device='cuda:0')
# chain:  0 /epoch: 24
# Mean loss: tensor(0.0460, device='cuda:0')
# chain:  0 /epoch: 25
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  0 /epoch: 26
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  0 /epoch: 27
# Mean loss: tensor(0.0501, device='cuda:0')
# chain:  0 /epoch: 28
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  0 /epoch: 29
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  0 /epoch: 30
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  0 /epoch: 31
# Mean loss: tensor(0.0557, device='cuda:0')
# chain:  0 /epoch: 32
# Mean loss: tensor(0.0544, device='cuda:0')
# chain:  0 /epoch: 33
# Mean loss: tensor(0.0544, device='cuda:0')
# chain:  0 /epoch: 34
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  0 /epoch: 35
# Mean loss: tensor(0.0532, device='cuda:0')
# chain:  0 /epoch: 36
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  0 /epoch: 37
# Mean loss: tensor(0.0570, device='cuda:0')
# chain:  0 /epoch: 38
# Mean loss: tensor(0.0602, device='cuda:0')
# chain:  0 /epoch: 39
# Mean loss: tensor(0.0541, device='cuda:0')
# chain:  1 /epoch: 0
# Mean loss: tensor(0.1722, device='cuda:0')
# chain:  1 /epoch: 1
# Mean loss: tensor(0.1722, device='cuda:0')
# chain:  1 /epoch: 2
# Mean loss: tensor(0.1454, device='cuda:0')
# chain:  1 /epoch: 3
# Mean loss: tensor(0.1226, device='cuda:0')
# chain:  1 /epoch: 4
# Mean loss: tensor(0.1087, device='cuda:0')
# chain:  1 /epoch: 5
# Mean loss: tensor(0.0908, device='cuda:0')
# chain:  1 /epoch: 6
# Mean loss: tensor(0.0794, device='cuda:0')
# chain:  1 /epoch: 7
# Mean loss: tensor(0.0761, device='cuda:0')
# chain:  1 /epoch: 8
# Mean loss: tensor(0.0678, device='cuda:0')
# chain:  1 /epoch: 9
# Mean loss: tensor(0.0631, device='cuda:0')
# chain:  1 /epoch: 10
# Mean loss: tensor(0.0625, device='cuda:0')
# chain:  1 /epoch: 11
# Mean loss: tensor(0.0594, device='cuda:0')
# chain:  1 /epoch: 12
# Mean loss: tensor(0.0516, device='cuda:0')
# chain:  1 /epoch: 13
# Mean loss: tensor(0.0571, device='cuda:0')
# chain:  1 /epoch: 14
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  1 /epoch: 15
# Mean loss: tensor(0.0540, device='cuda:0')
# chain:  1 /epoch: 16
# Mean loss: tensor(0.0604, device='cuda:0')
# chain:  1 /epoch: 17
# Mean loss: tensor(0.0576, device='cuda:0')
# chain:  1 /epoch: 18
# Mean loss: tensor(0.0588, device='cuda:0')
# chain:  1 /epoch: 19
# Mean loss: tensor(0.0585, device='cuda:0')
# chain:  1 /epoch: 20
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  1 /epoch: 21
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  1 /epoch: 22
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  1 /epoch: 23
# Mean loss: tensor(0.0515, device='cuda:0')
# chain:  1 /epoch: 24
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  1 /epoch: 25
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  1 /epoch: 26
# Mean loss: tensor(0.0527, device='cuda:0')
# chain:  1 /epoch: 27
# Mean loss: tensor(0.0469, device='cuda:0')
# chain:  1 /epoch: 28
# Mean loss: tensor(0.0496, device='cuda:0')
# chain:  1 /epoch: 29
# Mean loss: tensor(0.0491, device='cuda:0')
# chain:  1 /epoch: 30
# Mean loss: tensor(0.0495, device='cuda:0')
# chain:  1 /epoch: 31
# Mean loss: tensor(0.0532, device='cuda:0')
# chain:  1 /epoch: 32
# Mean loss: tensor(0.0542, device='cuda:0')
# chain:  1 /epoch: 33
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  1 /epoch: 34
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  1 /epoch: 35
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  1 /epoch: 36
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  1 /epoch: 37
# Mean loss: tensor(0.0541, device='cuda:0')
# chain:  1 /epoch: 38
# Mean loss: tensor(0.0517, device='cuda:0')
# chain:  1 /epoch: 39
# Mean loss: tensor(0.0504, device='cuda:0')
# chain:  2 /epoch: 0
# Mean loss: tensor(0.2136, device='cuda:0')
# chain:  2 /epoch: 1
# Mean loss: tensor(0.2018, device='cuda:0')
# chain:  2 /epoch: 2
# Mean loss: tensor(0.1628, device='cuda:0')
# chain:  2 /epoch: 3
# Mean loss: tensor(0.1304, device='cuda:0')
# chain:  2 /epoch: 4
# Mean loss: tensor(0.1143, device='cuda:0')
# chain:  2 /epoch: 5
# Mean loss: tensor(0.1001, device='cuda:0')
# chain:  2 /epoch: 6
# Mean loss: tensor(0.0858, device='cuda:0')
# chain:  2 /epoch: 7
# Mean loss: tensor(0.0799, device='cuda:0')
# chain:  2 /epoch: 8
# Mean loss: tensor(0.0687, device='cuda:0')
# chain:  2 /epoch: 9
# Mean loss: tensor(0.0636, device='cuda:0')
# chain:  2 /epoch: 10
# Mean loss: tensor(0.0609, device='cuda:0')
# chain:  2 /epoch: 11
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  2 /epoch: 12
# Mean loss: tensor(0.0575, device='cuda:0')
# chain:  2 /epoch: 13
# Mean loss: tensor(0.0545, device='cuda:0')
# chain:  2 /epoch: 14
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  2 /epoch: 15
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  2 /epoch: 16
# Mean loss: tensor(0.0536, device='cuda:0')
# chain:  2 /epoch: 17
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  2 /epoch: 18
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  2 /epoch: 19
# Mean loss: tensor(0.0506, device='cuda:0')
# chain:  2 /epoch: 20
# Mean loss: tensor(0.0540, device='cuda:0')
# chain:  2 /epoch: 21
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  2 /epoch: 22
# Mean loss: tensor(0.0495, device='cuda:0')
# chain:  2 /epoch: 23
# Mean loss: tensor(0.0490, device='cuda:0')
# chain:  2 /epoch: 24
# Mean loss: tensor(0.0515, device='cuda:0')
# chain:  2 /epoch: 25
# Mean loss: tensor(0.0537, device='cuda:0')
# chain:  2 /epoch: 26
# Mean loss: tensor(0.0580, device='cuda:0')
# chain:  2 /epoch: 27
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  2 /epoch: 28
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  2 /epoch: 29
# Mean loss: tensor(0.0495, device='cuda:0')
# chain:  2 /epoch: 30
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  2 /epoch: 31
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  2 /epoch: 32
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  2 /epoch: 33
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  2 /epoch: 34
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  2 /epoch: 35
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  2 /epoch: 36
# Mean loss: tensor(0.0551, device='cuda:0')
# chain:  2 /epoch: 37
# Mean loss: tensor(0.0547, device='cuda:0')
# chain:  2 /epoch: 38
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  2 /epoch: 39
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  3 /epoch: 0
# Mean loss: tensor(0.1831, device='cuda:0')
# chain:  3 /epoch: 1
# Mean loss: tensor(0.1652, device='cuda:0')
# chain:  3 /epoch: 2
# Mean loss: tensor(0.1453, device='cuda:0')
# chain:  3 /epoch: 3
# Mean loss: tensor(0.1208, device='cuda:0')
# chain:  3 /epoch: 4
# Mean loss: tensor(0.1067, device='cuda:0')
# chain:  3 /epoch: 5
# Mean loss: tensor(0.0885, device='cuda:0')
# chain:  3 /epoch: 6
# Mean loss: tensor(0.0775, device='cuda:0')
# chain:  3 /epoch: 7
# Mean loss: tensor(0.0731, device='cuda:0')
# chain:  3 /epoch: 8
# Mean loss: tensor(0.0626, device='cuda:0')
# chain:  3 /epoch: 9
# Mean loss: tensor(0.0605, device='cuda:0')
# chain:  3 /epoch: 10
# Mean loss: tensor(0.0571, device='cuda:0')
# chain:  3 /epoch: 11
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  3 /epoch: 12
# Mean loss: tensor(0.0491, device='cuda:0')
# chain:  3 /epoch: 13
# Mean loss: tensor(0.0542, device='cuda:0')
# chain:  3 /epoch: 14
# Mean loss: tensor(0.0554, device='cuda:0')
# chain:  3 /epoch: 15
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 16
# Mean loss: tensor(0.0526, device='cuda:0')
# chain:  3 /epoch: 17
# Mean loss: tensor(0.0508, device='cuda:0')
# chain:  3 /epoch: 18
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  3 /epoch: 19
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  3 /epoch: 20
# Mean loss: tensor(0.0559, device='cuda:0')
# chain:  3 /epoch: 21
# Mean loss: tensor(0.0532, device='cuda:0')
# chain:  3 /epoch: 22
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  3 /epoch: 23
# Mean loss: tensor(0.0516, device='cuda:0')
# chain:  3 /epoch: 24
# Mean loss: tensor(0.0505, device='cuda:0')
# chain:  3 /epoch: 25
# Mean loss: tensor(0.0543, device='cuda:0')
# chain:  3 /epoch: 26
# Mean loss: tensor(0.0542, device='cuda:0')
# chain:  3 /epoch: 27
# Mean loss: tensor(0.0524, device='cuda:0')
# chain:  3 /epoch: 28
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  3 /epoch: 29
# Mean loss: tensor(0.0554, device='cuda:0')
# chain:  3 /epoch: 30
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  3 /epoch: 31
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  3 /epoch: 32
# Mean loss: tensor(0.0554, device='cuda:0')
# chain:  3 /epoch: 33
# Mean loss: tensor(0.0528, device='cuda:0')
# chain:  3 /epoch: 34
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  3 /epoch: 35
# Mean loss: tensor(0.0479, device='cuda:0')
# chain:  3 /epoch: 36
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  3 /epoch: 37
# Mean loss: tensor(0.0527, device='cuda:0')
# chain:  3 /epoch: 38
# Mean loss: tensor(0.0482, device='cuda:0')
# chain:  3 /epoch: 39
# Mean loss: tensor(0.0512, device='cuda:0')
# Test accuracy of the model: 93.641 %
# Epoch [20], Average Loss: 0.0145
# par_it: 1
#
# Epoch [1/20], Step [300/300]
# Test accuracy of the model: 85.181 %
# Epoch [1], Average Loss: 0.5484
# Epoch [2/20], Step [300/300]
# Test accuracy of the model: 89.821 %
# Epoch [2], Average Loss: 0.3079
# Epoch [3/20], Step [300/300]
# Test accuracy of the model: 90.691 %
# Epoch [3], Average Loss: 0.2456
# Epoch [4/20], Step [300/300]
# Test accuracy of the model: 90.441 %
# Epoch [4], Average Loss: 0.2131
# Epoch [5/20], Step [300/300]
# Test accuracy of the model: 91.741 %
# Epoch [5], Average Loss: 0.2005
# Epoch [6/20], Step [300/300]
# Test accuracy of the model: 91.871 %
# Epoch [6], Average Loss: 0.1764
# Epoch [7/20], Step [300/300]
# Test accuracy of the model: 92.331 %
# Epoch [7], Average Loss: 0.1587
# Epoch [8/20], Step [300/300]
# Test accuracy of the model: 92.441 %
# Epoch [8], Average Loss: 0.1474
# Epoch [9/20], Step [300/300]
# Test accuracy of the model: 92.431 %
# Epoch [9], Average Loss: 0.1221
# Epoch [10/20], Step [300/300]
# Test accuracy of the model: 92.271 %
# Epoch [10], Average Loss: 0.1130
# Epoch [11/20], Step [300/300]
# Test accuracy of the model: 92.901 %
# Epoch [11], Average Loss: 0.0954
# Epoch [12/20], Step [300/300]
# Test accuracy of the model: 93.061 %
# Epoch [12], Average Loss: 0.0703
# Epoch [13/20], Step [300/300]
# Test accuracy of the model: 92.601 %
# Epoch [13], Average Loss: 0.0517
# Epoch [14/20], Step [300/300]
# Test accuracy of the model: 93.021 %
# Epoch [14], Average Loss: 0.0261
# Epoch [15/20], Step [300/300]
# Test accuracy of the model: 93.051 %
# Epoch [15], Average Loss: 0.0210
# Epoch [16/20], Step [300/300]
# Test accuracy of the model: 93.011 %
# Epoch [16], Average Loss: 0.0144
# Epoch [17/20], Step [300/300]
# Test accuracy of the model: 93.051 %
# Epoch [17], Average Loss: 0.0169
# Epoch [18/20], Step [300/300]
# Test accuracy of the model: 92.641 %
# Epoch [18], Average Loss: 0.0131
# Epoch [19/20], Step [300/300]
# Test accuracy of the model: 93.091 %
# Epoch [19], Average Loss: 0.0114
# Epoch [20/20], Step [300/300]
# chain:  0 /epoch: 0
# Mean loss: tensor(0.2181, device='cuda:0')
# chain:  0 /epoch: 1
# Mean loss: tensor(0.2027, device='cuda:0')
# chain:  0 /epoch: 2
# Mean loss: tensor(0.1741, device='cuda:0')
# chain:  0 /epoch: 3
# Mean loss: tensor(0.1470, device='cuda:0')
# chain:  0 /epoch: 4
# Mean loss: tensor(0.1222, device='cuda:0')
# chain:  0 /epoch: 5
# Mean loss: tensor(0.1053, device='cuda:0')
# chain:  0 /epoch: 6
# Mean loss: tensor(0.0908, device='cuda:0')
# chain:  0 /epoch: 7
# Mean loss: tensor(0.0771, device='cuda:0')
# chain:  0 /epoch: 8
# Mean loss: tensor(0.0665, device='cuda:0')
# chain:  0 /epoch: 9
# Mean loss: tensor(0.0680, device='cuda:0')
# chain:  0 /epoch: 10
# Mean loss: tensor(0.0594, device='cuda:0')
# chain:  0 /epoch: 11
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  0 /epoch: 12
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  0 /epoch: 13
# Mean loss: tensor(0.0566, device='cuda:0')
# chain:  0 /epoch: 14
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  0 /epoch: 15
# Mean loss: tensor(0.0494, device='cuda:0')
# chain:  0 /epoch: 16
# Mean loss: tensor(0.0484, device='cuda:0')
# chain:  0 /epoch: 17
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  0 /epoch: 18
# Mean loss: tensor(0.0481, device='cuda:0')
# chain:  0 /epoch: 19
# Mean loss: tensor(0.0566, device='cuda:0')
# chain:  0 /epoch: 20
# Mean loss: tensor(0.0488, device='cuda:0')
# chain:  0 /epoch: 21
# Mean loss: tensor(0.0528, device='cuda:0')
# chain:  0 /epoch: 22
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  0 /epoch: 23
# Mean loss: tensor(0.0491, device='cuda:0')
# chain:  0 /epoch: 24
# Mean loss: tensor(0.0564, device='cuda:0')
# chain:  0 /epoch: 25
# Mean loss: tensor(0.0583, device='cuda:0')
# chain:  0 /epoch: 26
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  0 /epoch: 27
# Mean loss: tensor(0.0571, device='cuda:0')
# chain:  0 /epoch: 28
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  0 /epoch: 29
# Mean loss: tensor(0.0518, device='cuda:0')
# chain:  0 /epoch: 30
# Mean loss: tensor(0.0538, device='cuda:0')
# chain:  0 /epoch: 31
# Mean loss: tensor(0.0586, device='cuda:0')
# chain:  0 /epoch: 32
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  0 /epoch: 33
# Mean loss: tensor(0.0492, device='cuda:0')
# chain:  0 /epoch: 34
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  0 /epoch: 35
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  0 /epoch: 36
# Mean loss: tensor(0.0484, device='cuda:0')
# chain:  0 /epoch: 37
# Mean loss: tensor(0.0483, device='cuda:0')
# chain:  0 /epoch: 38
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  0 /epoch: 39
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  1 /epoch: 0
# Mean loss: tensor(0.1998, device='cuda:0')
# chain:  1 /epoch: 1
# Mean loss: tensor(0.1719, device='cuda:0')
# chain:  1 /epoch: 2
# Mean loss: tensor(0.1478, device='cuda:0')
# chain:  1 /epoch: 3
# Mean loss: tensor(0.1310, device='cuda:0')
# chain:  1 /epoch: 4
# Mean loss: tensor(0.1091, device='cuda:0')
# chain:  1 /epoch: 5
# Mean loss: tensor(0.0922, device='cuda:0')
# chain:  1 /epoch: 6
# Mean loss: tensor(0.0831, device='cuda:0')
# chain:  1 /epoch: 7
# Mean loss: tensor(0.0731, device='cuda:0')
# chain:  1 /epoch: 8
# Mean loss: tensor(0.0708, device='cuda:0')
# chain:  1 /epoch: 9
# Mean loss: tensor(0.0661, device='cuda:0')
# chain:  1 /epoch: 10
# Mean loss: tensor(0.0585, device='cuda:0')
# chain:  1 /epoch: 11
# Mean loss: tensor(0.0567, device='cuda:0')
# chain:  1 /epoch: 12
# Mean loss: tensor(0.0582, device='cuda:0')
# chain:  1 /epoch: 13
# Mean loss: tensor(0.0542, device='cuda:0')
# chain:  1 /epoch: 14
# Mean loss: tensor(0.0574, device='cuda:0')
# chain:  1 /epoch: 15
# Mean loss: tensor(0.0566, device='cuda:0')
# chain:  1 /epoch: 16
# Mean loss: tensor(0.0605, device='cuda:0')
# chain:  1 /epoch: 17
# Mean loss: tensor(0.0537, device='cuda:0')
# chain:  1 /epoch: 18
# Mean loss: tensor(0.0555, device='cuda:0')
# chain:  1 /epoch: 19
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  1 /epoch: 20
# Mean loss: tensor(0.0561, device='cuda:0')
# chain:  1 /epoch: 21
# Mean loss: tensor(0.0536, device='cuda:0')
# chain:  1 /epoch: 22
# Mean loss: tensor(0.0547, device='cuda:0')
# chain:  1 /epoch: 23
# Mean loss: tensor(0.0569, device='cuda:0')
# chain:  1 /epoch: 24
# Mean loss: tensor(0.0563, device='cuda:0')
# chain:  1 /epoch: 25
# Mean loss: tensor(0.0559, device='cuda:0')
# chain:  1 /epoch: 26
# Mean loss: tensor(0.0554, device='cuda:0')
# chain:  1 /epoch: 27
# Mean loss: tensor(0.0544, device='cuda:0')
# chain:  1 /epoch: 28
# Mean loss: tensor(0.0549, device='cuda:0')
# chain:  1 /epoch: 29
# Mean loss: tensor(0.0573, device='cuda:0')
# chain:  1 /epoch: 30
# Mean loss: tensor(0.0544, device='cuda:0')
# chain:  1 /epoch: 31
# Mean loss: tensor(0.0607, device='cuda:0')
# chain:  1 /epoch: 32
# Mean loss: tensor(0.0554, device='cuda:0')
# chain:  1 /epoch: 33
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  1 /epoch: 34
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  1 /epoch: 35
# Mean loss: tensor(0.0506, device='cuda:0')
# chain:  1 /epoch: 36
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  1 /epoch: 37
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  1 /epoch: 38
# Mean loss: tensor(0.0521, device='cuda:0')
# chain:  1 /epoch: 39
# Mean loss: tensor(0.0506, device='cuda:0')
# chain:  2 /epoch: 0
# Mean loss: tensor(0.2041, device='cuda:0')
# chain:  2 /epoch: 1
# Mean loss: tensor(0.1780, device='cuda:0')
# chain:  2 /epoch: 2
# Mean loss: tensor(0.1427, device='cuda:0')
# chain:  2 /epoch: 3
# Mean loss: tensor(0.1252, device='cuda:0')
# chain:  2 /epoch: 4
# Mean loss: tensor(0.1060, device='cuda:0')
# chain:  2 /epoch: 5
# Mean loss: tensor(0.0938, device='cuda:0')
# chain:  2 /epoch: 6
# Mean loss: tensor(0.0810, device='cuda:0')
# chain:  2 /epoch: 7
# Mean loss: tensor(0.0719, device='cuda:0')
# chain:  2 /epoch: 8
# Mean loss: tensor(0.0659, device='cuda:0')
# chain:  2 /epoch: 9
# Mean loss: tensor(0.0613, device='cuda:0')
# chain:  2 /epoch: 10
# Mean loss: tensor(0.0518, device='cuda:0')
# chain:  2 /epoch: 11
# Mean loss: tensor(0.0505, device='cuda:0')
# chain:  2 /epoch: 12
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  2 /epoch: 13
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  2 /epoch: 14
# Mean loss: tensor(0.0528, device='cuda:0')
# chain:  2 /epoch: 15
# Mean loss: tensor(0.0518, device='cuda:0')
# chain:  2 /epoch: 16
# Mean loss: tensor(0.0501, device='cuda:0')
# chain:  2 /epoch: 17
# Mean loss: tensor(0.0502, device='cuda:0')
# chain:  2 /epoch: 18
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  2 /epoch: 19
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  2 /epoch: 20
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  2 /epoch: 21
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  2 /epoch: 22
# Mean loss: tensor(0.0669, device='cuda:0')
# chain:  2 /epoch: 23
# Mean loss: tensor(0.0557, device='cuda:0')
# chain:  2 /epoch: 24
# Mean loss: tensor(0.0554, device='cuda:0')
# chain:  2 /epoch: 25
# Mean loss: tensor(0.0545, device='cuda:0')
# chain:  2 /epoch: 26
# Mean loss: tensor(0.0561, device='cuda:0')
# chain:  2 /epoch: 27
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  2 /epoch: 28
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  2 /epoch: 29
# Mean loss: tensor(0.0476, device='cuda:0')
# chain:  2 /epoch: 30
# Mean loss: tensor(0.0501, device='cuda:0')
# chain:  2 /epoch: 31
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  2 /epoch: 32
# Mean loss: tensor(0.0492, device='cuda:0')
# chain:  2 /epoch: 33
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  2 /epoch: 34
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  2 /epoch: 35
# Mean loss: tensor(0.0516, device='cuda:0')
# chain:  2 /epoch: 36
# Mean loss: tensor(0.0487, device='cuda:0')
# chain:  2 /epoch: 37
# Mean loss: tensor(0.0508, device='cuda:0')
# chain:  2 /epoch: 38
# Mean loss: tensor(0.0495, device='cuda:0')
# chain:  2 /epoch: 39
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  3 /epoch: 0
# Mean loss: tensor(0.2346, device='cuda:0')
# chain:  3 /epoch: 1
# Mean loss: tensor(0.2063, device='cuda:0')
# chain:  3 /epoch: 2
# Mean loss: tensor(0.1920, device='cuda:0')
# chain:  3 /epoch: 3
# Mean loss: tensor(0.1563, device='cuda:0')
# chain:  3 /epoch: 4
# Mean loss: tensor(0.1435, device='cuda:0')
# chain:  3 /epoch: 5
# Mean loss: tensor(0.1152, device='cuda:0')
# chain:  3 /epoch: 6
# Mean loss: tensor(0.0945, device='cuda:0')
# chain:  3 /epoch: 7
# Mean loss: tensor(0.0833, device='cuda:0')
# chain:  3 /epoch: 8
# Mean loss: tensor(0.0768, device='cuda:0')
# chain:  3 /epoch: 9
# Mean loss: tensor(0.0669, device='cuda:0')
# chain:  3 /epoch: 10
# Mean loss: tensor(0.0612, device='cuda:0')
# chain:  3 /epoch: 11
# Mean loss: tensor(0.0528, device='cuda:0')
# chain:  3 /epoch: 12
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  3 /epoch: 13
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 14
# Mean loss: tensor(0.0527, device='cuda:0')
# chain:  3 /epoch: 15
# Mean loss: tensor(0.0596, device='cuda:0')
# chain:  3 /epoch: 16
# Mean loss: tensor(0.0536, device='cuda:0')
# chain:  3 /epoch: 17
# Mean loss: tensor(0.0513, device='cuda:0')
# chain:  3 /epoch: 18
# Mean loss: tensor(0.0518, device='cuda:0')
# chain:  3 /epoch: 19
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  3 /epoch: 20
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 21
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  3 /epoch: 22
# Mean loss: tensor(0.0538, device='cuda:0')
# chain:  3 /epoch: 23
# Mean loss: tensor(0.0485, device='cuda:0')
# chain:  3 /epoch: 24
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  3 /epoch: 25
# Mean loss: tensor(0.0481, device='cuda:0')
# chain:  3 /epoch: 26
# Mean loss: tensor(0.0478, device='cuda:0')
# chain:  3 /epoch: 27
# Mean loss: tensor(0.0494, device='cuda:0')
# chain:  3 /epoch: 28
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 29
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  3 /epoch: 30
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 31
# Mean loss: tensor(0.0538, device='cuda:0')
# chain:  3 /epoch: 32
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  3 /epoch: 33
# Mean loss: tensor(0.0493, device='cuda:0')
# chain:  3 /epoch: 34
# Mean loss: tensor(0.0496, device='cuda:0')
# chain:  3 /epoch: 35
# Mean loss: tensor(0.0517, device='cuda:0')
# chain:  3 /epoch: 36
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  3 /epoch: 37
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  3 /epoch: 38
# Mean loss: tensor(0.0491, device='cuda:0')
# chain:  3 /epoch: 39
# Mean loss: tensor(0.0487, device='cuda:0')
# Test accuracy of the model: 93.501 %
# Epoch [20], Average Loss: 0.0083
# par_it: 2
#
# Epoch [1/20], Step [300/300]
# Test accuracy of the model: 85.841 %
# Epoch [1], Average Loss: 0.5433
# Epoch [2/20], Step [300/300]
# Test accuracy of the model: 89.381 %
# Epoch [2], Average Loss: 0.3023
# Epoch [3/20], Step [300/300]
# Test accuracy of the model: 89.711 %
# Epoch [3], Average Loss: 0.2465
# Epoch [4/20], Step [300/300]
# Test accuracy of the model: 90.441 %
# Epoch [4], Average Loss: 0.2183
# Epoch [5/20], Step [300/300]
# Test accuracy of the model: 91.251 %
# Epoch [5], Average Loss: 0.1966
# Epoch [6/20], Step [300/300]
# Test accuracy of the model: 91.031 %
# Epoch [6], Average Loss: 0.1824
# Epoch [7/20], Step [300/300]
# Test accuracy of the model: 92.181 %
# Epoch [7], Average Loss: 0.1656
# Epoch [8/20], Step [300/300]
# Test accuracy of the model: 92.061 %
# Epoch [8], Average Loss: 0.1526
# Epoch [9/20], Step [300/300]
# Test accuracy of the model: 91.881 %
# Epoch [9], Average Loss: 0.1346
# Epoch [10/20], Step [300/300]
# Test accuracy of the model: 92.411 %
# Epoch [10], Average Loss: 0.1254
# Epoch [11/20], Step [300/300]
# Test accuracy of the model: 92.491 %
# Epoch [11], Average Loss: 0.0989
# Epoch [12/20], Step [300/300]
# Test accuracy of the model: 93.141 %
# Epoch [12], Average Loss: 0.0792
# Epoch [13/20], Step [300/300]
# Test accuracy of the model: 92.581 %
# Epoch [13], Average Loss: 0.0596
# Epoch [14/20], Step [300/300]
# Test accuracy of the model: 93.141 %
# Epoch [14], Average Loss: 0.0388
# Epoch [15/20], Step [300/300]
# Test accuracy of the model: 93.341 %
# Epoch [15], Average Loss: 0.0250
# Epoch [16/20], Step [300/300]
# Test accuracy of the model: 93.211 %
# Epoch [16], Average Loss: 0.0204
# Epoch [17/20], Step [300/300]
# Test accuracy of the model: 92.991 %
# Epoch [17], Average Loss: 0.0156
# Epoch [18/20], Step [300/300]
# Test accuracy of the model: 92.941 %
# Epoch [18], Average Loss: 0.0180
# Epoch [19/20], Step [300/300]
# Test accuracy of the model: 92.681 %
# Epoch [19], Average Loss: 0.0180
# Epoch [20/20], Step [300/300]
# chain:  0 /epoch: 0
# Mean loss: tensor(0.2065, device='cuda:0')
# chain:  0 /epoch: 1
# Mean loss: tensor(0.1675, device='cuda:0')
# chain:  0 /epoch: 2
# Mean loss: tensor(0.1544, device='cuda:0')
# chain:  0 /epoch: 3
# Mean loss: tensor(0.1334, device='cuda:0')
# chain:  0 /epoch: 4
# Mean loss: tensor(0.1190, device='cuda:0')
# chain:  0 /epoch: 5
# Mean loss: tensor(0.0956, device='cuda:0')
# chain:  0 /epoch: 6
# Mean loss: tensor(0.0841, device='cuda:0')
# chain:  0 /epoch: 7
# Mean loss: tensor(0.0770, device='cuda:0')
# chain:  0 /epoch: 8
# Mean loss: tensor(0.0679, device='cuda:0')
# chain:  0 /epoch: 9
# Mean loss: tensor(0.0647, device='cuda:0')
# chain:  0 /epoch: 10
# Mean loss: tensor(0.0622, device='cuda:0')
# chain:  0 /epoch: 11
# Mean loss: tensor(0.0594, device='cuda:0')
# chain:  0 /epoch: 12
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  0 /epoch: 13
# Mean loss: tensor(0.0541, device='cuda:0')
# chain:  0 /epoch: 14
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  0 /epoch: 15
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  0 /epoch: 16
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  0 /epoch: 17
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  0 /epoch: 18
# Mean loss: tensor(0.0549, device='cuda:0')
# chain:  0 /epoch: 19
# Mean loss: tensor(0.0611, device='cuda:0')
# chain:  0 /epoch: 20
# Mean loss: tensor(0.0597, device='cuda:0')
# chain:  0 /epoch: 21
# Mean loss: tensor(0.0580, device='cuda:0')
# chain:  0 /epoch: 22
# Mean loss: tensor(0.0570, device='cuda:0')
# chain:  0 /epoch: 23
# Mean loss: tensor(0.0549, device='cuda:0')
# chain:  0 /epoch: 24
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  0 /epoch: 25
# Mean loss: tensor(0.0515, device='cuda:0')
# chain:  0 /epoch: 26
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  0 /epoch: 27
# Mean loss: tensor(0.0512, device='cuda:0')
# chain:  0 /epoch: 28
# Mean loss: tensor(0.0503, device='cuda:0')
# chain:  0 /epoch: 29
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  0 /epoch: 30
# Mean loss: tensor(0.0532, device='cuda:0')
# chain:  0 /epoch: 31
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  0 /epoch: 32
# Mean loss: tensor(0.0527, device='cuda:0')
# chain:  0 /epoch: 33
# Mean loss: tensor(0.0585, device='cuda:0')
# chain:  0 /epoch: 34
# Mean loss: tensor(0.0600, device='cuda:0')
# chain:  0 /epoch: 35
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  0 /epoch: 36
# Mean loss: tensor(0.0537, device='cuda:0')
# chain:  0 /epoch: 37
# Mean loss: tensor(0.0526, device='cuda:0')
# chain:  0 /epoch: 38
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  0 /epoch: 39
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  1 /epoch: 0
# Mean loss: tensor(0.2130, device='cuda:0')
# chain:  1 /epoch: 1
# Mean loss: tensor(0.1931, device='cuda:0')
# chain:  1 /epoch: 2
# Mean loss: tensor(0.1671, device='cuda:0')
# chain:  1 /epoch: 3
# Mean loss: tensor(0.1478, device='cuda:0')
# chain:  1 /epoch: 4
# Mean loss: tensor(0.1316, device='cuda:0')
# chain:  1 /epoch: 5
# Mean loss: tensor(0.1147, device='cuda:0')
# chain:  1 /epoch: 6
# Mean loss: tensor(0.0924, device='cuda:0')
# chain:  1 /epoch: 7
# Mean loss: tensor(0.0817, device='cuda:0')
# chain:  1 /epoch: 8
# Mean loss: tensor(0.0692, device='cuda:0')
# chain:  1 /epoch: 9
# Mean loss: tensor(0.0671, device='cuda:0')
# chain:  1 /epoch: 10
# Mean loss: tensor(0.0668, device='cuda:0')
# chain:  1 /epoch: 11
# Mean loss: tensor(0.0604, device='cuda:0')
# chain:  1 /epoch: 12
# Mean loss: tensor(0.0585, device='cuda:0')
# chain:  1 /epoch: 13
# Mean loss: tensor(0.0572, device='cuda:0')
# chain:  1 /epoch: 14
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  1 /epoch: 15
# Mean loss: tensor(0.0569, device='cuda:0')
# chain:  1 /epoch: 16
# Mean loss: tensor(0.0582, device='cuda:0')
# chain:  1 /epoch: 17
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  1 /epoch: 18
# Mean loss: tensor(0.0595, device='cuda:0')
# chain:  1 /epoch: 19
# Mean loss: tensor(0.0563, device='cuda:0')
# chain:  1 /epoch: 20
# Mean loss: tensor(0.0556, device='cuda:0')
# chain:  1 /epoch: 21
# Mean loss: tensor(0.0570, device='cuda:0')
# chain:  1 /epoch: 22
# Mean loss: tensor(0.0575, device='cuda:0')
# chain:  1 /epoch: 23
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  1 /epoch: 24
# Mean loss: tensor(0.0543, device='cuda:0')
# chain:  1 /epoch: 25
# Mean loss: tensor(0.0614, device='cuda:0')
# chain:  1 /epoch: 26
# Mean loss: tensor(0.0572, device='cuda:0')
# chain:  1 /epoch: 27
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  1 /epoch: 28
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  1 /epoch: 29
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  1 /epoch: 30
# Mean loss: tensor(0.0487, device='cuda:0')
# chain:  1 /epoch: 31
# Mean loss: tensor(0.0561, device='cuda:0')
# chain:  1 /epoch: 32
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  1 /epoch: 33
# Mean loss: tensor(0.0573, device='cuda:0')
# chain:  1 /epoch: 34
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  1 /epoch: 35
# Mean loss: tensor(0.0538, device='cuda:0')
# chain:  1 /epoch: 36
# Mean loss: tensor(0.0541, device='cuda:0')
# chain:  1 /epoch: 37
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  1 /epoch: 38
# Mean loss: tensor(0.0505, device='cuda:0')
# chain:  1 /epoch: 39
# Mean loss: tensor(0.0479, device='cuda:0')
# chain:  2 /epoch: 0
# Mean loss: tensor(0.2024, device='cuda:0')
# chain:  2 /epoch: 1
# Mean loss: tensor(0.1850, device='cuda:0')
# chain:  2 /epoch: 2
# Mean loss: tensor(0.1657, device='cuda:0')
# chain:  2 /epoch: 3
# Mean loss: tensor(0.1498, device='cuda:0')
# chain:  2 /epoch: 4
# Mean loss: tensor(0.1288, device='cuda:0')
# chain:  2 /epoch: 5
# Mean loss: tensor(0.1180, device='cuda:0')
# chain:  2 /epoch: 6
# Mean loss: tensor(0.0961, device='cuda:0')
# chain:  2 /epoch: 7
# Mean loss: tensor(0.0900, device='cuda:0')
# chain:  2 /epoch: 8
# Mean loss: tensor(0.0771, device='cuda:0')
# chain:  2 /epoch: 9
# Mean loss: tensor(0.0656, device='cuda:0')
# chain:  2 /epoch: 10
# Mean loss: tensor(0.0595, device='cuda:0')
# chain:  2 /epoch: 11
# Mean loss: tensor(0.0556, device='cuda:0')
# chain:  2 /epoch: 12
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  2 /epoch: 13
# Mean loss: tensor(0.0556, device='cuda:0')
# chain:  2 /epoch: 14
# Mean loss: tensor(0.0586, device='cuda:0')
# chain:  2 /epoch: 15
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  2 /epoch: 16
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  2 /epoch: 17
# Mean loss: tensor(0.0560, device='cuda:0')
# chain:  2 /epoch: 18
# Mean loss: tensor(0.0526, device='cuda:0')
# chain:  2 /epoch: 19
# Mean loss: tensor(0.0504, device='cuda:0')
# chain:  2 /epoch: 20
# Mean loss: tensor(0.0516, device='cuda:0')
# chain:  2 /epoch: 21
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  2 /epoch: 22
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  2 /epoch: 23
# Mean loss: tensor(0.0487, device='cuda:0')
# chain:  2 /epoch: 24
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  2 /epoch: 25
# Mean loss: tensor(0.0548, device='cuda:0')
# chain:  2 /epoch: 26
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  2 /epoch: 27
# Mean loss: tensor(0.0538, device='cuda:0')
# chain:  2 /epoch: 28
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  2 /epoch: 29
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  2 /epoch: 30
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  2 /epoch: 31
# Mean loss: tensor(0.0506, device='cuda:0')
# chain:  2 /epoch: 32
# Mean loss: tensor(0.0517, device='cuda:0')
# chain:  2 /epoch: 33
# Mean loss: tensor(0.0551, device='cuda:0')
# chain:  2 /epoch: 34
# Mean loss: tensor(0.0542, device='cuda:0')
# chain:  2 /epoch: 35
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  2 /epoch: 36
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  2 /epoch: 37
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  2 /epoch: 38
# Mean loss: tensor(0.0526, device='cuda:0')
# chain:  2 /epoch: 39
# Mean loss: tensor(0.0571, device='cuda:0')
# chain:  3 /epoch: 0
# Mean loss: tensor(0.2096, device='cuda:0')
# chain:  3 /epoch: 1
# Mean loss: tensor(0.1889, device='cuda:0')
# chain:  3 /epoch: 2
# Mean loss: tensor(0.1677, device='cuda:0')
# chain:  3 /epoch: 3
# Mean loss: tensor(0.1438, device='cuda:0')
# chain:  3 /epoch: 4
# Mean loss: tensor(0.1272, device='cuda:0')
# chain:  3 /epoch: 5
# Mean loss: tensor(0.1122, device='cuda:0')
# chain:  3 /epoch: 6
# Mean loss: tensor(0.0944, device='cuda:0')
# chain:  3 /epoch: 7
# Mean loss: tensor(0.0837, device='cuda:0')
# chain:  3 /epoch: 8
# Mean loss: tensor(0.0716, device='cuda:0')
# chain:  3 /epoch: 9
# Mean loss: tensor(0.0643, device='cuda:0')
# chain:  3 /epoch: 10
# Mean loss: tensor(0.0587, device='cuda:0')
# chain:  3 /epoch: 11
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  3 /epoch: 12
# Mean loss: tensor(0.0581, device='cuda:0')
# chain:  3 /epoch: 13
# Mean loss: tensor(0.0590, device='cuda:0')
# chain:  3 /epoch: 14
# Mean loss: tensor(0.0580, device='cuda:0')
# chain:  3 /epoch: 15
# Mean loss: tensor(0.0543, device='cuda:0')
# chain:  3 /epoch: 16
# Mean loss: tensor(0.0527, device='cuda:0')
# chain:  3 /epoch: 17
# Mean loss: tensor(0.0545, device='cuda:0')
# chain:  3 /epoch: 18
# Mean loss: tensor(0.0567, device='cuda:0')
# chain:  3 /epoch: 19
# Mean loss: tensor(0.0561, device='cuda:0')
# chain:  3 /epoch: 20
# Mean loss: tensor(0.0548, device='cuda:0')
# chain:  3 /epoch: 21
# Mean loss: tensor(0.0524, device='cuda:0')
# chain:  3 /epoch: 22
# Mean loss: tensor(0.0505, device='cuda:0')
# chain:  3 /epoch: 23
# Mean loss: tensor(0.0504, device='cuda:0')
# chain:  3 /epoch: 24
# Mean loss: tensor(0.0504, device='cuda:0')
# chain:  3 /epoch: 25
# Mean loss: tensor(0.0516, device='cuda:0')
# chain:  3 /epoch: 26
# Mean loss: tensor(0.0518, device='cuda:0')
# chain:  3 /epoch: 27
# Mean loss: tensor(0.0569, device='cuda:0')
# chain:  3 /epoch: 28
# Mean loss: tensor(0.0552, device='cuda:0')
# chain:  3 /epoch: 29
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  3 /epoch: 30
# Mean loss: tensor(0.0585, device='cuda:0')
# chain:  3 /epoch: 31
# Mean loss: tensor(0.0567, device='cuda:0')
# chain:  3 /epoch: 32
# Mean loss: tensor(0.0651, device='cuda:0')
# chain:  3 /epoch: 33
# Mean loss: tensor(0.0614, device='cuda:0')
# chain:  3 /epoch: 34
# Mean loss: tensor(0.0574, device='cuda:0')
# chain:  3 /epoch: 35
# Mean loss: tensor(0.0591, device='cuda:0')
# chain:  3 /epoch: 36
# Mean loss: tensor(0.0592, device='cuda:0')
# chain:  3 /epoch: 37
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  3 /epoch: 38
# Mean loss: tensor(0.0547, device='cuda:0')
# chain:  3 /epoch: 39
# Mean loss: tensor(0.0570, device='cuda:0')
# Test accuracy of the model: 93.561 %
# Epoch [20], Average Loss: 0.0117
# par_it: 3
#
# Epoch [1/20], Step [300/300]
# Test accuracy of the model: 88.161 %
# Epoch [1], Average Loss: 0.5142
# Epoch [2/20], Step [300/300]
# Test accuracy of the model: 90.541 %
# Epoch [2], Average Loss: 0.2930
# Epoch [3/20], Step [300/300]
# Test accuracy of the model: 90.211 %
# Epoch [3], Average Loss: 0.2383
# Epoch [4/20], Step [300/300]
# Test accuracy of the model: 91.021 %
# Epoch [4], Average Loss: 0.2115
# Epoch [5/20], Step [300/300]
# Test accuracy of the model: 91.041 %
# Epoch [5], Average Loss: 0.1893
# Epoch [6/20], Step [300/300]
# Test accuracy of the model: 91.851 %
# Epoch [6], Average Loss: 0.1719
# Epoch [7/20], Step [300/300]
# Test accuracy of the model: 91.991 %
# Epoch [7], Average Loss: 0.1605
# Epoch [8/20], Step [300/300]
# Test accuracy of the model: 92.191 %
# Epoch [8], Average Loss: 0.1418
# Epoch [9/20], Step [300/300]
# Test accuracy of the model: 92.581 %
# Epoch [9], Average Loss: 0.1309
# Epoch [10/20], Step [300/300]
# Test accuracy of the model: 92.191 %
# Epoch [10], Average Loss: 0.1099
# Epoch [11/20], Step [300/300]
# Test accuracy of the model: 92.561 %
# Epoch [11], Average Loss: 0.0890
# Epoch [12/20], Step [300/300]
# Test accuracy of the model: 92.911 %
# Epoch [12], Average Loss: 0.0704
# Epoch [13/20], Step [300/300]
# Test accuracy of the model: 92.831 %
# Epoch [13], Average Loss: 0.0457
# Epoch [14/20], Step [300/300]
# Test accuracy of the model: 93.411 %
# Epoch [14], Average Loss: 0.0322
# Epoch [15/20], Step [300/300]
# Test accuracy of the model: 93.291 %
# Epoch [15], Average Loss: 0.0186
# Epoch [16/20], Step [300/300]
# Test accuracy of the model: 92.911 %
# Epoch [16], Average Loss: 0.0155
# Epoch [17/20], Step [300/300]
# Test accuracy of the model: 93.171 %
# Epoch [17], Average Loss: 0.0137
# Epoch [18/20], Step [300/300]
# Test accuracy of the model: 93.271 %
# Epoch [18], Average Loss: 0.0127
# Epoch [19/20], Step [300/300]
# Test accuracy of the model: 93.211 %
# Epoch [19], Average Loss: 0.0141
# Epoch [20/20], Step [300/300]
# chain:  0 /epoch: 0
# Mean loss: tensor(0.2168, device='cuda:0')
# chain:  0 /epoch: 1
# Mean loss: tensor(0.2026, device='cuda:0')
# chain:  0 /epoch: 2
# Mean loss: tensor(0.1636, device='cuda:0')
# chain:  0 /epoch: 3
# Mean loss: tensor(0.1347, device='cuda:0')
# chain:  0 /epoch: 4
# Mean loss: tensor(0.1201, device='cuda:0')
# chain:  0 /epoch: 5
# Mean loss: tensor(0.1023, device='cuda:0')
# chain:  0 /epoch: 6
# Mean loss: tensor(0.0894, device='cuda:0')
# chain:  0 /epoch: 7
# Mean loss: tensor(0.0794, device='cuda:0')
# chain:  0 /epoch: 8
# Mean loss: tensor(0.0676, device='cuda:0')
# chain:  0 /epoch: 9
# Mean loss: tensor(0.0651, device='cuda:0')
# chain:  0 /epoch: 10
# Mean loss: tensor(0.0571, device='cuda:0')
# chain:  0 /epoch: 11
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  0 /epoch: 12
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  0 /epoch: 13
# Mean loss: tensor(0.0586, device='cuda:0')
# chain:  0 /epoch: 14
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  0 /epoch: 15
# Mean loss: tensor(0.0585, device='cuda:0')
# chain:  0 /epoch: 16
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  0 /epoch: 17
# Mean loss: tensor(0.0539, device='cuda:0')
# chain:  0 /epoch: 18
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  0 /epoch: 19
# Mean loss: tensor(0.0516, device='cuda:0')
# chain:  0 /epoch: 20
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  0 /epoch: 21
# Mean loss: tensor(0.0547, device='cuda:0')
# chain:  0 /epoch: 22
# Mean loss: tensor(0.0470, device='cuda:0')
# chain:  0 /epoch: 23
# Mean loss: tensor(0.0478, device='cuda:0')
# chain:  0 /epoch: 24
# Mean loss: tensor(0.0485, device='cuda:0')
# chain:  0 /epoch: 25
# Mean loss: tensor(0.0502, device='cuda:0')
# chain:  0 /epoch: 26
# Mean loss: tensor(0.0478, device='cuda:0')
# chain:  0 /epoch: 27
# Mean loss: tensor(0.0490, device='cuda:0')
# chain:  0 /epoch: 28
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  0 /epoch: 29
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  0 /epoch: 30
# Mean loss: tensor(0.0484, device='cuda:0')
# chain:  0 /epoch: 31
# Mean loss: tensor(0.0559, device='cuda:0')
# chain:  0 /epoch: 32
# Mean loss: tensor(0.0504, device='cuda:0')
# chain:  0 /epoch: 33
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  0 /epoch: 34
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  0 /epoch: 35
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  0 /epoch: 36
# Mean loss: tensor(0.0463, device='cuda:0')
# chain:  0 /epoch: 37
# Mean loss: tensor(0.0526, device='cuda:0')
# chain:  0 /epoch: 38
# Mean loss: tensor(0.0540, device='cuda:0')
# chain:  0 /epoch: 39
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  1 /epoch: 0
# Mean loss: tensor(0.1963, device='cuda:0')
# chain:  1 /epoch: 1
# Mean loss: tensor(0.1708, device='cuda:0')
# chain:  1 /epoch: 2
# Mean loss: tensor(0.1536, device='cuda:0')
# chain:  1 /epoch: 3
# Mean loss: tensor(0.1327, device='cuda:0')
# chain:  1 /epoch: 4
# Mean loss: tensor(0.1103, device='cuda:0')
# chain:  1 /epoch: 5
# Mean loss: tensor(0.0946, device='cuda:0')
# chain:  1 /epoch: 6
# Mean loss: tensor(0.0850, device='cuda:0')
# chain:  1 /epoch: 7
# Mean loss: tensor(0.0776, device='cuda:0')
# chain:  1 /epoch: 8
# Mean loss: tensor(0.0667, device='cuda:0')
# chain:  1 /epoch: 9
# Mean loss: tensor(0.0577, device='cuda:0')
# chain:  1 /epoch: 10
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  1 /epoch: 11
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  1 /epoch: 12
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  1 /epoch: 13
# Mean loss: tensor(0.0492, device='cuda:0')
# chain:  1 /epoch: 14
# Mean loss: tensor(0.0524, device='cuda:0')
# chain:  1 /epoch: 15
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  1 /epoch: 16
# Mean loss: tensor(0.0463, device='cuda:0')
# chain:  1 /epoch: 17
# Mean loss: tensor(0.0461, device='cuda:0')
# chain:  1 /epoch: 18
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  1 /epoch: 19
# Mean loss: tensor(0.0489, device='cuda:0')
# chain:  1 /epoch: 20
# Mean loss: tensor(0.0507, device='cuda:0')
# chain:  1 /epoch: 21
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  1 /epoch: 22
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  1 /epoch: 23
# Mean loss: tensor(0.0431, device='cuda:0')
# chain:  1 /epoch: 24
# Mean loss: tensor(0.0487, device='cuda:0')
# chain:  1 /epoch: 25
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  1 /epoch: 26
# Mean loss: tensor(0.0521, device='cuda:0')
# chain:  1 /epoch: 27
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  1 /epoch: 28
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  1 /epoch: 29
# Mean loss: tensor(0.0492, device='cuda:0')
# chain:  1 /epoch: 30
# Mean loss: tensor(0.0489, device='cuda:0')
# chain:  1 /epoch: 31
# Mean loss: tensor(0.0555, device='cuda:0')
# chain:  1 /epoch: 32
# Mean loss: tensor(0.0528, device='cuda:0')
# chain:  1 /epoch: 33
# Mean loss: tensor(0.0484, device='cuda:0')
# chain:  1 /epoch: 34
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  1 /epoch: 35
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  1 /epoch: 36
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  1 /epoch: 37
# Mean loss: tensor(0.0491, device='cuda:0')
# chain:  1 /epoch: 38
# Mean loss: tensor(0.0448, device='cuda:0')
# chain:  1 /epoch: 39
# Mean loss: tensor(0.0454, device='cuda:0')
# chain:  2 /epoch: 0
# Mean loss: tensor(0.1766, device='cuda:0')
# chain:  2 /epoch: 1
# Mean loss: tensor(0.1675, device='cuda:0')
# chain:  2 /epoch: 2
# Mean loss: tensor(0.1441, device='cuda:0')
# chain:  2 /epoch: 3
# Mean loss: tensor(0.1162, device='cuda:0')
# chain:  2 /epoch: 4
# Mean loss: tensor(0.1089, device='cuda:0')
# chain:  2 /epoch: 5
# Mean loss: tensor(0.0849, device='cuda:0')
# chain:  2 /epoch: 6
# Mean loss: tensor(0.0775, device='cuda:0')
# chain:  2 /epoch: 7
# Mean loss: tensor(0.0667, device='cuda:0')
# chain:  2 /epoch: 8
# Mean loss: tensor(0.0589, device='cuda:0')
# chain:  2 /epoch: 9
# Mean loss: tensor(0.0569, device='cuda:0')
# chain:  2 /epoch: 10
# Mean loss: tensor(0.0547, device='cuda:0')
# chain:  2 /epoch: 11
# Mean loss: tensor(0.0506, device='cuda:0')
# chain:  2 /epoch: 12
# Mean loss: tensor(0.0505, device='cuda:0')
# chain:  2 /epoch: 13
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  2 /epoch: 14
# Mean loss: tensor(0.0482, device='cuda:0')
# chain:  2 /epoch: 15
# Mean loss: tensor(0.0550, device='cuda:0')
# chain:  2 /epoch: 16
# Mean loss: tensor(0.0515, device='cuda:0')
# chain:  2 /epoch: 17
# Mean loss: tensor(0.0513, device='cuda:0')
# chain:  2 /epoch: 18
# Mean loss: tensor(0.0472, device='cuda:0')
# chain:  2 /epoch: 19
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  2 /epoch: 20
# Mean loss: tensor(0.0539, device='cuda:0')
# chain:  2 /epoch: 21
# Mean loss: tensor(0.0508, device='cuda:0')
# chain:  2 /epoch: 22
# Mean loss: tensor(0.0539, device='cuda:0')
# chain:  2 /epoch: 23
# Mean loss: tensor(0.0539, device='cuda:0')
# chain:  2 /epoch: 24
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  2 /epoch: 25
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  2 /epoch: 26
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  2 /epoch: 27
# Mean loss: tensor(0.0480, device='cuda:0')
# chain:  2 /epoch: 28
# Mean loss: tensor(0.0482, device='cuda:0')
# chain:  2 /epoch: 29
# Mean loss: tensor(0.0456, device='cuda:0')
# chain:  2 /epoch: 30
# Mean loss: tensor(0.0485, device='cuda:0')
# chain:  2 /epoch: 31
# Mean loss: tensor(0.0513, device='cuda:0')
# chain:  2 /epoch: 32
# Mean loss: tensor(0.0441, device='cuda:0')
# chain:  2 /epoch: 33
# Mean loss: tensor(0.0415, device='cuda:0')
# chain:  2 /epoch: 34
# Mean loss: tensor(0.0440, device='cuda:0')
# chain:  2 /epoch: 35
# Mean loss: tensor(0.0474, device='cuda:0')
# chain:  2 /epoch: 36
# Mean loss: tensor(0.0434, device='cuda:0')
# chain:  2 /epoch: 37
# Mean loss: tensor(0.0477, device='cuda:0')
# chain:  2 /epoch: 38
# Mean loss: tensor(0.0481, device='cuda:0')
# chain:  2 /epoch: 39
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  3 /epoch: 0
# Mean loss: tensor(0.1800, device='cuda:0')
# chain:  3 /epoch: 1
# Mean loss: tensor(0.1766, device='cuda:0')
# chain:  3 /epoch: 2
# Mean loss: tensor(0.1479, device='cuda:0')
# chain:  3 /epoch: 3
# Mean loss: tensor(0.1226, device='cuda:0')
# chain:  3 /epoch: 4
# Mean loss: tensor(0.1105, device='cuda:0')
# chain:  3 /epoch: 5
# Mean loss: tensor(0.0890, device='cuda:0')
# chain:  3 /epoch: 6
# Mean loss: tensor(0.0717, device='cuda:0')
# chain:  3 /epoch: 7
# Mean loss: tensor(0.0672, device='cuda:0')
# chain:  3 /epoch: 8
# Mean loss: tensor(0.0651, device='cuda:0')
# chain:  3 /epoch: 9
# Mean loss: tensor(0.0609, device='cuda:0')
# chain:  3 /epoch: 10
# Mean loss: tensor(0.0599, device='cuda:0')
# chain:  3 /epoch: 11
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  3 /epoch: 12
# Mean loss: tensor(0.0508, device='cuda:0')
# chain:  3 /epoch: 13
# Mean loss: tensor(0.0521, device='cuda:0')
# chain:  3 /epoch: 14
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  3 /epoch: 15
# Mean loss: tensor(0.0477, device='cuda:0')
# chain:  3 /epoch: 16
# Mean loss: tensor(0.0485, device='cuda:0')
# chain:  3 /epoch: 17
# Mean loss: tensor(0.0482, device='cuda:0')
# chain:  3 /epoch: 18
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  3 /epoch: 19
# Mean loss: tensor(0.0518, device='cuda:0')
# chain:  3 /epoch: 20
# Mean loss: tensor(0.0473, device='cuda:0')
# chain:  3 /epoch: 21
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  3 /epoch: 22
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  3 /epoch: 23
# Mean loss: tensor(0.0474, device='cuda:0')
# chain:  3 /epoch: 24
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 25
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  3 /epoch: 26
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  3 /epoch: 27
# Mean loss: tensor(0.0527, device='cuda:0')
# chain:  3 /epoch: 28
# ...
# chain:  2 /epoch: 22
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  2 /epoch: 23
# Mean loss: tensor(0.0477, device='cuda:0')
# chain:  2 /epoch: 24
# Mean loss: tensor(0.0508, device='cuda:0')
# chain:  2 /epoch: 25
# Mean loss: tensor(0.0537, device='cuda:0')
# chain:  2 /epoch: 26
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  2 /epoch: 27
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  2 /epoch: 28
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  2 /epoch: 29
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  2 /epoch: 30
# Mean loss: tensor(0.0487, device='cuda:0')
# chain:  2 /epoch: 31
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  2 /epoch: 32
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  2 /epoch: 33
# Mean loss: tensor(0.0520, device='cuda:0')
# chain:  2 /epoch: 34
# Mean loss: tensor(0.0448, device='cuda:0')
# chain:  2 /epoch: 35
# Mean loss: tensor(0.0447, device='cuda:0')
# chain:  2 /epoch: 36
# Mean loss: tensor(0.0445, device='cuda:0')
# chain:  2 /epoch: 37
# Mean loss: tensor(0.0501, device='cuda:0')
# chain:  2 /epoch: 38
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  2 /epoch: 39
# Mean loss: tensor(0.0492, device='cuda:0')
# chain:  3 /epoch: 0
# Mean loss: tensor(0.1888, device='cuda:0')
# chain:  3 /epoch: 1
# Mean loss: tensor(0.1670, device='cuda:0')
# chain:  3 /epoch: 2
# Mean loss: tensor(0.1433, device='cuda:0')
# chain:  3 /epoch: 3
# Mean loss: tensor(0.1215, device='cuda:0')
# chain:  3 /epoch: 4
# Mean loss: tensor(0.1024, device='cuda:0')
# chain:  3 /epoch: 5
# Mean loss: tensor(0.0865, device='cuda:0')
# chain:  3 /epoch: 6
# Mean loss: tensor(0.0760, device='cuda:0')
# chain:  3 /epoch: 7
# Mean loss: tensor(0.0683, device='cuda:0')
# chain:  3 /epoch: 8
# Mean loss: tensor(0.0656, device='cuda:0')
# chain:  3 /epoch: 9
# Mean loss: tensor(0.0615, device='cuda:0')
# chain:  3 /epoch: 10
# Mean loss: tensor(0.0514, device='cuda:0')
# chain:  3 /epoch: 11
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  3 /epoch: 12
# Mean loss: tensor(0.0477, device='cuda:0')
# chain:  3 /epoch: 13
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  3 /epoch: 14
# Mean loss: tensor(0.0515, device='cuda:0')
# chain:  3 /epoch: 15
# Mean loss: tensor(0.0503, device='cuda:0')
# chain:  3 /epoch: 16
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  3 /epoch: 17
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  3 /epoch: 18
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  3 /epoch: 19
# Mean loss: tensor(0.0513, device='cuda:0')
# chain:  3 /epoch: 20
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  3 /epoch: 21
# Mean loss: tensor(0.0464, device='cuda:0')
# chain:  3 /epoch: 22
# Mean loss: tensor(0.0452, device='cuda:0')
# chain:  3 /epoch: 23
# Mean loss: tensor(0.0456, device='cuda:0')
# chain:  3 /epoch: 24
# Mean loss: tensor(0.0451, device='cuda:0')
# chain:  3 /epoch: 25
# Mean loss: tensor(0.0494, device='cuda:0')
# chain:  3 /epoch: 26
# Mean loss: tensor(0.0482, device='cuda:0')
# chain:  3 /epoch: 27
# Mean loss: tensor(0.0484, device='cuda:0')
# chain:  3 /epoch: 28
# Mean loss: tensor(0.0510, device='cuda:0')
# chain:  3 /epoch: 29
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  3 /epoch: 30
# Mean loss: tensor(0.0493, device='cuda:0')
# chain:  3 /epoch: 31
# Mean loss: tensor(0.0531, device='cuda:0')
# chain:  3 /epoch: 32
# Mean loss: tensor(0.0488, device='cuda:0')
# chain:  3 /epoch: 33
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  3 /epoch: 34
# Mean loss: tensor(0.0502, device='cuda:0')
# chain:  3 /epoch: 35
# Mean loss: tensor(0.0470, device='cuda:0')
# chain:  3 /epoch: 36
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  3 /epoch: 37
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  3 /epoch: 38
# Mean loss: tensor(0.0488, device='cuda:0')
# chain:  3 /epoch: 39
# Mean loss: tensor(0.0533, device='cuda:0')
# Test accuracy of the model: 93.721 %
# Epoch [20], Average Loss: 0.0110
# par_it: 15
#
# Epoch [1/20], Step [300/300]
# Test accuracy of the model: 84.102 %
# Epoch [1], Average Loss: 0.5551
# Epoch [2/20], Step [300/300]
# Test accuracy of the model: 88.141 %
# Epoch [2], Average Loss: 0.3153
# Epoch [3/20], Step [300/300]
# Test accuracy of the model: 90.781 %
# Epoch [3], Average Loss: 0.2528
# Epoch [4/20], Step [300/300]
# Test accuracy of the model: 91.481 %
# Epoch [4], Average Loss: 0.2181
# Epoch [5/20], Step [300/300]
# Test accuracy of the model: 91.851 %
# Epoch [5], Average Loss: 0.1934
# Epoch [6/20], Step [300/300]
# Test accuracy of the model: 91.821 %
# Epoch [6], Average Loss: 0.1747
# Epoch [7/20], Step [300/300]
# Test accuracy of the model: 91.871 %
# Epoch [7], Average Loss: 0.1594
# Epoch [8/20], Step [300/300]
# Test accuracy of the model: 92.241 %
# Epoch [8], Average Loss: 0.1496
# Epoch [9/20], Step [300/300]
# Test accuracy of the model: 92.591 %
# Epoch [9], Average Loss: 0.1256
# Epoch [10/20], Step [300/300]
# Test accuracy of the model: 92.681 %
# Epoch [10], Average Loss: 0.1147
# Epoch [11/20], Step [300/300]
# Test accuracy of the model: 92.701 %
# Epoch [11], Average Loss: 0.0924
# Epoch [12/20], Step [300/300]
# Test accuracy of the model: 92.871 %
# Epoch [12], Average Loss: 0.0781
# Epoch [13/20], Step [300/300]
# Test accuracy of the model: 93.221 %
# Epoch [13], Average Loss: 0.0557
# Epoch [14/20], Step [300/300]
# Test accuracy of the model: 93.011 %
# Epoch [14], Average Loss: 0.0307
# Epoch [15/20], Step [300/300]
# Test accuracy of the model: 92.841 %
# Epoch [15], Average Loss: 0.0234
# Epoch [16/20], Step [300/300]
# Test accuracy of the model: 93.311 %
# Epoch [16], Average Loss: 0.0181
# Epoch [17/20], Step [300/300]
# Test accuracy of the model: 93.031 %
# Epoch [17], Average Loss: 0.0139
# Epoch [18/20], Step [300/300]
# Test accuracy of the model: 93.311 %
# Epoch [18], Average Loss: 0.0114
# Epoch [19/20], Step [300/300]
# Test accuracy of the model: 92.881 %
# Epoch [19], Average Loss: 0.0116
# Epoch [20/20], Step [300/300]
# chain:  0 /epoch: 0
# Mean loss: tensor(0.1881, device='cuda:0')
# chain:  0 /epoch: 1
# Mean loss: tensor(0.1713, device='cuda:0')
# chain:  0 /epoch: 2
# Mean loss: tensor(0.1465, device='cuda:0')
# chain:  0 /epoch: 3
# Mean loss: tensor(0.1250, device='cuda:0')
# chain:  0 /epoch: 4
# Mean loss: tensor(0.1124, device='cuda:0')
# chain:  0 /epoch: 5
# Mean loss: tensor(0.0992, device='cuda:0')
# chain:  0 /epoch: 6
# Mean loss: tensor(0.0881, device='cuda:0')
# chain:  0 /epoch: 7
# Mean loss: tensor(0.0752, device='cuda:0')
# chain:  0 /epoch: 8
# Mean loss: tensor(0.0684, device='cuda:0')
# chain:  0 /epoch: 9
# Mean loss: tensor(0.0719, device='cuda:0')
# chain:  0 /epoch: 10
# Mean loss: tensor(0.0751, device='cuda:0')
# chain:  0 /epoch: 11
# Mean loss: tensor(0.0604, device='cuda:0')
# chain:  0 /epoch: 12
# Mean loss: tensor(0.0595, device='cuda:0')
# chain:  0 /epoch: 13
# Mean loss: tensor(0.0609, device='cuda:0')
# chain:  0 /epoch: 14
# Mean loss: tensor(0.0600, device='cuda:0')
# chain:  0 /epoch: 15
# Mean loss: tensor(0.0567, device='cuda:0')
# chain:  0 /epoch: 16
# Mean loss: tensor(0.0559, device='cuda:0')
# chain:  0 /epoch: 17
# Mean loss: tensor(0.0521, device='cuda:0')
# chain:  0 /epoch: 18
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  0 /epoch: 19
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  0 /epoch: 20
# Mean loss: tensor(0.0576, device='cuda:0')
# chain:  0 /epoch: 21
# Mean loss: tensor(0.0557, device='cuda:0')
# chain:  0 /epoch: 22
# Mean loss: tensor(0.0524, device='cuda:0')
# chain:  0 /epoch: 23
# Mean loss: tensor(0.0502, device='cuda:0')
# chain:  0 /epoch: 24
# Mean loss: tensor(0.0557, device='cuda:0')
# chain:  0 /epoch: 25
# Mean loss: tensor(0.0568, device='cuda:0')
# chain:  0 /epoch: 26
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  0 /epoch: 27
# Mean loss: tensor(0.0535, device='cuda:0')
# chain:  0 /epoch: 28
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  0 /epoch: 29
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  0 /epoch: 30
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  0 /epoch: 31
# Mean loss: tensor(0.0517, device='cuda:0')
# chain:  0 /epoch: 32
# Mean loss: tensor(0.0496, device='cuda:0')
# chain:  0 /epoch: 33
# Mean loss: tensor(0.0530, device='cuda:0')
# chain:  0 /epoch: 34
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  0 /epoch: 35
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  0 /epoch: 36
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  0 /epoch: 37
# Mean loss: tensor(0.0542, device='cuda:0')
# chain:  0 /epoch: 38
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  0 /epoch: 39
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  1 /epoch: 0
# Mean loss: tensor(0.2230, device='cuda:0')
# chain:  1 /epoch: 1
# Mean loss: tensor(0.2184, device='cuda:0')
# chain:  1 /epoch: 2
# Mean loss: tensor(0.1719, device='cuda:0')
# chain:  1 /epoch: 3
# Mean loss: tensor(0.1537, device='cuda:0')
# chain:  1 /epoch: 4
# Mean loss: tensor(0.1333, device='cuda:0')
# chain:  1 /epoch: 5
# Mean loss: tensor(0.1101, device='cuda:0')
# chain:  1 /epoch: 6
# Mean loss: tensor(0.1013, device='cuda:0')
# chain:  1 /epoch: 7
# Mean loss: tensor(0.0902, device='cuda:0')
# chain:  1 /epoch: 8
# Mean loss: tensor(0.0757, device='cuda:0')
# chain:  1 /epoch: 9
# Mean loss: tensor(0.0639, device='cuda:0')
# chain:  1 /epoch: 10
# Mean loss: tensor(0.0622, device='cuda:0')
# chain:  1 /epoch: 11
# Mean loss: tensor(0.0571, device='cuda:0')
# chain:  1 /epoch: 12
# Mean loss: tensor(0.0664, device='cuda:0')
# chain:  1 /epoch: 13
# Mean loss: tensor(0.0652, device='cuda:0')
# chain:  1 /epoch: 14
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  1 /epoch: 15
# Mean loss: tensor(0.0537, device='cuda:0')
# chain:  1 /epoch: 16
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  1 /epoch: 17
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  1 /epoch: 18
# Mean loss: tensor(0.0546, device='cuda:0')
# chain:  1 /epoch: 19
# Mean loss: tensor(0.0580, device='cuda:0')
# chain:  1 /epoch: 20
# Mean loss: tensor(0.0557, device='cuda:0')
# chain:  1 /epoch: 21
# Mean loss: tensor(0.0508, device='cuda:0')
# chain:  1 /epoch: 22
# Mean loss: tensor(0.0500, device='cuda:0')
# chain:  1 /epoch: 23
# Mean loss: tensor(0.0498, device='cuda:0')
# chain:  1 /epoch: 24
# Mean loss: tensor(0.0526, device='cuda:0')
# chain:  1 /epoch: 25
# Mean loss: tensor(0.0555, device='cuda:0')
# chain:  1 /epoch: 26
# Mean loss: tensor(0.0539, device='cuda:0')
# chain:  1 /epoch: 27
# Mean loss: tensor(0.0503, device='cuda:0')
# chain:  1 /epoch: 28
# Mean loss: tensor(0.0506, device='cuda:0')
# chain:  1 /epoch: 29
# Mean loss: tensor(0.0488, device='cuda:0')
# chain:  1 /epoch: 30
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  1 /epoch: 31
# Mean loss: tensor(0.0547, device='cuda:0')
# chain:  1 /epoch: 32
# Mean loss: tensor(0.0572, device='cuda:0')
# chain:  1 /epoch: 33
# Mean loss: tensor(0.0560, device='cuda:0')
# chain:  1 /epoch: 34
# Mean loss: tensor(0.0560, device='cuda:0')
# chain:  1 /epoch: 35
# Mean loss: tensor(0.0550, device='cuda:0')
# chain:  1 /epoch: 36
# Mean loss: tensor(0.0549, device='cuda:0')
# chain:  1 /epoch: 37
# Mean loss: tensor(0.0541, device='cuda:0')
# chain:  1 /epoch: 38
# Mean loss: tensor(0.0553, device='cuda:0')
# chain:  1 /epoch: 39
# Mean loss: tensor(0.0524, device='cuda:0')
# chain:  2 /epoch: 0
# Mean loss: tensor(0.2139, device='cuda:0')
# chain:  2 /epoch: 1
# Mean loss: tensor(0.1738, device='cuda:0')
# chain:  2 /epoch: 2
# Mean loss: tensor(0.1454, device='cuda:0')
# chain:  2 /epoch: 3
# Mean loss: tensor(0.1337, device='cuda:0')
# chain:  2 /epoch: 4
# Mean loss: tensor(0.1089, device='cuda:0')
# chain:  2 /epoch: 5
# Mean loss: tensor(0.0918, device='cuda:0')
# chain:  2 /epoch: 6
# Mean loss: tensor(0.0860, device='cuda:0')
# chain:  2 /epoch: 7
# Mean loss: tensor(0.0761, device='cuda:0')
# chain:  2 /epoch: 8
# Mean loss: tensor(0.0697, device='cuda:0')
# chain:  2 /epoch: 9
# Mean loss: tensor(0.0619, device='cuda:0')
# chain:  2 /epoch: 10
# Mean loss: tensor(0.0580, device='cuda:0')
# chain:  2 /epoch: 11
# Mean loss: tensor(0.0593, device='cuda:0')
# chain:  2 /epoch: 12
# Mean loss: tensor(0.0641, device='cuda:0')
# chain:  2 /epoch: 13
# Mean loss: tensor(0.0557, device='cuda:0')
# chain:  2 /epoch: 14
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  2 /epoch: 15
# Mean loss: tensor(0.0536, device='cuda:0')
# chain:  2 /epoch: 16
# Mean loss: tensor(0.0563, device='cuda:0')
# chain:  2 /epoch: 17
# Mean loss: tensor(0.0521, device='cuda:0')
# chain:  2 /epoch: 18
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  2 /epoch: 19
# Mean loss: tensor(0.0561, device='cuda:0')
# chain:  2 /epoch: 20
# Mean loss: tensor(0.0537, device='cuda:0')
# chain:  2 /epoch: 21
# Mean loss: tensor(0.0543, device='cuda:0')
# chain:  2 /epoch: 22
# Mean loss: tensor(0.0499, device='cuda:0')
# chain:  2 /epoch: 23
# Mean loss: tensor(0.0502, device='cuda:0')
# chain:  2 /epoch: 24
# Mean loss: tensor(0.0501, device='cuda:0')
# chain:  2 /epoch: 25
# Mean loss: tensor(0.0522, device='cuda:0')
# chain:  2 /epoch: 26
# Mean loss: tensor(0.0541, device='cuda:0')
# chain:  2 /epoch: 27
# Mean loss: tensor(0.0525, device='cuda:0')
# chain:  2 /epoch: 28
# Mean loss: tensor(0.0543, device='cuda:0')
# chain:  2 /epoch: 29
# Mean loss: tensor(0.0511, device='cuda:0')
# chain:  2 /epoch: 30
# Mean loss: tensor(0.0533, device='cuda:0')
# chain:  2 /epoch: 31
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  2 /epoch: 32
# Mean loss: tensor(0.0529, device='cuda:0')
# chain:  2 /epoch: 33
# Mean loss: tensor(0.0487, device='cuda:0')
# chain:  2 /epoch: 34
# Mean loss: tensor(0.0538, device='cuda:0')
# chain:  2 /epoch: 35
# Mean loss: tensor(0.0517, device='cuda:0')
# chain:  2 /epoch: 36
# Mean loss: tensor(0.0515, device='cuda:0')
# chain:  2 /epoch: 37
# Mean loss: tensor(0.0550, device='cuda:0')
# chain:  2 /epoch: 38
# Mean loss: tensor(0.0583, device='cuda:0')
# chain:  2 /epoch: 39
# Mean loss: tensor(0.0580, device='cuda:0')
# chain:  3 /epoch: 0
# Mean loss: tensor(0.2433, device='cuda:0')
# chain:  3 /epoch: 1
# Mean loss: tensor(0.2271, device='cuda:0')
# chain:  3 /epoch: 2
# Mean loss: tensor(0.1869, device='cuda:0')
# chain:  3 /epoch: 3
# Mean loss: tensor(0.1575, device='cuda:0')
# chain:  3 /epoch: 4
# Mean loss: tensor(0.1420, device='cuda:0')
# chain:  3 /epoch: 5
# Mean loss: tensor(0.1221, device='cuda:0')
# chain:  3 /epoch: 6
# Mean loss: tensor(0.1017, device='cuda:0')
# chain:  3 /epoch: 7
# Mean loss: tensor(0.0970, device='cuda:0')
# chain:  3 /epoch: 8
# Mean loss: tensor(0.0891, device='cuda:0')
# chain:  3 /epoch: 9
# Mean loss: tensor(0.0719, device='cuda:0')
# chain:  3 /epoch: 10
# Mean loss: tensor(0.0689, device='cuda:0')
# chain:  3 /epoch: 11
# Mean loss: tensor(0.0565, device='cuda:0')
# chain:  3 /epoch: 12
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  3 /epoch: 13
# Mean loss: tensor(0.0591, device='cuda:0')
# chain:  3 /epoch: 14
# Mean loss: tensor(0.0536, device='cuda:0')
# chain:  3 /epoch: 15
# Mean loss: tensor(0.0548, device='cuda:0')
# chain:  3 /epoch: 16
# Mean loss: tensor(0.0556, device='cuda:0')
# chain:  3 /epoch: 17
# Mean loss: tensor(0.0534, device='cuda:0')
# chain:  3 /epoch: 18
# Mean loss: tensor(0.0523, device='cuda:0')
# chain:  3 /epoch: 19
# Mean loss: tensor(0.0558, device='cuda:0')
# chain:  3 /epoch: 20
# Mean loss: tensor(0.0544, device='cuda:0')
# chain:  3 /epoch: 21
# Mean loss: tensor(0.0608, device='cuda:0')
# chain:  3 /epoch: 22
# Mean loss: tensor(0.0555, device='cuda:0')
# chain:  3 /epoch: 23
# Mean loss: tensor(0.0570, device='cuda:0')
# chain:  3 /epoch: 24
# Mean loss: tensor(0.0562, device='cuda:0')
# chain:  3 /epoch: 25
# Mean loss: tensor(0.0567, device='cuda:0')
# chain:  3 /epoch: 26
# Mean loss: tensor(0.0589, device='cuda:0')
# chain:  3 /epoch: 27
# Mean loss: tensor(0.0597, device='cuda:0')
# chain:  3 /epoch: 28
# Mean loss: tensor(0.0549, device='cuda:0')
# chain:  3 /epoch: 29
# Mean loss: tensor(0.0573, device='cuda:0')
# chain:  3 /epoch: 30
# Mean loss: tensor(0.0521, device='cuda:0')
# chain:  3 /epoch: 31
# Mean loss: tensor(0.0589, device='cuda:0')
# chain:  3 /epoch: 32
# Mean loss: tensor(0.0509, device='cuda:0')
# chain:  3 /epoch: 33
# Mean loss: tensor(0.0486, device='cuda:0')
# chain:  3 /epoch: 34
# Mean loss: tensor(0.0471, device='cuda:0')
# chain:  3 /epoch: 35
# Mean loss: tensor(0.0497, device='cuda:0')
# chain:  3 /epoch: 36
# Mean loss: tensor(0.0496, device='cuda:0')
# chain:  3 /epoch: 37
# Mean loss: tensor(0.0519, device='cuda:0')
# chain:  3 /epoch: 38
# Mean loss: tensor(0.0513, device='cuda:0')
# chain:  3 /epoch: 39
# Mean loss: tensor(0.0509, device='cuda:0')
# Test accuracy of the model: 93.701 %
# Epoch [20], Average Loss: 0.0144

# %%
n=0
for par in net.parameters():
    n+=par.numel()
n
# Out:
# 1265258

# %%
net_star_backup=copy.deepcopy(net_star)

# %%
#filepath="output_fashion.pickle"
#with open(filepath,"rb") as file:
#    [labels_arr,test_labels_arr,test_prob_arr,_,_]=pickle.load(file)
#labels_arr=torch.tensor(labels_arr).detach()
#test_labels_arr=torch.tensor(test_labels_arr).detach()
#test_prob_arr=torch.tensor(test_prob_arr).detach()

# %%
# Outcome should be a binary list of the ordinal outcome. [0, 1, 0] for exmaple.
# Probs should be a list of probabilities. [0.79, 0.09, 0.12] for example.
# Outcome and Probs must be provided with the same order as probabilities.

def rps_single(probs, true_label):
    outcome=torch.zeros(num_classes)
    outcome[true_label.int()]=1.0
    cum_probs = torch.cumsum(probs,0)
    cum_outcomes = torch.cumsum(outcome,0)
    
    #print(cum_outcomes)
    #print(cum_probs)
    sum_rps = 0
    for i in range(len(outcome)):         
        sum_rps+= (cum_probs[i] - cum_outcomes[i])**2
    
    return sum_rps/(num_classes-1)

def rps_calc(test_probs, true_labels):
    rps_vec=torch.zeros(test_data_len)
    for it in range(test_data_len):
        rps_vec[it]=rps_single(test_probs[it,:].reshape(num_classes),true_labels[it])
    return rps_vec

def nll_calc(test_probs, true_labels):
    res=0
    for it in range(test_data_len):
        res-=torch.max(torch.tensor([torch.log(test_probs[it,true_labels[it].int()]),-100]))
    return res/test_data_len

def adaptive_calibration_error(test_probs,true_labels, num_bins=20):
    max_probs, predicted_labels = torch.max(test_probs,1)
    ind=torch.argsort(max_probs,stable=True)
    sorted_max_probs=max_probs[ind]
    sorted_predicted_labels=predicted_labels[ind]
    sorted_true_labels=true_labels[ind]

    correct = (sorted_predicted_labels == sorted_true_labels).clone().detach().float()
    bins=(torch.tensor(range(test_data_len))/torch.tensor(test_data_len/num_bins)).floor()

    o=torch.tensor(0.0)
    for b in range(num_bins):
        mask = (bins == b)
        if torch.any(mask):
            #print(b, sorted_max_probs[mask].mean(), (correct[mask] - sorted_max_probs[mask]).mean())
            o += (correct[mask] - sorted_max_probs[mask]).mean().abs()

    return o / num_bins

# %%
#test_prob=torch.Tensor(test_prob_arr[:,:,29,0]).reshape(test_size,num_classes)
#torch.cumsum(test_prob[1,:].reshape(num_classes),0)
#rps_single(test_prob[1,:].reshape(num_classes),test_labels_arr[1])

# %%
#no bayesian
par_runs=1
def compute_acc_ace_rps_no_bayes(es):
    copies=int(par_runs/es)
    ace_arr=torch.zeros(copies)
    rps_arr=torch.zeros(copies)
    nll_arr=torch.zeros(copies)
    accuracy_arr=torch.zeros(copies)

    for it in range(copies):
        test_prob=torch.Tensor(test_prob_arr[:,:,14,it*es:(it+1)*es]).mean(-1).reshape(test_size,num_classes)
        ace_arr[it]=adaptive_calibration_error(test_prob,test_labels_arr)
        rps_arr[it]=(rps_calc(test_prob, test_labels_arr)).mean()
        nll_arr[it]=nll_calc(test_prob, test_labels_arr)
        _, predictedt = torch.max(test_prob,1)
        accuracy_arr[it]= (predictedt==test_labels_arr.reshape(1,test_size)).sum()/test_size
    print("Non-Bayesian, ensemble size:", es)
    print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
    print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
    print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
    print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
    return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

acc=torch.zeros(5)
acc_std=torch.zeros(5)
ace=torch.zeros(5)
ace_std=torch.zeros(5)
rps=torch.zeros(5)
rps_std=torch.zeros(5)
nll=torch.zeros(5)
nll_std=torch.zeros(5)
[acc[0],acc_std[0],ace[0],ace_std[0],rps[0],rps_std[0],nll[0],nll_std[0]]=compute_acc_ace_rps_no_bayes(1)
[acc[1],acc_std[1],ace[1],ace_std[1],rps[1],rps_std[1],nll[1],nll_std[1]]=compute_acc_ace_rps_no_bayes(2)
[acc[2],acc_std[2],ace[2],ace_std[2],rps[2],rps_std[2],nll[2],nll_std[2]]=compute_acc_ace_rps_no_bayes(4)
[acc[3],acc_std[3],ace[3],ace_std[3],rps[3],rps_std[3],nll[3],nll_std[3]]=compute_acc_ace_rps_no_bayes(8)
[acc[4],acc_std[4],ace[4],ace_std[4],rps[4],rps_std[4],nll[4],nll_std[4]]=compute_acc_ace_rps_no_bayes(16)

# from scipy.io import savemat
# filepath="results_fashion_no_bayes_rand_test.mat"
# mdic={"acc":acc.cpu().numpy(),"acc_std":acc_std.cpu().numpy(),"nll": nll.cpu().numpy(),"nll_std":nll_std.cpu().numpy(),\
#       "ace": ace.cpu().numpy(),"ace_std":ace_std.cpu().numpy(), "rps":rps.cpu().numpy(),"rps_std":rps_std.cpu().numpy()}
# savemat(filepath,mdic)
# Out:
# Non-Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9320) std: tensor(nan)
# mean ace: tensor(0.0440) std: tensor(nan)
# mean nll: tensor(0.3028) std: tensor(nan)
# mean rps: tensor(0.0213) std: tensor(nan)
# Non-Bayesian, ensemble size: 2
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# Non-Bayesian, ensemble size: 4
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# Non-Bayesian, ensemble size: 8
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# Non-Bayesian, ensemble size: 16
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# <ipython-input-18-5f500bdf8e3f>:18: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
# <ipython-input-18-5f500bdf8e3f>:19: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
# <ipython-input-18-5f500bdf8e3f>:20: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
# <ipython-input-18-5f500bdf8e3f>:21: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
# <ipython-input-18-5f500bdf8e3f>:22: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

# %% [markdown]
# Non-Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9296) std: tensor(0.0020)
# mean ace: tensor(0.0555) std: tensor(0.0018)
# mean nll: tensor(0.4709) std: tensor(0.0251)
# mean rps: tensor(0.0230) std: tensor(0.0008)
# Non-Bayesian, ensemble size: 2
# mean accuracy: tensor(0.9383) std: tensor(0.0015)
# mean ace: tensor(0.0294) std: tensor(0.0016)
# mean nll: tensor(0.3109) std: tensor(0.0127)
# mean rps: tensor(0.0188) std: tensor(0.0005)
# Non-Bayesian, ensemble size: 4
# mean accuracy: tensor(0.9422) std: tensor(0.0010)
# mean ace: tensor(0.0177) std: tensor(0.0011)
# mean nll: tensor(0.2385) std: tensor(0.0066)
# mean rps: tensor(0.0168) std: tensor(0.0003)
# Non-Bayesian, ensemble size: 8
# mean accuracy: tensor(0.9443) std: tensor(0.0006)
# mean ace: tensor(0.0126) std: tensor(0.0007)
# mean nll: tensor(0.2025) std: tensor(0.0042)
# mean rps: tensor(0.0157) std: tensor(0.0002)
# Non-Bayesian, ensemble size: 16
# mean accuracy: tensor(0.9459) std: tensor(0.0009)
# mean ace: tensor(0.0098) std: tensor(0.0007)
# mean nll: tensor(0.1832) std: tensor(0.0029)
# mean rps: tensor(0.0152) std: tensor(8.2395e-05)

# %%
#swa
def compute_acc_ace_rps_swa(es):
    copies=int(par_runs/es)
    ace_arr=torch.zeros(copies)
    rps_arr=torch.zeros(copies)
    nll_arr=torch.zeros(copies)
    accuracy_arr=torch.zeros(copies)

    for it in range(copies):
        test_prob=torch.Tensor(test_prob_arr[:,:,19,it*es:(it+1)*es]).mean(-1).reshape(test_size,num_classes)
        ace_arr[it]=adaptive_calibration_error(test_prob,test_labels_arr)
        rps_arr[it]=(rps_calc(test_prob, test_labels_arr)).mean()
        nll_arr[it]=nll_calc(test_prob, test_labels_arr)
        _, predictedt = torch.max(test_prob,1)
        accuracy_arr[it]= (predictedt==test_labels_arr.reshape(1,test_size)).sum()/test_size
    print("SWA, ensemble size:", es)
    print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
    print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
    print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
    print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
    return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

acc=torch.zeros(5)
acc_std=torch.zeros(5)
ace=torch.zeros(5)
ace_std=torch.zeros(5)
rps=torch.zeros(5)
rps_std=torch.zeros(5)
nll=torch.zeros(5)
nll_std=torch.zeros(5)
[acc[0],acc_std[0],ace[0],ace_std[0],rps[0],rps_std[0],nll[0],nll_std[0]]=compute_acc_ace_rps_swa(1)
[acc[1],acc_std[1],ace[1],ace_std[1],rps[1],rps_std[1],nll[1],nll_std[1]]=compute_acc_ace_rps_swa(2)
[acc[2],acc_std[2],ace[2],ace_std[2],rps[2],rps_std[2],nll[2],nll_std[2]]=compute_acc_ace_rps_swa(4)
[acc[3],acc_std[3],ace[3],ace_std[3],rps[3],rps_std[3],nll[3],nll_std[3]]=compute_acc_ace_rps_swa(8)
[acc[4],acc_std[4],ace[4],ace_std[4],rps[4],rps_std[4],nll[4],nll_std[4]]=compute_acc_ace_rps_swa(16)

# from scipy.io import savemat
# filepath="results_fashion_swa_rand_test.mat"
# mdic={"acc":acc.cpu().numpy(),"acc_std":acc_std.cpu().numpy(),"nll": nll.cpu().numpy(),"nll_std":nll_std.cpu().numpy(),\
#       "ace": ace.cpu().numpy(),"ace_std":ace_std.cpu().numpy(), "rps":rps.cpu().numpy(),"rps_std":rps_std.cpu().numpy()}
# savemat(filepath,mdic)
# Out:
# SWA, ensemble size: 1
# mean accuracy: tensor(0.9357) std: tensor(nan)
# mean ace: tensor(0.0458) std: tensor(nan)
# mean nll: tensor(0.3382) std: tensor(nan)
# mean rps: tensor(0.0209) std: tensor(nan)
# SWA, ensemble size: 2
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# SWA, ensemble size: 4
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# SWA, ensemble size: 8
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# SWA, ensemble size: 16
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# <ipython-input-19-584ea30b4abe>:17: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
# <ipython-input-19-584ea30b4abe>:18: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
# <ipython-input-19-584ea30b4abe>:19: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
# <ipython-input-19-584ea30b4abe>:20: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
# <ipython-input-19-584ea30b4abe>:21: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

# %% [markdown]
# SWA, ensemble size: 1
# mean accuracy: tensor(0.9337) std: tensor(0.0016)
# mean ace: tensor(0.0537) std: tensor(0.0016)
# mean nll: tensor(0.4826) std: tensor(0.0191)
# mean rps: tensor(0.0220) std: tensor(0.0006)
# SWA, ensemble size: 2
# mean accuracy: tensor(0.9403) std: tensor(0.0012)
# mean ace: tensor(0.0309) std: tensor(0.0012)
# mean nll: tensor(0.3312) std: tensor(0.0111)
# mean rps: tensor(0.0184) std: tensor(0.0004)
# SWA, ensemble size: 4
# mean accuracy: tensor(0.9435) std: tensor(0.0011)
# mean ace: tensor(0.0223) std: tensor(0.0010)
# mean nll: tensor(0.2579) std: tensor(0.0078)
# mean rps: tensor(0.0166) std: tensor(0.0003)
# SWA, ensemble size: 8
# mean accuracy: tensor(0.9453) std: tensor(0.0008)
# mean ace: tensor(0.0180) std: tensor(0.0011)
# mean nll: tensor(0.2186) std: tensor(0.0036)
# mean rps: tensor(0.0157) std: tensor(0.0002)
# SWA, ensemble size: 16
# mean accuracy: tensor(0.9462) std: tensor(0.0008)
# mean ace: tensor(0.0158) std: tensor(0.0009)
# mean nll: tensor(0.1964) std: tensor(0.0034)
# mean rps: tensor(0.0153) std: tensor(5.5335e-05)

# %%
#Bayesian
def compute_acc_ace_rps_bayes(es):
    copies=int(par_runs/es)
    ace_arr=torch.zeros(copies)
    rps_arr=torch.zeros(copies)
    nll_arr=torch.zeros(copies)
    accuracy_arr=torch.zeros(copies)

    for it in range(copies):
        test_prob=torch.Tensor(test_prob_arr[:,:,30:60,it*es:(it+1)*es]).mean(-1).mean(-1).reshape(test_size,num_classes)
        ace_arr[it]=adaptive_calibration_error(test_prob,test_labels_arr)
        rps_arr[it]=(rps_calc(test_prob, test_labels_arr)).mean()
        nll_arr[it]=nll_calc(test_prob, test_labels_arr)
        _, predictedt = torch.max(test_prob,1)
        accuracy_arr[it]= (predictedt==test_labels_arr.reshape(1,test_size)).sum()/test_size
    print("Bayesian, ensemble size:", es)
    print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
    print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
    print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
    print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
    return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]



acc=torch.zeros(5)
acc_std=torch.zeros(5)
ace=torch.zeros(5)
ace_std=torch.zeros(5)
rps=torch.zeros(5)
rps_std=torch.zeros(5)
nll=torch.zeros(5)
nll_std=torch.zeros(5)
[acc[0],acc_std[0],ace[0],ace_std[0],rps[0],rps_std[0],nll[0],nll_std[0]]=compute_acc_ace_rps_bayes(1)
[acc[1],acc_std[1],ace[1],ace_std[1],rps[1],rps_std[1],nll[1],nll_std[1]]=compute_acc_ace_rps_bayes(2)
[acc[2],acc_std[2],ace[2],ace_std[2],rps[2],rps_std[2],nll[2],nll_std[2]]=compute_acc_ace_rps_bayes(4)
[acc[3],acc_std[3],ace[3],ace_std[3],rps[3],rps_std[3],nll[3],nll_std[3]]=compute_acc_ace_rps_bayes(8)
[acc[4],acc_std[4],ace[4],ace_std[4],rps[4],rps_std[4],nll[4],nll_std[4]]=compute_acc_ace_rps_bayes(16)

# from scipy.io import savemat
# filepath="results_fashion_bayes_rand_test.mat"
# mdic={"acc":acc.cpu().numpy(),"acc_std":acc_std.cpu().numpy(),"nll": nll.cpu().numpy(),"nll_std":nll_std.cpu().numpy(),\
#       "ace": ace.cpu().numpy(),"ace_std":ace_std.cpu().numpy(), "rps":rps.cpu().numpy(),"rps_std":rps_std.cpu().numpy()}
# savemat(filepath,mdic)
# Out:
# Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9373) std: tensor(nan)
# mean ace: tensor(0.0137) std: tensor(nan)
# mean nll: tensor(0.1941) std: tensor(nan)
# mean rps: tensor(0.0179) std: tensor(nan)
# Bayesian, ensemble size: 2
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# Bayesian, ensemble size: 4
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# Bayesian, ensemble size: 8
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# Bayesian, ensemble size: 16
# mean accuracy: tensor(nan) std: tensor(nan)
# mean ace: tensor(nan) std: tensor(nan)
# mean nll: tensor(nan) std: tensor(nan)
# mean rps: tensor(nan) std: tensor(nan)
# <ipython-input-20-858763f44eaa>:17: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean accuracy:",accuracy_arr.mean(),"std:",accuracy_arr.std())
# <ipython-input-20-858763f44eaa>:18: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean ace:",ace_arr.mean(),"std:",ace_arr.std())
# <ipython-input-20-858763f44eaa>:19: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean nll:",nll_arr.mean(),"std:",nll_arr.std())
# <ipython-input-20-858763f44eaa>:20: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   print("mean rps:",rps_arr.mean(),"std:",rps_arr.std())
# <ipython-input-20-858763f44eaa>:21: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\ReduceOps.cpp:1807.)
#   return [accuracy_arr.mean(),accuracy_arr.std(),ace_arr.mean(),ace_arr.std(),rps_arr.mean(),rps_arr.std(),nll_arr.mean(),nll_arr.std()]

# %% [markdown]
# Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9358) std: tensor(nan)
# mean ace: tensor(0.0123) std: tensor(nan)
# mean nll: tensor(0.2039) std: tensor(nan)
# mean rps: tensor(0.0177) std: tensor(nan)
#
# Bayesian, ensemble size: 1
# mean accuracy: tensor(0.9400) std: tensor(nan)
# mean ace: tensor(0.0072) std: tensor(nan)
# mean nll: tensor(0.1876) std: tensor(nan)
# mean rps: tensor(0.0169) std: tensor(nan)

# %%
# test_prob=torch.Tensor(test_prob_arr[:,7,0]).reshape(test_size,1)
# ace=adaptive_calibration_error(test_labels_arr.reshape(test_size,1).numpy(),test_prob.numpy(),20)
# ace

# %%
# test_prob=torch.Tensor(test_prob_arr[:,10:16,48:64]).mean(-1).mean(-1).reshape(test_size,1)
# ace=adaptive_calibration_error(test_labels_arr.reshape(test_size,1).numpy(),test_prob.numpy(),20)
# ace

# %%
import torchvision
from torchview import draw_graph
net2 = Fashion_MNIST_CNN()

#model_graph = draw_graph(net2, input_size=(1,3,64,64), expand_nested=True)
model_graph = draw_graph(net2, input_size=(1,1,28,28), expand_nested=True)
model_graph.visual_graph
# Out:
# Warning: Could not load "C:\Users\Daniel Paulin\.conda\envs\torchenv39\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: no hard-coded metrics for 'Linux libertine'.  Falling back to 'Times' metrics
